# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 16 kB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=178e9755ef393844b24e83e02ead016b40fa530f90fd14374fcc7f1754115851
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*100)/math.log(mean)
  img = np.power(img, gamma).clip(0,100).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((22279, 48, 48, 1), (2755, 48, 48, 1), (2749, 48, 48, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import callbacks as cb

# Training parameter
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
dataset_type = 'FER2013'


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = dataset_type + '_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.7):
      lr = 0.0001
    elif epoch >= (epochs*0.3):
      lr=0.001
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    datagen.fit(x_train)
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Epoch 1/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 442ms/step - loss: 0.9612 - accuracy: 0.6911 - val_loss: 1.5680 - val_accuracy: 0.5216
#
# Epoch 00001: val_accuracy did not improve from 0.69916
# Epoch 2/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 442ms/step - loss: 0.9123 - accuracy: 0.7112 - val_loss: 1.5878 - val_accuracy: 0.5155
#
# Epoch 00002: val_accuracy did not improve from 0.69916
# Epoch 3/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 444ms/step - loss: 0.8852 - accuracy: 0.7183 - val_loss: 3.1741 - val_accuracy: 0.3529
#
# Epoch 00003: val_accuracy did not improve from 0.69916
# Epoch 4/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 445ms/step - loss: 0.8694 - accuracy: 0.7234 - val_loss: 1.4961 - val_accuracy: 0.5075
#
# Epoch 00004: val_accuracy did not improve from 0.69916
# Epoch 5/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 446ms/step - loss: 0.8687 - accuracy: 0.7252 - val_loss: 4.0332 - val_accuracy: 0.1943
#
# Epoch 00005: val_accuracy did not improve from 0.69916
# Epoch 6/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 449ms/step - loss: 0.8646 - accuracy: 0.7297 - val_loss: 1.6167 - val_accuracy: 0.4962
#
# Epoch 00006: val_accuracy did not improve from 0.69916
# Epoch 7/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 451ms/step - loss: 0.8544 - accuracy: 0.7378 - val_loss: 2.2332 - val_accuracy: 0.4034
#
# Epoch 00007: val_accuracy did not improve from 0.69916
# Epoch 8/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 452ms/step - loss: 0.8535 - accuracy: 0.7368 - val_loss: 1.5667 - val_accuracy: 0.5005
#
# Epoch 00008: val_accuracy did not improve from 0.69916
# Epoch 9/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 451ms/step - loss: 0.8602 - accuracy: 0.7357 - val_loss: 2.2062 - val_accuracy: 0.3594
#
# Epoch 00009: val_accuracy did not improve from 0.69916
# Epoch 10/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 453ms/step - loss: 0.8727 - accuracy: 0.7291 - val_loss: 1.2684 - val_accuracy: 0.6257
#
# Epoch 00010: val_accuracy did not improve from 0.69916
# Epoch 11/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8500 - accuracy: 0.7418 - val_loss: 1.5605 - val_accuracy: 0.4714
#
# Epoch 00011: val_accuracy did not improve from 0.69916
# Epoch 12/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 0.8739 - accuracy: 0.7310 - val_loss: 1.2832 - val_accuracy: 0.6082
#
# Epoch 00012: val_accuracy did not improve from 0.69916
# Epoch 13/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8592 - accuracy: 0.7355 - val_loss: 1.4633 - val_accuracy: 0.5729
#
# Epoch 00013: val_accuracy did not improve from 0.69916
# Epoch 14/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 461ms/step - loss: 0.8640 - accuracy: 0.7398 - val_loss: 1.8505 - val_accuracy: 0.4467
#
# Epoch 00014: val_accuracy did not improve from 0.69916
# Epoch 15/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 451ms/step - loss: 0.8679 - accuracy: 0.7390 - val_loss: 1.6689 - val_accuracy: 0.5198
#
# Epoch 00015: val_accuracy did not improve from 0.69916
# Epoch 16/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 458ms/step - loss: 0.8613 - accuracy: 0.7407 - val_loss: 1.6356 - val_accuracy: 0.5442
#
# Epoch 00016: val_accuracy did not improve from 0.69916
# Epoch 17/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 454ms/step - loss: 0.8621 - accuracy: 0.7385 - val_loss: 1.8604 - val_accuracy: 0.4638
#
# Epoch 00017: val_accuracy did not improve from 0.69916
# Epoch 18/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 455ms/step - loss: 0.8712 - accuracy: 0.7355 - val_loss: 1.7531 - val_accuracy: 0.4925
#
# Epoch 00018: val_accuracy did not improve from 0.69916
# Epoch 19/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8761 - accuracy: 0.7398 - val_loss: 1.6749 - val_accuracy: 0.4882
#
# Epoch 00019: val_accuracy did not improve from 0.69916
# Epoch 20/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 453ms/step - loss: 0.8754 - accuracy: 0.7391 - val_loss: 3.9644 - val_accuracy: 0.2455
#
# Epoch 00020: val_accuracy did not improve from 0.69916
# Epoch 21/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8822 - accuracy: 0.7354 - val_loss: 1.5467 - val_accuracy: 0.5380
#
# Epoch 00021: val_accuracy did not improve from 0.69916
# Epoch 22/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 457ms/step - loss: 0.8796 - accuracy: 0.7391 - val_loss: 1.6442 - val_accuracy: 0.5176
#
# Epoch 00022: val_accuracy did not improve from 0.69916
# Epoch 23/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 455ms/step - loss: 0.8916 - accuracy: 0.7318 - val_loss: 1.7927 - val_accuracy: 0.4423
#
# Epoch 00023: val_accuracy did not improve from 0.69916
# Epoch 24/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8734 - accuracy: 0.7364 - val_loss: 1.7764 - val_accuracy: 0.4027
#
# Epoch 00024: val_accuracy did not improve from 0.69916
# Epoch 25/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 454ms/step - loss: 0.8784 - accuracy: 0.7372 - val_loss: 3.9323 - val_accuracy: 0.1768
#
# Epoch 00025: val_accuracy did not improve from 0.69916
# Epoch 26/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 458ms/step - loss: 0.8846 - accuracy: 0.7371 - val_loss: 2.1522 - val_accuracy: 0.3598
#
# Epoch 00026: val_accuracy did not improve from 0.69916
# Epoch 27/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 457ms/step - loss: 0.8911 - accuracy: 0.7345 - val_loss: 2.2095 - val_accuracy: 0.3383
#
# Epoch 00027: val_accuracy did not improve from 0.69916
# Epoch 28/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 457ms/step - loss: 0.8916 - accuracy: 0.7329 - val_loss: 1.5836 - val_accuracy: 0.5035
#
# Epoch 00028: val_accuracy did not improve from 0.69916
# Epoch 29/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 452ms/step - loss: 0.8915 - accuracy: 0.7323 - val_loss: 1.8467 - val_accuracy: 0.3449
#
# Epoch 00029: val_accuracy did not improve from 0.69916
# Epoch 30/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 454ms/step - loss: 0.8871 - accuracy: 0.7345 - val_loss: 1.8304 - val_accuracy: 0.4212
#
# Epoch 00030: val_accuracy did not improve from 0.69916
# Epoch 31/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8858 - accuracy: 0.7397 - val_loss: 1.7964 - val_accuracy: 0.4187
#
# Epoch 00031: val_accuracy did not improve from 0.69916
# Epoch 32/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 457ms/step - loss: 0.8910 - accuracy: 0.7362 - val_loss: 1.7698 - val_accuracy: 0.4558
#
# Epoch 00032: val_accuracy did not improve from 0.69916
# Epoch 33/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8922 - accuracy: 0.7357 - val_loss: 2.2518 - val_accuracy: 0.3627
#
# Epoch 00033: val_accuracy did not improve from 0.69916
# Epoch 34/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 455ms/step - loss: 0.9021 - accuracy: 0.7340 - val_loss: 1.6961 - val_accuracy: 0.4638
#
# Epoch 00034: val_accuracy did not improve from 0.69916
# Epoch 35/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 0.9073 - accuracy: 0.7304 - val_loss: 1.9507 - val_accuracy: 0.3452
#
# Epoch 00035: val_accuracy did not improve from 0.69916
# Epoch 36/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 455ms/step - loss: 0.9137 - accuracy: 0.7284 - val_loss: 1.7721 - val_accuracy: 0.5111
#
# Epoch 00036: val_accuracy did not improve from 0.69916
# Epoch 37/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 459ms/step - loss: 0.9008 - accuracy: 0.7344 - val_loss: 1.5431 - val_accuracy: 0.5489
#
# Epoch 00037: val_accuracy did not improve from 0.69916
# Epoch 38/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 454ms/step - loss: 0.9059 - accuracy: 0.7326 - val_loss: 1.7014 - val_accuracy: 0.5482
#
# Epoch 00038: val_accuracy did not improve from 0.69916
# Epoch 39/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 462ms/step - loss: 0.8961 - accuracy: 0.7398 - val_loss: 1.4840 - val_accuracy: 0.5482
#
# Epoch 00039: val_accuracy did not improve from 0.69916
# Epoch 40/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 458ms/step - loss: 0.9064 - accuracy: 0.7327 - val_loss: 1.7986 - val_accuracy: 0.3976
#
# Epoch 00040: val_accuracy did not improve from 0.69916
# Epoch 41/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 464ms/step - loss: 0.8350 - accuracy: 0.7655 - val_loss: 1.2974 - val_accuracy: 0.6108
#
# Epoch 00041: val_accuracy did not improve from 0.69916
# Epoch 42/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7782 - accuracy: 0.7864 - val_loss: 1.1989 - val_accuracy: 0.6457
#
# Epoch 00042: val_accuracy did not improve from 0.69916
# Epoch 43/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7517 - accuracy: 0.7920 - val_loss: 1.1412 - val_accuracy: 0.6737
#
# Epoch 00043: val_accuracy did not improve from 0.69916
# Epoch 44/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7371 - accuracy: 0.7974 - val_loss: 1.1424 - val_accuracy: 0.6770
#
# Epoch 00044: val_accuracy did not improve from 0.69916
# Epoch 45/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.7249 - accuracy: 0.8033 - val_loss: 1.1186 - val_accuracy: 0.6872
#
# Epoch 00045: val_accuracy did not improve from 0.69916
# Epoch 46/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.7156 - accuracy: 0.8052 - val_loss: 1.1339 - val_accuracy: 0.6839
#
# Epoch 00046: val_accuracy did not improve from 0.69916
# Epoch 47/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 459ms/step - loss: 0.7044 - accuracy: 0.8077 - val_loss: 1.1353 - val_accuracy: 0.6912
#
# Epoch 00047: val_accuracy did not improve from 0.69916
# Epoch 48/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.6972 - accuracy: 0.8089 - val_loss: 1.1273 - val_accuracy: 0.6904
#
# Epoch 00048: val_accuracy did not improve from 0.69916
# Epoch 49/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.6930 - accuracy: 0.8147 - val_loss: 1.1395 - val_accuracy: 0.6868
#
# Epoch 00049: val_accuracy did not improve from 0.69916
# Epoch 50/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.6846 - accuracy: 0.8146 - val_loss: 1.1615 - val_accuracy: 0.6784
#
# Epoch 00050: val_accuracy did not improve from 0.69916
# Epoch 51/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6815 - accuracy: 0.8140 - val_loss: 1.1863 - val_accuracy: 0.6872
#
# Epoch 00051: val_accuracy did not improve from 0.69916
# Epoch 52/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.6613 - accuracy: 0.8209 - val_loss: 1.2021 - val_accuracy: 0.6966
#
# Epoch 00052: val_accuracy did not improve from 0.69916
# Epoch 53/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6563 - accuracy: 0.8223 - val_loss: 1.2081 - val_accuracy: 0.6868
#
# Epoch 00053: val_accuracy did not improve from 0.69916
# Epoch 54/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.6608 - accuracy: 0.8219 - val_loss: 1.1855 - val_accuracy: 0.6919
#
# Epoch 00054: val_accuracy did not improve from 0.69916
# Epoch 55/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.6517 - accuracy: 0.8238 - val_loss: 1.1763 - val_accuracy: 0.6890
#
# Epoch 00055: val_accuracy did not improve from 0.69916
# Epoch 56/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.6395 - accuracy: 0.8302 - val_loss: 1.1921 - val_accuracy: 0.6930
#
# Epoch 00056: val_accuracy did not improve from 0.69916
# Epoch 57/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6384 - accuracy: 0.8280 - val_loss: 1.2490 - val_accuracy: 0.6639
#
# Epoch 00057: val_accuracy did not improve from 0.69916
# Epoch 58/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.6288 - accuracy: 0.8306 - val_loss: 1.1413 - val_accuracy: 0.6893
#
# Epoch 00058: val_accuracy did not improve from 0.69916
# Epoch 59/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.6233 - accuracy: 0.8336 - val_loss: 1.1589 - val_accuracy: 0.6893
#
# Epoch 00059: val_accuracy did not improve from 0.69916
# Epoch 60/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.6193 - accuracy: 0.8352 - val_loss: 1.2203 - val_accuracy: 0.6872
#
# Epoch 00060: val_accuracy did not improve from 0.69916
# Epoch 61/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.6194 - accuracy: 0.8368 - val_loss: 1.1450 - val_accuracy: 0.6984
#
# Epoch 00061: val_accuracy did not improve from 0.69916
# Epoch 62/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.6144 - accuracy: 0.8372 - val_loss: 1.1463 - val_accuracy: 0.6901
#
# Epoch 00062: val_accuracy did not improve from 0.69916
# Epoch 63/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6046 - accuracy: 0.8387 - val_loss: 1.2350 - val_accuracy: 0.6730
#
# Epoch 00063: val_accuracy did not improve from 0.69916
# Epoch 64/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.6016 - accuracy: 0.8394 - val_loss: 1.3980 - val_accuracy: 0.6268
#
# Epoch 00064: val_accuracy did not improve from 0.69916
# Epoch 65/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5995 - accuracy: 0.8409 - val_loss: 1.3171 - val_accuracy: 0.6511
#
# Epoch 00065: val_accuracy did not improve from 0.69916
# Epoch 66/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 456ms/step - loss: 0.5883 - accuracy: 0.8425 - val_loss: 1.2963 - val_accuracy: 0.6686
#
# Epoch 00066: val_accuracy did not improve from 0.69916
# Epoch 67/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5918 - accuracy: 0.8404 - val_loss: 1.2049 - val_accuracy: 0.6930
#
# Epoch 00067: val_accuracy did not improve from 0.69916
# Epoch 68/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5870 - accuracy: 0.8443 - val_loss: 1.2567 - val_accuracy: 0.6824
#
# Epoch 00068: val_accuracy did not improve from 0.69916
# Epoch 69/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5834 - accuracy: 0.8450 - val_loss: 1.2718 - val_accuracy: 0.6682
#
# Epoch 00069: val_accuracy did not improve from 0.69916
# Epoch 70/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5820 - accuracy: 0.8454 - val_loss: 1.2549 - val_accuracy: 0.6802
#
# Epoch 00070: val_accuracy did not improve from 0.69916
# Epoch 71/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 460ms/step - loss: 0.5789 - accuracy: 0.8442 - val_loss: 1.2135 - val_accuracy: 0.6839
#
# Epoch 00071: val_accuracy did not improve from 0.69916
# Epoch 72/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.5739 - accuracy: 0.8478 - val_loss: 1.2550 - val_accuracy: 0.6893
#
# Epoch 00072: val_accuracy did not improve from 0.69916
# Epoch 73/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5730 - accuracy: 0.8473 - val_loss: 1.2328 - val_accuracy: 0.6813
#
# Epoch 00073: val_accuracy did not improve from 0.69916
# Epoch 74/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5705 - accuracy: 0.8484 - val_loss: 1.2089 - val_accuracy: 0.6850
#
# Epoch 00074: val_accuracy did not improve from 0.69916
# Epoch 75/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 460ms/step - loss: 0.5695 - accuracy: 0.8481 - val_loss: 1.2578 - val_accuracy: 0.6817
#
# Epoch 00075: val_accuracy did not improve from 0.69916
# Epoch 76/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5629 - accuracy: 0.8516 - val_loss: 1.3089 - val_accuracy: 0.6792
#
# Epoch 00076: val_accuracy did not improve from 0.69916
# Epoch 77/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5571 - accuracy: 0.8555 - val_loss: 1.2201 - val_accuracy: 0.6868
#
# Epoch 00077: val_accuracy did not improve from 0.69916
# Epoch 78/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 456ms/step - loss: 0.5576 - accuracy: 0.8523 - val_loss: 1.2602 - val_accuracy: 0.6821
#
# Epoch 00078: val_accuracy did not improve from 0.69916
# Epoch 79/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5572 - accuracy: 0.8541 - val_loss: 1.2711 - val_accuracy: 0.6872
#
# Epoch 00079: val_accuracy did not improve from 0.69916
# Epoch 80/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5499 - accuracy: 0.8556 - val_loss: 1.4390 - val_accuracy: 0.6759
#
# Epoch 00080: val_accuracy did not improve from 0.69916
# Epoch 81/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 459ms/step - loss: 0.5457 - accuracy: 0.8561 - val_loss: 1.3025 - val_accuracy: 0.6817
#
# Epoch 00081: val_accuracy did not improve from 0.69916
# Epoch 82/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5468 - accuracy: 0.8573 - val_loss: 1.2250 - val_accuracy: 0.6813
#
# Epoch 00082: val_accuracy did not improve from 0.69916
# Epoch 83/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 459ms/step - loss: 0.5441 - accuracy: 0.8570 - val_loss: 1.2163 - val_accuracy: 0.6824
#
# Epoch 00083: val_accuracy did not improve from 0.69916
# Epoch 84/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5368 - accuracy: 0.8579 - val_loss: 1.2917 - val_accuracy: 0.6923
#
# Epoch 00084: val_accuracy did not improve from 0.69916
# Epoch 85/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5370 - accuracy: 0.8595 - val_loss: 1.2436 - val_accuracy: 0.6810
#
# Epoch 00085: val_accuracy did not improve from 0.69916
# Epoch 86/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.5308 - accuracy: 0.8597 - val_loss: 1.2974 - val_accuracy: 0.6566
#
# Epoch 00086: val_accuracy did not improve from 0.69916
# Epoch 87/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5331 - accuracy: 0.8583 - val_loss: 1.3391 - val_accuracy: 0.6864
#
# Epoch 00087: val_accuracy did not improve from 0.69916
# Epoch 88/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.5308 - accuracy: 0.8583 - val_loss: 1.2642 - val_accuracy: 0.6883
#
# Epoch 00088: val_accuracy did not improve from 0.69916
# Epoch 89/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5260 - accuracy: 0.8618 - val_loss: 1.2475 - val_accuracy: 0.6886
#
# Epoch 00089: val_accuracy did not improve from 0.69916
# Epoch 90/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5295 - accuracy: 0.8607 - val_loss: 1.2637 - val_accuracy: 0.6879
#
# Epoch 00090: val_accuracy did not improve from 0.69916
# Epoch 91/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.5178 - accuracy: 0.8651 - val_loss: 1.4244 - val_accuracy: 0.6781
#
# Epoch 00091: val_accuracy did not improve from 0.69916
# Epoch 92/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5225 - accuracy: 0.8650 - val_loss: 1.3450 - val_accuracy: 0.6879
#
# Epoch 00092: val_accuracy did not improve from 0.69916
# Epoch 93/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.5193 - accuracy: 0.8656 - val_loss: 1.2617 - val_accuracy: 0.6864
#
# Epoch 00093: val_accuracy did not improve from 0.69916
# Epoch 94/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5087 - accuracy: 0.8670 - val_loss: 1.3241 - val_accuracy: 0.6722
#
# Epoch 00094: val_accuracy did not improve from 0.69916
# Epoch 95/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5138 - accuracy: 0.8677 - val_loss: 1.3696 - val_accuracy: 0.6421
#
# Epoch 00095: val_accuracy did not improve from 0.69916
# Epoch 96/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5155 - accuracy: 0.8660 - val_loss: 1.2625 - val_accuracy: 0.6904
#
# Epoch 00096: val_accuracy did not improve from 0.69916
# Epoch 97/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.5049 - accuracy: 0.8689 - val_loss: 1.2358 - val_accuracy: 0.6810
#
# Epoch 00097: val_accuracy did not improve from 0.69916
# Epoch 98/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5090 - accuracy: 0.8684 - val_loss: 1.3049 - val_accuracy: 0.6810
#
# Epoch 00098: val_accuracy did not improve from 0.69916
# Epoch 99/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5041 - accuracy: 0.8715 - val_loss: 1.2937 - val_accuracy: 0.6817
#
# Epoch 00099: val_accuracy did not improve from 0.69916
# Epoch 100/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 446ms/step - loss: 0.5009 - accuracy: 0.8698 - val_loss: 1.3045 - val_accuracy: 0.6733
#
# Epoch 00100: val_accuracy did not improve from 0.69916
# Epoch 101/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4966 - accuracy: 0.8715 - val_loss: 1.2917 - val_accuracy: 0.6857
#
# Epoch 00101: val_accuracy did not improve from 0.69916
# Epoch 102/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.4991 - accuracy: 0.8703 - val_loss: 1.3571 - val_accuracy: 0.6712
#
# Epoch 00102: val_accuracy did not improve from 0.69916
# Epoch 103/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4986 - accuracy: 0.8722 - val_loss: 1.3193 - val_accuracy: 0.6810
#
# Epoch 00103: val_accuracy did not improve from 0.69916
# Epoch 104/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.4945 - accuracy: 0.8722 - val_loss: 1.2621 - val_accuracy: 0.6828
#
# Epoch 00104: val_accuracy did not improve from 0.69916
# Epoch 105/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.4891 - accuracy: 0.8740 - val_loss: 1.4514 - val_accuracy: 0.6744
#
# Epoch 00105: val_accuracy did not improve from 0.69916
# Epoch 106/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4939 - accuracy: 0.8736 - val_loss: 1.3509 - val_accuracy: 0.6606
#
# Epoch 00106: val_accuracy did not improve from 0.69916
# Epoch 107/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 450ms/step - loss: 0.4841 - accuracy: 0.8752 - val_loss: 1.3912 - val_accuracy: 0.6704
#
# Epoch 00107: val_accuracy did not improve from 0.69916
# Epoch 108/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4909 - accuracy: 0.8751 - val_loss: 1.3641 - val_accuracy: 0.6672
#
# Epoch 00108: val_accuracy did not improve from 0.69916
# Epoch 109/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4859 - accuracy: 0.8759 - val_loss: 1.5288 - val_accuracy: 0.6544
#
# Epoch 00109: val_accuracy did not improve from 0.69916
# Epoch 110/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4760 - accuracy: 0.8780 - val_loss: 1.3539 - val_accuracy: 0.6824
#
# Epoch 00110: val_accuracy did not improve from 0.69916
# Epoch 111/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4822 - accuracy: 0.8770 - val_loss: 1.3970 - val_accuracy: 0.6693
#
# Epoch 00111: val_accuracy did not improve from 0.69916
# Epoch 112/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.4753 - accuracy: 0.8790 - val_loss: 1.2825 - val_accuracy: 0.6875
#
# Epoch 00112: val_accuracy did not improve from 0.69916
# Epoch 113/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4814 - accuracy: 0.8753 - val_loss: 1.3230 - val_accuracy: 0.6842
#
# Epoch 00113: val_accuracy did not improve from 0.69916
# Epoch 114/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4806 - accuracy: 0.8781 - val_loss: 1.3059 - val_accuracy: 0.6850
#
# Epoch 00114: val_accuracy did not improve from 0.69916
# Epoch 115/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4738 - accuracy: 0.8788 - val_loss: 1.4710 - val_accuracy: 0.6748
#
# Epoch 00115: val_accuracy did not improve from 0.69916
# Epoch 116/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4727 - accuracy: 0.8800 - val_loss: 1.4680 - val_accuracy: 0.6846
#
# Epoch 00116: val_accuracy did not improve from 0.69916
# Epoch 117/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.4647 - accuracy: 0.8818 - val_loss: 1.4974 - val_accuracy: 0.6559
#
# Epoch 00117: val_accuracy did not improve from 0.69916
# Epoch 118/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4705 - accuracy: 0.8815 - val_loss: 1.3775 - val_accuracy: 0.6639
#
# Epoch 00118: val_accuracy did not improve from 0.69916
# Epoch 119/200
# Learning rate:  0.001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4674 - accuracy: 0.8805 - val_loss: 1.3862 - val_accuracy: 0.6748
#
# Epoch 00119: val_accuracy did not improve from 0.69916
# Epoch 120/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4614 - accuracy: 0.8822 - val_loss: 1.4711 - val_accuracy: 0.6857
#
# Epoch 00120: val_accuracy did not improve from 0.69916
# Epoch 121/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4415 - accuracy: 0.8939 - val_loss: 1.3773 - val_accuracy: 0.6984
#
# Epoch 00121: val_accuracy did not improve from 0.69916
# Epoch 122/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4159 - accuracy: 0.9032 - val_loss: 1.3930 - val_accuracy: 0.6970
#
# Epoch 00122: val_accuracy did not improve from 0.69916
# Epoch 123/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4148 - accuracy: 0.9008 - val_loss: 1.3848 - val_accuracy: 0.6995
#
# Epoch 00123: val_accuracy improved from 0.69916 to 0.69953, saving model to /content/saved_models/FER2013_model.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 124/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3999 - accuracy: 0.9065 - val_loss: 1.3998 - val_accuracy: 0.6984
#
# Epoch 00124: val_accuracy did not improve from 0.69953
# Epoch 125/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3974 - accuracy: 0.9080 - val_loss: 1.4091 - val_accuracy: 0.6963
#
# Epoch 00125: val_accuracy did not improve from 0.69953
# Epoch 126/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3955 - accuracy: 0.9057 - val_loss: 1.4336 - val_accuracy: 0.7006
#
# Epoch 00126: val_accuracy improved from 0.69953 to 0.70062, saving model to /content/saved_models/FER2013_model.h5
# Epoch 127/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3985 - accuracy: 0.9092 - val_loss: 1.4208 - val_accuracy: 0.6966
#
# Epoch 00127: val_accuracy did not improve from 0.70062
# Epoch 128/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4017 - accuracy: 0.9051 - val_loss: 1.4303 - val_accuracy: 0.6977
#
# Epoch 00128: val_accuracy did not improve from 0.70062
# Epoch 129/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3910 - accuracy: 0.9096 - val_loss: 1.4440 - val_accuracy: 0.6948
#
# Epoch 00129: val_accuracy did not improve from 0.70062
# Epoch 130/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3974 - accuracy: 0.9061 - val_loss: 1.4275 - val_accuracy: 0.6995
#
# Epoch 00130: val_accuracy did not improve from 0.70062
# Epoch 131/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3939 - accuracy: 0.9094 - val_loss: 1.4408 - val_accuracy: 0.6966
#
# Epoch 00131: val_accuracy did not improve from 0.70062
# Epoch 132/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 459ms/step - loss: 0.3879 - accuracy: 0.9117 - val_loss: 1.4242 - val_accuracy: 0.7013
#
# Epoch 00132: val_accuracy improved from 0.70062 to 0.70135, saving model to /content/saved_models/FER2013_model.h5
# Epoch 133/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3859 - accuracy: 0.9138 - val_loss: 1.4107 - val_accuracy: 0.6963
#
# Epoch 00133: val_accuracy did not improve from 0.70135
# Epoch 134/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.3840 - accuracy: 0.9128 - val_loss: 1.4274 - val_accuracy: 0.6959
#
# Epoch 00134: val_accuracy did not improve from 0.70135
# Epoch 135/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3868 - accuracy: 0.9122 - val_loss: 1.4434 - val_accuracy: 0.6981
#
# Epoch 00135: val_accuracy did not improve from 0.70135
# Epoch 136/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3838 - accuracy: 0.9135 - val_loss: 1.4514 - val_accuracy: 0.6886
#
# Epoch 00136: val_accuracy did not improve from 0.70135
# Epoch 137/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3794 - accuracy: 0.9144 - val_loss: 1.4586 - val_accuracy: 0.6973
#
# Epoch 00137: val_accuracy did not improve from 0.70135
# Epoch 138/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.3796 - accuracy: 0.9144 - val_loss: 1.4501 - val_accuracy: 0.6966
#
# Epoch 00138: val_accuracy did not improve from 0.70135
# Epoch 139/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 456ms/step - loss: 0.3790 - accuracy: 0.9136 - val_loss: 1.4678 - val_accuracy: 0.6915
#
# Epoch 00139: val_accuracy did not improve from 0.70135
# Epoch 140/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.3799 - accuracy: 0.9122 - val_loss: 1.4818 - val_accuracy: 0.6992
#
# Epoch 00140: val_accuracy did not improve from 0.70135
# Epoch 141/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3741 - accuracy: 0.9169 - val_loss: 1.4769 - val_accuracy: 0.6923
#
# Epoch 00141: val_accuracy did not improve from 0.70135
# Epoch 142/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3743 - accuracy: 0.9163 - val_loss: 1.4952 - val_accuracy: 0.6963
#
# Epoch 00142: val_accuracy did not improve from 0.70135
# Epoch 143/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3746 - accuracy: 0.9175 - val_loss: 1.4765 - val_accuracy: 0.6970
#
# Epoch 00143: val_accuracy did not improve from 0.70135
# Epoch 144/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.3703 - accuracy: 0.9166 - val_loss: 1.4741 - val_accuracy: 0.6984
#
# Epoch 00144: val_accuracy did not improve from 0.70135
# Epoch 145/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3748 - accuracy: 0.9159 - val_loss: 1.4930 - val_accuracy: 0.6959
#
# Epoch 00145: val_accuracy did not improve from 0.70135
# Epoch 146/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3708 - accuracy: 0.9181 - val_loss: 1.4933 - val_accuracy: 0.6970
#
# Epoch 00146: val_accuracy did not improve from 0.70135
# Epoch 147/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.3713 - accuracy: 0.9193 - val_loss: 1.4845 - val_accuracy: 0.6999
#
# Epoch 00147: val_accuracy did not improve from 0.70135
# Epoch 148/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3683 - accuracy: 0.9157 - val_loss: 1.4651 - val_accuracy: 0.6984
#
# Epoch 00148: val_accuracy did not improve from 0.70135
# Epoch 149/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3743 - accuracy: 0.9164 - val_loss: 1.4779 - val_accuracy: 0.6963
#
# Epoch 00149: val_accuracy did not improve from 0.70135
# Epoch 150/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.3678 - accuracy: 0.9179 - val_loss: 1.4907 - val_accuracy: 0.6981
#
# Epoch 00150: val_accuracy did not improve from 0.70135
# Epoch 151/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3691 - accuracy: 0.9194 - val_loss: 1.4780 - val_accuracy: 0.6966
#
# Epoch 00151: val_accuracy did not improve from 0.70135
# Epoch 152/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3687 - accuracy: 0.9162 - val_loss: 1.5170 - val_accuracy: 0.7017
#
# Epoch 00152: val_accuracy improved from 0.70135 to 0.70171, saving model to /content/saved_models/FER2013_model.h5
# Epoch 153/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3682 - accuracy: 0.9169 - val_loss: 1.4991 - val_accuracy: 0.7028
#
# Epoch 00153: val_accuracy improved from 0.70171 to 0.70280, saving model to /content/saved_models/FER2013_model.h5
# Epoch 154/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3621 - accuracy: 0.9196 - val_loss: 1.5016 - val_accuracy: 0.7013
#
# Epoch 00154: val_accuracy did not improve from 0.70280
# Epoch 155/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.3636 - accuracy: 0.9191 - val_loss: 1.5017 - val_accuracy: 0.6988
#
# Epoch 00155: val_accuracy did not improve from 0.70280
# Epoch 156/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3616 - accuracy: 0.9189 - val_loss: 1.5065 - val_accuracy: 0.6944
#
# Epoch 00156: val_accuracy did not improve from 0.70280
# Epoch 157/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.3624 - accuracy: 0.9202 - val_loss: 1.5090 - val_accuracy: 0.6963
#
# Epoch 00157: val_accuracy did not improve from 0.70280
# Epoch 158/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3658 - accuracy: 0.9179 - val_loss: 1.5112 - val_accuracy: 0.6915
#
# Epoch 00158: val_accuracy did not improve from 0.70280
# Epoch 159/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3580 - accuracy: 0.9232 - val_loss: 1.5106 - val_accuracy: 0.6988
#
# Epoch 00159: val_accuracy did not improve from 0.70280
# Epoch 160/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3612 - accuracy: 0.9198 - val_loss: 1.5068 - val_accuracy: 0.6959
#
# Epoch 00160: val_accuracy did not improve from 0.70280
# Epoch 161/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3635 - accuracy: 0.9203 - val_loss: 1.5020 - val_accuracy: 0.6984
#
# Epoch 00161: val_accuracy did not improve from 0.70280
# Epoch 162/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 450ms/step - loss: 0.3615 - accuracy: 0.9190 - val_loss: 1.5270 - val_accuracy: 0.6999
#
# Epoch 00162: val_accuracy did not improve from 0.70280
# Epoch 163/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3528 - accuracy: 0.9227 - val_loss: 1.5263 - val_accuracy: 0.6988
#
# Epoch 00163: val_accuracy did not improve from 0.70280
# Epoch 164/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3552 - accuracy: 0.9237 - val_loss: 1.5380 - val_accuracy: 0.6981
#
# Epoch 00164: val_accuracy did not improve from 0.70280
# Epoch 165/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3596 - accuracy: 0.9204 - val_loss: 1.5261 - val_accuracy: 0.6923
#
# Epoch 00165: val_accuracy did not improve from 0.70280
# Epoch 166/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.3545 - accuracy: 0.9228 - val_loss: 1.5307 - val_accuracy: 0.6872
#
# Epoch 00166: val_accuracy did not improve from 0.70280
# Epoch 167/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3594 - accuracy: 0.9214 - val_loss: 1.5241 - val_accuracy: 0.6955
#
# Epoch 00167: val_accuracy did not improve from 0.70280
# Epoch 168/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.3589 - accuracy: 0.9201 - val_loss: 1.5222 - val_accuracy: 0.6959
#
# Epoch 00168: val_accuracy did not improve from 0.70280
# Epoch 169/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3640 - accuracy: 0.9177 - val_loss: 1.5299 - val_accuracy: 0.6886
#
# Epoch 00169: val_accuracy did not improve from 0.70280
# Epoch 170/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.3550 - accuracy: 0.9214 - val_loss: 1.5048 - val_accuracy: 0.6901
#
# Epoch 00170: val_accuracy did not improve from 0.70280
# Epoch 171/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3589 - accuracy: 0.9219 - val_loss: 1.5218 - val_accuracy: 0.7013
#
# Epoch 00171: val_accuracy did not improve from 0.70280
# Epoch 172/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 451ms/step - loss: 0.3524 - accuracy: 0.9237 - val_loss: 1.5429 - val_accuracy: 0.6992
#
# Epoch 00172: val_accuracy did not improve from 0.70280
# Epoch 173/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3585 - accuracy: 0.9201 - val_loss: 1.5341 - val_accuracy: 0.6970
#
# Epoch 00173: val_accuracy did not improve from 0.70280
# Epoch 174/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3536 - accuracy: 0.9223 - val_loss: 1.5303 - val_accuracy: 0.6955
#
# Epoch 00174: val_accuracy did not improve from 0.70280
# Epoch 175/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3480 - accuracy: 0.9268 - val_loss: 1.5532 - val_accuracy: 0.6944
#
# Epoch 00175: val_accuracy did not improve from 0.70280
# Epoch 176/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.3534 - accuracy: 0.9218 - val_loss: 1.5637 - val_accuracy: 0.6988
#
# Epoch 00176: val_accuracy did not improve from 0.70280
# Epoch 177/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.3491 - accuracy: 0.9245 - val_loss: 1.5447 - val_accuracy: 0.6937
#
# Epoch 00177: val_accuracy did not improve from 0.70280
# Epoch 178/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3518 - accuracy: 0.9212 - val_loss: 1.5406 - val_accuracy: 0.6915
#
# Epoch 00178: val_accuracy did not improve from 0.70280
# Epoch 179/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 457ms/step - loss: 0.3433 - accuracy: 0.9267 - val_loss: 1.5361 - val_accuracy: 0.7006
#
# Epoch 00179: val_accuracy did not improve from 0.70280
# Epoch 180/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3477 - accuracy: 0.9247 - val_loss: 1.5514 - val_accuracy: 0.6970
#
# Epoch 00180: val_accuracy did not improve from 0.70280
# Epoch 181/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3574 - accuracy: 0.9206 - val_loss: 1.5455 - val_accuracy: 0.6948
#
# Epoch 00181: val_accuracy did not improve from 0.70280
# Epoch 182/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 452ms/step - loss: 0.3505 - accuracy: 0.9234 - val_loss: 1.5372 - val_accuracy: 0.6966
#
# Epoch 00182: val_accuracy did not improve from 0.70280
# Epoch 183/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 454ms/step - loss: 0.3442 - accuracy: 0.9248 - val_loss: 1.5356 - val_accuracy: 0.6981
#
# Epoch 00183: val_accuracy did not improve from 0.70280
# Epoch 184/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3497 - accuracy: 0.9241 - val_loss: 1.5345 - val_accuracy: 0.6952
#
# Epoch 00184: val_accuracy did not improve from 0.70280
# Epoch 185/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 453ms/step - loss: 0.3521 - accuracy: 0.9211 - val_loss: 1.5211 - val_accuracy: 0.6948
#
# Epoch 00185: val_accuracy did not improve from 0.70280
# Epoch 186/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3465 - accuracy: 0.9263 - val_loss: 1.5272 - val_accuracy: 0.6930
#
# Epoch 00186: val_accuracy did not improve from 0.70280
# Epoch 187/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 460ms/step - loss: 0.3475 - accuracy: 0.9269 - val_loss: 1.5776 - val_accuracy: 0.7039
#
# Epoch 00187: val_accuracy improved from 0.70280 to 0.70389, saving model to /content/saved_models/FER2013_model.h5
# Epoch 188/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 458ms/step - loss: 0.3428 - accuracy: 0.9259 - val_loss: 1.5682 - val_accuracy: 0.6952
#
# Epoch 00188: val_accuracy did not improve from 0.70389
# Epoch 189/200
# Learning rate:  0.0001
# 44/44 [==============================] - 20s 455ms/step - loss: 0.3498 - accuracy: 0.9235 - val_loss: 1.5886 - val_accuracy: 0.6970
#
# Epoch 00189: val_accuracy did not improve from 0.70389
# Epoch 190/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 455ms/step - loss: 0.3493 - accuracy: 0.9241 - val_loss: 1.5485 - val_accuracy: 0.6944
#
# Epoch 00190: val_accuracy did not improve from 0.70389
# Epoch 191/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 456ms/step - loss: 0.3467 - accuracy: 0.9226 - val_loss: 1.5449 - val_accuracy: 0.6952
#
# Epoch 00191: val_accuracy did not improve from 0.70389
# Epoch 192/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 454ms/step - loss: 0.3434 - accuracy: 0.9254 - val_loss: 1.5546 - val_accuracy: 0.6992
#
# Epoch 00192: val_accuracy did not improve from 0.70389
# Epoch 193/200
# Learning rate:  0.0001
# 25/44 [================>.............] - ETA: 7s - loss: 0.3463 - accuracy: 0.9258
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-195849e54eb0> in <module>()
#       3                 validation_data=(x_val, y_val),
#       4                 epochs=epochs, verbose=1, workers=4,
# ----> 5                 callbacks=callbacks)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
best_model = keras.models.load_model('/content/saved_models/FER2013_model.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 87/87 [==============================] - 4s 22ms/step - loss: 1.4461 - accuracy: 0.7165
# [1.4461058378219604, 0.7165154218673706]

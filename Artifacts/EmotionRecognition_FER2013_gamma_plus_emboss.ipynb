# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_val.csv",header=None)
  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 21 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=a89bc60cf15f8c7a94178351f427ed03bd4935b5402b9518b6a96206ea00d9a8
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*100)/math.log(mean)
  img = np.power(img, gamma).clip(0,100).astype(np.uint8)

  img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((22279, 48, 48, 1), (2755, 48, 48, 1), (2749, 48, 48, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import callbacks as cb

# Training parameter
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
dataset_type = 'FER2013'


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = dataset_type + '_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.8):
      lr = 0.0001
    elif epoch >= (epochs*0.3):
      lr=0.001
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    datagen.fit(x_train)
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.01
# 44/44 [==============================] - 30s 493ms/step - loss: 1.9864 - accuracy: 0.2636 - val_loss: 1.9461 - val_accuracy: 0.2666
#
# Epoch 00001: val_accuracy improved from -inf to 0.26664, saving model to /content/saved_models/FER2013_model.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 443ms/step - loss: 1.8817 - accuracy: 0.2707 - val_loss: 1.9403 - val_accuracy: 0.1382
#
# Epoch 00002: val_accuracy did not improve from 0.26664
# Epoch 3/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 452ms/step - loss: 1.7862 - accuracy: 0.3060 - val_loss: 2.4127 - val_accuracy: 0.1542
#
# Epoch 00003: val_accuracy did not improve from 0.26664
# Epoch 4/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 1.6307 - accuracy: 0.3982 - val_loss: 2.1092 - val_accuracy: 0.1237
#
# Epoch 00004: val_accuracy did not improve from 0.26664
# Epoch 5/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 454ms/step - loss: 1.5245 - accuracy: 0.4518 - val_loss: 2.0447 - val_accuracy: 0.2666
#
# Epoch 00005: val_accuracy did not improve from 0.26664
# Epoch 6/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 455ms/step - loss: 1.4386 - accuracy: 0.4947 - val_loss: 2.9885 - val_accuracy: 0.1302
#
# Epoch 00006: val_accuracy did not improve from 0.26664
# Epoch 7/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 456ms/step - loss: 1.3672 - accuracy: 0.5172 - val_loss: 3.0342 - val_accuracy: 0.1266
#
# Epoch 00007: val_accuracy did not improve from 0.26664
# Epoch 8/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 458ms/step - loss: 1.3361 - accuracy: 0.5301 - val_loss: 3.0358 - val_accuracy: 0.2666
#
# Epoch 00008: val_accuracy did not improve from 0.26664
# Epoch 9/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.3205 - accuracy: 0.5380 - val_loss: 2.3766 - val_accuracy: 0.2837
#
# Epoch 00009: val_accuracy improved from 0.26664 to 0.28374, saving model to /content/saved_models/FER2013_model.h5
# Epoch 10/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.3067 - accuracy: 0.5441 - val_loss: 2.1269 - val_accuracy: 0.1830
#
# Epoch 00010: val_accuracy did not improve from 0.28374
# Epoch 11/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.2898 - accuracy: 0.5506 - val_loss: 1.7389 - val_accuracy: 0.3841
#
# Epoch 00011: val_accuracy improved from 0.28374 to 0.38414, saving model to /content/saved_models/FER2013_model.h5
# Epoch 12/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2548 - accuracy: 0.5669 - val_loss: 2.2371 - val_accuracy: 0.1390
#
# Epoch 00012: val_accuracy did not improve from 0.38414
# Epoch 13/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2617 - accuracy: 0.5644 - val_loss: 2.1477 - val_accuracy: 0.1364
#
# Epoch 00013: val_accuracy did not improve from 0.38414
# Epoch 14/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2363 - accuracy: 0.5782 - val_loss: 2.1079 - val_accuracy: 0.1488
#
# Epoch 00014: val_accuracy did not improve from 0.38414
# Epoch 15/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2278 - accuracy: 0.5784 - val_loss: 1.9849 - val_accuracy: 0.2397
#
# Epoch 00015: val_accuracy did not improve from 0.38414
# Epoch 16/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.2293 - accuracy: 0.5833 - val_loss: 2.0404 - val_accuracy: 0.3132
#
# Epoch 00016: val_accuracy did not improve from 0.38414
# Epoch 17/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2136 - accuracy: 0.5889 - val_loss: 1.7786 - val_accuracy: 0.3685
#
# Epoch 00017: val_accuracy did not improve from 0.38414
# Epoch 18/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.2049 - accuracy: 0.5937 - val_loss: 3.1234 - val_accuracy: 0.1481
#
# Epoch 00018: val_accuracy did not improve from 0.38414
# Epoch 19/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 474ms/step - loss: 1.2038 - accuracy: 0.5967 - val_loss: 2.3314 - val_accuracy: 0.1641
#
# Epoch 00019: val_accuracy did not improve from 0.38414
# Epoch 20/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1816 - accuracy: 0.5995 - val_loss: 2.4982 - val_accuracy: 0.2634
#
# Epoch 00020: val_accuracy did not improve from 0.38414
# Epoch 21/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1889 - accuracy: 0.5960 - val_loss: 2.2893 - val_accuracy: 0.2663
#
# Epoch 00021: val_accuracy did not improve from 0.38414
# Epoch 22/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.1791 - accuracy: 0.6049 - val_loss: 1.9828 - val_accuracy: 0.2441
#
# Epoch 00022: val_accuracy did not improve from 0.38414
# Epoch 23/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1711 - accuracy: 0.6086 - val_loss: 2.5194 - val_accuracy: 0.2106
#
# Epoch 00023: val_accuracy did not improve from 0.38414
# Epoch 24/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1652 - accuracy: 0.6108 - val_loss: 2.5911 - val_accuracy: 0.1688
#
# Epoch 00024: val_accuracy did not improve from 0.38414
# Epoch 25/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 475ms/step - loss: 1.1581 - accuracy: 0.6122 - val_loss: 2.2196 - val_accuracy: 0.1604
#
# Epoch 00025: val_accuracy did not improve from 0.38414
# Epoch 26/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1656 - accuracy: 0.6108 - val_loss: 2.1405 - val_accuracy: 0.3001
#
# Epoch 00026: val_accuracy did not improve from 0.38414
# Epoch 27/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1657 - accuracy: 0.6121 - val_loss: 3.6717 - val_accuracy: 0.2666
#
# Epoch 00027: val_accuracy did not improve from 0.38414
# Epoch 28/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1547 - accuracy: 0.6152 - val_loss: 3.1770 - val_accuracy: 0.1608
#
# Epoch 00028: val_accuracy did not improve from 0.38414
# Epoch 29/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1497 - accuracy: 0.6155 - val_loss: 2.3556 - val_accuracy: 0.1673
#
# Epoch 00029: val_accuracy did not improve from 0.38414
# Epoch 30/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1475 - accuracy: 0.6204 - val_loss: 3.3425 - val_accuracy: 0.1331
#
# Epoch 00030: val_accuracy did not improve from 0.38414
# Epoch 31/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 476ms/step - loss: 1.1432 - accuracy: 0.6247 - val_loss: 2.4447 - val_accuracy: 0.1324
#
# Epoch 00031: val_accuracy did not improve from 0.38414
# Epoch 32/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.1326 - accuracy: 0.6248 - val_loss: 5.4273 - val_accuracy: 0.0397
#
# Epoch 00032: val_accuracy did not improve from 0.38414
# Epoch 33/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.1293 - accuracy: 0.6252 - val_loss: 2.5524 - val_accuracy: 0.1335
#
# Epoch 00033: val_accuracy did not improve from 0.38414
# Epoch 34/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1327 - accuracy: 0.6230 - val_loss: 2.3929 - val_accuracy: 0.1350
#
# Epoch 00034: val_accuracy did not improve from 0.38414
# Epoch 35/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1248 - accuracy: 0.6256 - val_loss: 2.5874 - val_accuracy: 0.1437
#
# Epoch 00035: val_accuracy did not improve from 0.38414
# Epoch 36/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 475ms/step - loss: 1.1303 - accuracy: 0.6235 - val_loss: 2.2515 - val_accuracy: 0.1546
#
# Epoch 00036: val_accuracy did not improve from 0.38414
# Epoch 37/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.1234 - accuracy: 0.6283 - val_loss: 2.1390 - val_accuracy: 0.1713
#
# Epoch 00037: val_accuracy did not improve from 0.38414
# Epoch 38/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1222 - accuracy: 0.6317 - val_loss: 6.9373 - val_accuracy: 0.1393
#
# Epoch 00038: val_accuracy did not improve from 0.38414
# Epoch 39/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1184 - accuracy: 0.6296 - val_loss: 1.9975 - val_accuracy: 0.2761
#
# Epoch 00039: val_accuracy did not improve from 0.38414
# Epoch 40/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.1181 - accuracy: 0.6312 - val_loss: 2.1953 - val_accuracy: 0.1735
#
# Epoch 00040: val_accuracy did not improve from 0.38414
# Epoch 41/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.1147 - accuracy: 0.6354 - val_loss: 2.7013 - val_accuracy: 0.1597
#
# Epoch 00041: val_accuracy did not improve from 0.38414
# Epoch 42/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.1096 - accuracy: 0.6372 - val_loss: 2.3988 - val_accuracy: 0.1815
#
# Epoch 00042: val_accuracy did not improve from 0.38414
# Epoch 43/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1056 - accuracy: 0.6371 - val_loss: 3.5007 - val_accuracy: 0.1033
#
# Epoch 00043: val_accuracy did not improve from 0.38414
# Epoch 44/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1143 - accuracy: 0.6355 - val_loss: 2.1360 - val_accuracy: 0.1804
#
# Epoch 00044: val_accuracy did not improve from 0.38414
# Epoch 45/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1077 - accuracy: 0.6355 - val_loss: 1.7871 - val_accuracy: 0.3961
#
# Epoch 00045: val_accuracy improved from 0.38414 to 0.39614, saving model to /content/saved_models/FER2013_model.h5
# Epoch 46/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0997 - accuracy: 0.6389 - val_loss: 1.7008 - val_accuracy: 0.4165
#
# Epoch 00046: val_accuracy improved from 0.39614 to 0.41652, saving model to /content/saved_models/FER2013_model.h5
# Epoch 47/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.1069 - accuracy: 0.6378 - val_loss: 1.8020 - val_accuracy: 0.3510
#
# Epoch 00047: val_accuracy did not improve from 0.41652
# Epoch 48/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.1059 - accuracy: 0.6378 - val_loss: 2.5091 - val_accuracy: 0.1324
#
# Epoch 00048: val_accuracy did not improve from 0.41652
# Epoch 49/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0937 - accuracy: 0.6400 - val_loss: 5.0242 - val_accuracy: 0.1251
#
# Epoch 00049: val_accuracy did not improve from 0.41652
# Epoch 50/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0940 - accuracy: 0.6418 - val_loss: 2.2517 - val_accuracy: 0.1728
#
# Epoch 00050: val_accuracy did not improve from 0.41652
# Epoch 51/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0902 - accuracy: 0.6437 - val_loss: 1.4227 - val_accuracy: 0.5380
#
# Epoch 00051: val_accuracy improved from 0.41652 to 0.53801, saving model to /content/saved_models/FER2013_model.h5
# Epoch 52/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0912 - accuracy: 0.6447 - val_loss: 2.2115 - val_accuracy: 0.1892
#
# Epoch 00052: val_accuracy did not improve from 0.53801
# Epoch 53/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0982 - accuracy: 0.6372 - val_loss: 1.5722 - val_accuracy: 0.4347
#
# Epoch 00053: val_accuracy did not improve from 0.53801
# Epoch 54/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0970 - accuracy: 0.6440 - val_loss: 2.0758 - val_accuracy: 0.1495
#
# Epoch 00054: val_accuracy did not improve from 0.53801
# Epoch 55/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 475ms/step - loss: 1.0956 - accuracy: 0.6437 - val_loss: 2.2716 - val_accuracy: 0.2856
#
# Epoch 00055: val_accuracy did not improve from 0.53801
# Epoch 56/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 474ms/step - loss: 1.0898 - accuracy: 0.6459 - val_loss: 1.9074 - val_accuracy: 0.3601
#
# Epoch 00056: val_accuracy did not improve from 0.53801
# Epoch 57/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0821 - accuracy: 0.6451 - val_loss: 3.3344 - val_accuracy: 0.1397
#
# Epoch 00057: val_accuracy did not improve from 0.53801
# Epoch 58/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 476ms/step - loss: 1.0875 - accuracy: 0.6446 - val_loss: 1.9016 - val_accuracy: 0.3154
#
# Epoch 00058: val_accuracy did not improve from 0.53801
# Epoch 59/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0883 - accuracy: 0.6439 - val_loss: 2.3220 - val_accuracy: 0.4332
#
# Epoch 00059: val_accuracy did not improve from 0.53801
# Epoch 60/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0783 - accuracy: 0.6494 - val_loss: 2.2719 - val_accuracy: 0.2084
#
# Epoch 00060: val_accuracy did not improve from 0.53801
# Epoch 61/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 476ms/step - loss: 1.0149 - accuracy: 0.6776 - val_loss: 1.7903 - val_accuracy: 0.3579
#
# Epoch 00061: val_accuracy did not improve from 0.53801
# Epoch 62/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.9821 - accuracy: 0.6846 - val_loss: 1.8117 - val_accuracy: 0.3638
#
# Epoch 00062: val_accuracy did not improve from 0.53801
# Epoch 63/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.9659 - accuracy: 0.6892 - val_loss: 1.4334 - val_accuracy: 0.5096
#
# Epoch 00063: val_accuracy did not improve from 0.53801
# Epoch 64/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.9519 - accuracy: 0.6928 - val_loss: 1.4570 - val_accuracy: 0.4965
#
# Epoch 00064: val_accuracy did not improve from 0.53801
# Epoch 65/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.9467 - accuracy: 0.6942 - val_loss: 1.1724 - val_accuracy: 0.6115
#
# Epoch 00065: val_accuracy improved from 0.53801 to 0.61150, saving model to /content/saved_models/FER2013_model.h5
# Epoch 66/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.9326 - accuracy: 0.7026 - val_loss: 1.1089 - val_accuracy: 0.6257
#
# Epoch 00066: val_accuracy improved from 0.61150 to 0.62568, saving model to /content/saved_models/FER2013_model.h5
# Epoch 67/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.9249 - accuracy: 0.7051 - val_loss: 1.1982 - val_accuracy: 0.6006
#
# Epoch 00067: val_accuracy did not improve from 0.62568
# Epoch 68/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.9175 - accuracy: 0.7043 - val_loss: 1.1323 - val_accuracy: 0.6322
#
# Epoch 00068: val_accuracy improved from 0.62568 to 0.63223, saving model to /content/saved_models/FER2013_model.h5
# Epoch 69/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.9108 - accuracy: 0.7075 - val_loss: 1.1198 - val_accuracy: 0.6304
#
# Epoch 00069: val_accuracy did not improve from 0.63223
# Epoch 70/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.9046 - accuracy: 0.7085 - val_loss: 1.1397 - val_accuracy: 0.6155
#
# Epoch 00070: val_accuracy did not improve from 0.63223
# Epoch 71/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.9015 - accuracy: 0.7088 - val_loss: 1.2133 - val_accuracy: 0.6035
#
# Epoch 00071: val_accuracy did not improve from 0.63223
# Epoch 72/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.8958 - accuracy: 0.7110 - val_loss: 1.0979 - val_accuracy: 0.6413
#
# Epoch 00072: val_accuracy improved from 0.63223 to 0.64132, saving model to /content/saved_models/FER2013_model.h5
# Epoch 73/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8892 - accuracy: 0.7135 - val_loss: 1.1044 - val_accuracy: 0.6275
#
# Epoch 00073: val_accuracy did not improve from 0.64132
# Epoch 74/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8817 - accuracy: 0.7161 - val_loss: 1.1122 - val_accuracy: 0.6431
#
# Epoch 00074: val_accuracy improved from 0.64132 to 0.64314, saving model to /content/saved_models/FER2013_model.h5
# Epoch 75/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 484ms/step - loss: 0.8738 - accuracy: 0.7212 - val_loss: 1.1019 - val_accuracy: 0.6322
#
# Epoch 00075: val_accuracy did not improve from 0.64314
# Epoch 76/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.8719 - accuracy: 0.7169 - val_loss: 1.2374 - val_accuracy: 0.5915
#
# Epoch 00076: val_accuracy did not improve from 0.64314
# Epoch 77/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8682 - accuracy: 0.7227 - val_loss: 1.2354 - val_accuracy: 0.5969
#
# Epoch 00077: val_accuracy did not improve from 0.64314
# Epoch 78/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.8672 - accuracy: 0.7203 - val_loss: 1.1440 - val_accuracy: 0.6268
#
# Epoch 00078: val_accuracy did not improve from 0.64314
# Epoch 79/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.8558 - accuracy: 0.7247 - val_loss: 1.2898 - val_accuracy: 0.5988
#
# Epoch 00079: val_accuracy did not improve from 0.64314
# Epoch 80/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8507 - accuracy: 0.7261 - val_loss: 1.0979 - val_accuracy: 0.6315
#
# Epoch 00080: val_accuracy did not improve from 0.64314
# Epoch 81/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.8504 - accuracy: 0.7267 - val_loss: 1.1423 - val_accuracy: 0.6344
#
# Epoch 00081: val_accuracy did not improve from 0.64314
# Epoch 82/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8448 - accuracy: 0.7264 - val_loss: 1.5195 - val_accuracy: 0.5278
#
# Epoch 00082: val_accuracy did not improve from 0.64314
# Epoch 83/200
# Learning rate:  0.001
# 44/44 [==============================] - 22s 479ms/step - loss: 0.8411 - accuracy: 0.7294 - val_loss: 1.3916 - val_accuracy: 0.5635
#
# Epoch 00083: val_accuracy did not improve from 0.64314
# Epoch 84/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.8342 - accuracy: 0.7341 - val_loss: 1.3082 - val_accuracy: 0.5613
#
# Epoch 00084: val_accuracy did not improve from 0.64314
# Epoch 85/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.8284 - accuracy: 0.7333 - val_loss: 1.3554 - val_accuracy: 0.5769
#
# Epoch 00085: val_accuracy did not improve from 0.64314
# Epoch 86/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8283 - accuracy: 0.7352 - val_loss: 1.2813 - val_accuracy: 0.5813
#
# Epoch 00086: val_accuracy did not improve from 0.64314
# Epoch 87/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 476ms/step - loss: 0.8263 - accuracy: 0.7351 - val_loss: 1.4422 - val_accuracy: 0.5242
#
# Epoch 00087: val_accuracy did not improve from 0.64314
# Epoch 88/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.8185 - accuracy: 0.7345 - val_loss: 1.4027 - val_accuracy: 0.5562
#
# Epoch 00088: val_accuracy did not improve from 0.64314
# Epoch 89/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.8146 - accuracy: 0.7402 - val_loss: 1.2313 - val_accuracy: 0.6017
#
# Epoch 00089: val_accuracy did not improve from 0.64314
# Epoch 90/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.8123 - accuracy: 0.7412 - val_loss: 1.1518 - val_accuracy: 0.6082
#
# Epoch 00090: val_accuracy did not improve from 0.64314
# Epoch 91/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.8070 - accuracy: 0.7402 - val_loss: 1.3350 - val_accuracy: 0.5624
#
# Epoch 00091: val_accuracy did not improve from 0.64314
# Epoch 92/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.8035 - accuracy: 0.7407 - val_loss: 1.2725 - val_accuracy: 0.5537
#
# Epoch 00092: val_accuracy did not improve from 0.64314
# Epoch 93/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7982 - accuracy: 0.7434 - val_loss: 1.2528 - val_accuracy: 0.5948
#
# Epoch 00093: val_accuracy did not improve from 0.64314
# Epoch 94/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7961 - accuracy: 0.7452 - val_loss: 1.2042 - val_accuracy: 0.6126
#
# Epoch 00094: val_accuracy did not improve from 0.64314
# Epoch 95/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7862 - accuracy: 0.7468 - val_loss: 2.6975 - val_accuracy: 0.3696
#
# Epoch 00095: val_accuracy did not improve from 0.64314
# Epoch 96/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7936 - accuracy: 0.7450 - val_loss: 1.5812 - val_accuracy: 0.4965
#
# Epoch 00096: val_accuracy did not improve from 0.64314
# Epoch 97/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7869 - accuracy: 0.7449 - val_loss: 1.2170 - val_accuracy: 0.6075
#
# Epoch 00097: val_accuracy did not improve from 0.64314
# Epoch 98/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7871 - accuracy: 0.7450 - val_loss: 1.2160 - val_accuracy: 0.6042
#
# Epoch 00098: val_accuracy did not improve from 0.64314
# Epoch 99/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7818 - accuracy: 0.7498 - val_loss: 1.1123 - val_accuracy: 0.6351
#
# Epoch 00099: val_accuracy did not improve from 0.64314
# Epoch 100/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7847 - accuracy: 0.7460 - val_loss: 1.2025 - val_accuracy: 0.6162
#
# Epoch 00100: val_accuracy did not improve from 0.64314
# Epoch 101/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7732 - accuracy: 0.7528 - val_loss: 1.2096 - val_accuracy: 0.5995
#
# Epoch 00101: val_accuracy did not improve from 0.64314
# Epoch 102/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7706 - accuracy: 0.7529 - val_loss: 1.2073 - val_accuracy: 0.6213
#
# Epoch 00102: val_accuracy did not improve from 0.64314
# Epoch 103/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.7650 - accuracy: 0.7546 - val_loss: 1.1259 - val_accuracy: 0.6497
#
# Epoch 00103: val_accuracy improved from 0.64314 to 0.64969, saving model to /content/saved_models/FER2013_model.h5
# Epoch 104/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7611 - accuracy: 0.7561 - val_loss: 1.2526 - val_accuracy: 0.6170
#
# Epoch 00104: val_accuracy did not improve from 0.64969
# Epoch 105/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7655 - accuracy: 0.7546 - val_loss: 1.3233 - val_accuracy: 0.5529
#
# Epoch 00105: val_accuracy did not improve from 0.64969
# Epoch 106/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.7597 - accuracy: 0.7570 - val_loss: 1.2327 - val_accuracy: 0.6006
#
# Epoch 00106: val_accuracy did not improve from 0.64969
# Epoch 107/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.7586 - accuracy: 0.7596 - val_loss: 1.1331 - val_accuracy: 0.6431
#
# Epoch 00107: val_accuracy did not improve from 0.64969
# Epoch 108/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7529 - accuracy: 0.7585 - val_loss: 1.1732 - val_accuracy: 0.6406
#
# Epoch 00108: val_accuracy did not improve from 0.64969
# Epoch 109/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7520 - accuracy: 0.7603 - val_loss: 1.4688 - val_accuracy: 0.5631
#
# Epoch 00109: val_accuracy did not improve from 0.64969
# Epoch 110/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7509 - accuracy: 0.7585 - val_loss: 1.2153 - val_accuracy: 0.6213
#
# Epoch 00110: val_accuracy did not improve from 0.64969
# Epoch 111/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7414 - accuracy: 0.7632 - val_loss: 1.1332 - val_accuracy: 0.6370
#
# Epoch 00111: val_accuracy did not improve from 0.64969
# Epoch 112/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7380 - accuracy: 0.7683 - val_loss: 1.4725 - val_accuracy: 0.5853
#
# Epoch 00112: val_accuracy did not improve from 0.64969
# Epoch 113/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7392 - accuracy: 0.7654 - val_loss: 1.2199 - val_accuracy: 0.6282
#
# Epoch 00113: val_accuracy did not improve from 0.64969
# Epoch 114/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7313 - accuracy: 0.7678 - val_loss: 1.2056 - val_accuracy: 0.6362
#
# Epoch 00114: val_accuracy did not improve from 0.64969
# Epoch 115/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7260 - accuracy: 0.7696 - val_loss: 1.3461 - val_accuracy: 0.6009
#
# Epoch 00115: val_accuracy did not improve from 0.64969
# Epoch 116/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7304 - accuracy: 0.7672 - val_loss: 1.1693 - val_accuracy: 0.6268
#
# Epoch 00116: val_accuracy did not improve from 0.64969
# Epoch 117/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7206 - accuracy: 0.7715 - val_loss: 1.5015 - val_accuracy: 0.5246
#
# Epoch 00117: val_accuracy did not improve from 0.64969
# Epoch 118/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.7221 - accuracy: 0.7708 - val_loss: 1.3577 - val_accuracy: 0.5857
#
# Epoch 00118: val_accuracy did not improve from 0.64969
# Epoch 119/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7195 - accuracy: 0.7707 - val_loss: 1.1455 - val_accuracy: 0.6333
#
# Epoch 00119: val_accuracy did not improve from 0.64969
# Epoch 120/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7212 - accuracy: 0.7718 - val_loss: 1.2926 - val_accuracy: 0.6119
#
# Epoch 00120: val_accuracy did not improve from 0.64969
# Epoch 121/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7180 - accuracy: 0.7731 - val_loss: 1.4251 - val_accuracy: 0.5740
#
# Epoch 00121: val_accuracy did not improve from 0.64969
# Epoch 122/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7102 - accuracy: 0.7752 - val_loss: 1.3401 - val_accuracy: 0.6097
#
# Epoch 00122: val_accuracy did not improve from 0.64969
# Epoch 123/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7142 - accuracy: 0.7723 - val_loss: 1.1916 - val_accuracy: 0.6384
#
# Epoch 00123: val_accuracy did not improve from 0.64969
# Epoch 124/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7077 - accuracy: 0.7756 - val_loss: 1.2265 - val_accuracy: 0.5959
#
# Epoch 00124: val_accuracy did not improve from 0.64969
# Epoch 125/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7083 - accuracy: 0.7761 - val_loss: 1.2116 - val_accuracy: 0.6293
#
# Epoch 00125: val_accuracy did not improve from 0.64969
# Epoch 126/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 475ms/step - loss: 0.7045 - accuracy: 0.7770 - val_loss: 1.5950 - val_accuracy: 0.4925
#
# Epoch 00126: val_accuracy did not improve from 0.64969
# Epoch 127/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6988 - accuracy: 0.7796 - val_loss: 1.5417 - val_accuracy: 0.5282
#
# Epoch 00127: val_accuracy did not improve from 0.64969
# Epoch 128/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 479ms/step - loss: 0.6974 - accuracy: 0.7815 - val_loss: 1.5601 - val_accuracy: 0.5369
#
# Epoch 00128: val_accuracy did not improve from 0.64969
# Epoch 129/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6957 - accuracy: 0.7818 - val_loss: 1.2138 - val_accuracy: 0.6413
#
# Epoch 00129: val_accuracy did not improve from 0.64969
# Epoch 130/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6926 - accuracy: 0.7807 - val_loss: 1.2966 - val_accuracy: 0.6017
#
# Epoch 00130: val_accuracy did not improve from 0.64969
# Epoch 131/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6878 - accuracy: 0.7822 - val_loss: 1.2554 - val_accuracy: 0.6126
#
# Epoch 00131: val_accuracy did not improve from 0.64969
# Epoch 132/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.6842 - accuracy: 0.7857 - val_loss: 1.2110 - val_accuracy: 0.6373
#
# Epoch 00132: val_accuracy did not improve from 0.64969
# Epoch 133/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6835 - accuracy: 0.7831 - val_loss: 1.4710 - val_accuracy: 0.5424
#
# Epoch 00133: val_accuracy did not improve from 0.64969
# Epoch 134/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6843 - accuracy: 0.7839 - val_loss: 1.5446 - val_accuracy: 0.5908
#
# Epoch 00134: val_accuracy did not improve from 0.64969
# Epoch 135/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6827 - accuracy: 0.7864 - val_loss: 1.5165 - val_accuracy: 0.5984
#
# Epoch 00135: val_accuracy did not improve from 0.64969
# Epoch 136/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6824 - accuracy: 0.7842 - val_loss: 1.4186 - val_accuracy: 0.5929
#
# Epoch 00136: val_accuracy did not improve from 0.64969
# Epoch 137/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 477ms/step - loss: 0.6781 - accuracy: 0.7856 - val_loss: 1.4538 - val_accuracy: 0.5555
#
# Epoch 00137: val_accuracy did not improve from 0.64969
# Epoch 138/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6735 - accuracy: 0.7874 - val_loss: 1.4902 - val_accuracy: 0.5377
#
# Epoch 00138: val_accuracy did not improve from 0.64969
# Epoch 139/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.6707 - accuracy: 0.7917 - val_loss: 1.2795 - val_accuracy: 0.6159
#
# Epoch 00139: val_accuracy did not improve from 0.64969
# Epoch 140/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6628 - accuracy: 0.7955 - val_loss: 1.4461 - val_accuracy: 0.5900
#
# Epoch 00140: val_accuracy did not improve from 0.64969
# Epoch 141/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6652 - accuracy: 0.7931 - val_loss: 1.3309 - val_accuracy: 0.5973
#
# Epoch 00141: val_accuracy did not improve from 0.64969
# Epoch 142/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6675 - accuracy: 0.7886 - val_loss: 1.2889 - val_accuracy: 0.6100
#
# Epoch 00142: val_accuracy did not improve from 0.64969
# Epoch 143/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6654 - accuracy: 0.7929 - val_loss: 1.7108 - val_accuracy: 0.5446
#
# Epoch 00143: val_accuracy did not improve from 0.64969
# Epoch 144/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6677 - accuracy: 0.7917 - val_loss: 1.6633 - val_accuracy: 0.5133
#
# Epoch 00144: val_accuracy did not improve from 0.64969
# Epoch 145/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.6549 - accuracy: 0.7944 - val_loss: 1.5430 - val_accuracy: 0.5457
#
# Epoch 00145: val_accuracy did not improve from 0.64969
# Epoch 146/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6565 - accuracy: 0.7959 - val_loss: 1.9184 - val_accuracy: 0.4864
#
# Epoch 00146: val_accuracy did not improve from 0.64969
# Epoch 147/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6527 - accuracy: 0.7938 - val_loss: 1.2881 - val_accuracy: 0.6173
#
# Epoch 00147: val_accuracy did not improve from 0.64969
# Epoch 148/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.6518 - accuracy: 0.7964 - val_loss: 1.2889 - val_accuracy: 0.6060
#
# Epoch 00148: val_accuracy did not improve from 0.64969
# Epoch 149/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 475ms/step - loss: 0.6486 - accuracy: 0.7950 - val_loss: 1.3503 - val_accuracy: 0.5911
#
# Epoch 00149: val_accuracy did not improve from 0.64969
# Epoch 150/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6495 - accuracy: 0.7990 - val_loss: 1.1997 - val_accuracy: 0.6399
#
# Epoch 00150: val_accuracy did not improve from 0.64969
# Epoch 151/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6451 - accuracy: 0.7978 - val_loss: 1.4689 - val_accuracy: 0.5678
#
# Epoch 00151: val_accuracy did not improve from 0.64969
# Epoch 152/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.6480 - accuracy: 0.8002 - val_loss: 1.3452 - val_accuracy: 0.6111
#
# Epoch 00152: val_accuracy did not improve from 0.64969
# Epoch 153/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6383 - accuracy: 0.8016 - val_loss: 1.3857 - val_accuracy: 0.5780
#
# Epoch 00153: val_accuracy did not improve from 0.64969
# Epoch 154/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6406 - accuracy: 0.8004 - val_loss: 1.4232 - val_accuracy: 0.5973
#
# Epoch 00154: val_accuracy did not improve from 0.64969
# Epoch 155/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6406 - accuracy: 0.7986 - val_loss: 1.3504 - val_accuracy: 0.6104
#
# Epoch 00155: val_accuracy did not improve from 0.64969
# Epoch 156/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6330 - accuracy: 0.8037 - val_loss: 1.3086 - val_accuracy: 0.6264
#
# Epoch 00156: val_accuracy did not improve from 0.64969
# Epoch 157/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6282 - accuracy: 0.8061 - val_loss: 1.6241 - val_accuracy: 0.5857
#
# Epoch 00157: val_accuracy did not improve from 0.64969
# Epoch 158/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.6405 - accuracy: 0.7985 - val_loss: 1.3549 - val_accuracy: 0.6224
#
# Epoch 00158: val_accuracy did not improve from 0.64969
# Epoch 159/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6403 - accuracy: 0.8017 - val_loss: 1.2949 - val_accuracy: 0.6170
#
# Epoch 00159: val_accuracy did not improve from 0.64969
# Epoch 160/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.6313 - accuracy: 0.8035 - val_loss: 1.3524 - val_accuracy: 0.6322
#
# Epoch 00160: val_accuracy did not improve from 0.64969
# Epoch 161/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6022 - accuracy: 0.8179 - val_loss: 1.2514 - val_accuracy: 0.6562
#
# Epoch 00161: val_accuracy improved from 0.64969 to 0.65624, saving model to /content/saved_models/FER2013_model.h5
# Epoch 162/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5864 - accuracy: 0.8227 - val_loss: 1.1679 - val_accuracy: 0.6715
#
# Epoch 00162: val_accuracy improved from 0.65624 to 0.67152, saving model to /content/saved_models/FER2013_model.h5
# Epoch 163/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.5761 - accuracy: 0.8283 - val_loss: 1.1807 - val_accuracy: 0.6682
#
# Epoch 00163: val_accuracy did not improve from 0.67152
# Epoch 164/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 476ms/step - loss: 0.5782 - accuracy: 0.8269 - val_loss: 1.1693 - val_accuracy: 0.6748
#
# Epoch 00164: val_accuracy improved from 0.67152 to 0.67479, saving model to /content/saved_models/FER2013_model.h5
# Epoch 165/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5728 - accuracy: 0.8271 - val_loss: 1.1818 - val_accuracy: 0.6693
#
# Epoch 00165: val_accuracy did not improve from 0.67479
# Epoch 166/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5660 - accuracy: 0.8307 - val_loss: 1.1639 - val_accuracy: 0.6755
#
# Epoch 00166: val_accuracy improved from 0.67479 to 0.67552, saving model to /content/saved_models/FER2013_model.h5
# Epoch 167/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5668 - accuracy: 0.8302 - val_loss: 1.1760 - val_accuracy: 0.6708
#
# Epoch 00167: val_accuracy did not improve from 0.67552
# Epoch 168/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5663 - accuracy: 0.8321 - val_loss: 1.1843 - val_accuracy: 0.6675
#
# Epoch 00168: val_accuracy did not improve from 0.67552
# Epoch 169/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.5661 - accuracy: 0.8301 - val_loss: 1.1815 - val_accuracy: 0.6672
#
# Epoch 00169: val_accuracy did not improve from 0.67552
# Epoch 170/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5568 - accuracy: 0.8347 - val_loss: 1.1820 - val_accuracy: 0.6657
#
# Epoch 00170: val_accuracy did not improve from 0.67552
# Epoch 171/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.5648 - accuracy: 0.8284 - val_loss: 1.1806 - val_accuracy: 0.6719
#
# Epoch 00171: val_accuracy did not improve from 0.67552
# Epoch 172/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5591 - accuracy: 0.8342 - val_loss: 1.1942 - val_accuracy: 0.6632
#
# Epoch 00172: val_accuracy did not improve from 0.67552
# Epoch 173/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.5566 - accuracy: 0.8355 - val_loss: 1.1823 - val_accuracy: 0.6701
#
# Epoch 00173: val_accuracy did not improve from 0.67552
# Epoch 174/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5536 - accuracy: 0.8354 - val_loss: 1.1952 - val_accuracy: 0.6657
#
# Epoch 00174: val_accuracy did not improve from 0.67552
# Epoch 175/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 477ms/step - loss: 0.5592 - accuracy: 0.8316 - val_loss: 1.2056 - val_accuracy: 0.6722
#
# Epoch 00175: val_accuracy did not improve from 0.67552
# Epoch 176/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5575 - accuracy: 0.8359 - val_loss: 1.2015 - val_accuracy: 0.6635
#
# Epoch 00176: val_accuracy did not improve from 0.67552
# Epoch 177/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5532 - accuracy: 0.8327 - val_loss: 1.1977 - val_accuracy: 0.6628
#
# Epoch 00177: val_accuracy did not improve from 0.67552
# Epoch 178/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5574 - accuracy: 0.8315 - val_loss: 1.1814 - val_accuracy: 0.6752
#
# Epoch 00178: val_accuracy did not improve from 0.67552
# Epoch 179/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.5570 - accuracy: 0.8337 - val_loss: 1.1758 - val_accuracy: 0.6697
#
# Epoch 00179: val_accuracy did not improve from 0.67552
# Epoch 180/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5513 - accuracy: 0.8365 - val_loss: 1.2029 - val_accuracy: 0.6708
#
# Epoch 00180: val_accuracy did not improve from 0.67552
# Epoch 181/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.5476 - accuracy: 0.8360 - val_loss: 1.2075 - val_accuracy: 0.6653
#
# Epoch 00181: val_accuracy did not improve from 0.67552
# Epoch 182/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5495 - accuracy: 0.8356 - val_loss: 1.2119 - val_accuracy: 0.6639
#
# Epoch 00182: val_accuracy did not improve from 0.67552
# Epoch 183/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5510 - accuracy: 0.8348 - val_loss: 1.1995 - val_accuracy: 0.6690
#
# Epoch 00183: val_accuracy did not improve from 0.67552
# Epoch 184/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5467 - accuracy: 0.8383 - val_loss: 1.2021 - val_accuracy: 0.6635
#
# Epoch 00184: val_accuracy did not improve from 0.67552
# Epoch 185/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.5474 - accuracy: 0.8364 - val_loss: 1.1986 - val_accuracy: 0.6642
#
# Epoch 00185: val_accuracy did not improve from 0.67552
# Epoch 186/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5482 - accuracy: 0.8328 - val_loss: 1.2088 - val_accuracy: 0.6722
#
# Epoch 00186: val_accuracy did not improve from 0.67552
# Epoch 187/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5477 - accuracy: 0.8363 - val_loss: 1.1968 - val_accuracy: 0.6635
#
# Epoch 00187: val_accuracy did not improve from 0.67552
# Epoch 188/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5435 - accuracy: 0.8392 - val_loss: 1.2033 - val_accuracy: 0.6697
#
# Epoch 00188: val_accuracy did not improve from 0.67552
# Epoch 189/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5445 - accuracy: 0.8396 - val_loss: 1.2166 - val_accuracy: 0.6697
#
# Epoch 00189: val_accuracy did not improve from 0.67552
# Epoch 190/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.5407 - accuracy: 0.8359 - val_loss: 1.2034 - val_accuracy: 0.6646
#
# Epoch 00190: val_accuracy did not improve from 0.67552
# Epoch 191/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5385 - accuracy: 0.8391 - val_loss: 1.2051 - val_accuracy: 0.6748
#
# Epoch 00191: val_accuracy did not improve from 0.67552
# Epoch 192/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.5452 - accuracy: 0.8372 - val_loss: 1.2154 - val_accuracy: 0.6621
#
# Epoch 00192: val_accuracy did not improve from 0.67552
# Epoch 193/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5394 - accuracy: 0.8371 - val_loss: 1.2239 - val_accuracy: 0.6653
#
# Epoch 00193: val_accuracy did not improve from 0.67552
# Epoch 194/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5414 - accuracy: 0.8377 - val_loss: 1.2141 - val_accuracy: 0.6639
#
# Epoch 00194: val_accuracy did not improve from 0.67552
# Epoch 195/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5440 - accuracy: 0.8335 - val_loss: 1.2284 - val_accuracy: 0.6599
#
# Epoch 00195: val_accuracy did not improve from 0.67552
# Epoch 196/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5362 - accuracy: 0.8423 - val_loss: 1.2121 - val_accuracy: 0.6679
#
# Epoch 00196: val_accuracy did not improve from 0.67552
# Epoch 197/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5373 - accuracy: 0.8401 - val_loss: 1.2292 - val_accuracy: 0.6642
#
# Epoch 00197: val_accuracy did not improve from 0.67552
# Epoch 198/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5409 - accuracy: 0.8387 - val_loss: 1.2120 - val_accuracy: 0.6588
#
# Epoch 00198: val_accuracy did not improve from 0.67552
# Epoch 199/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5363 - accuracy: 0.8411 - val_loss: 1.2261 - val_accuracy: 0.6599
#
# Epoch 00199: val_accuracy did not improve from 0.67552
# Epoch 200/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5331 - accuracy: 0.8415 - val_loss: 1.2251 - val_accuracy: 0.6664
#
# Epoch 00200: val_accuracy did not improve from 0.67552
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
best_model = keras.models.load_model('/content/saved_models/FER2013_model.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 87/87 [==============================] - 4s 23ms/step - loss: 1.1392 - accuracy: 0.6926
# [1.1391783952713013, 0.692559003829956]

# %%
#test images
from sklearn.metrics import confusion_matrix
import seaborn as sn
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE

print('Labels Dictionary:')
print(emotion)
print('Number of predition samples = ', len(x_test))
pred = model.predict(x_test)
cm = confusion_matrix( np.argmax(y_test,1),pred.argmax(1),normalize='pred')
#cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize =(10,6))
sn.heatmap(cm, annot=True, annot_kws={"size": 12},cmap=plt.cm.Blues) # font size
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Labels Dictionary:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
# Number of predition samples =  2755

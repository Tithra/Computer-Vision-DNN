# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

img_H = 0
img_W = 0
img_D = 0

#Reshare csv array to image
def data_reshape(x,y,shape=48,depth=1):
  x = np.array(x)
  x = x.reshape(len(x),shape,shape,depth)
  y = np.array(y)
  return x, y

#Load FAFFE
def load_FAFEE():
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/y_val.csv",header=None)
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/x_train.csv",header=None)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/y_train.csv",header=None)

  x = [x_train,x_val]
  y = [y_train,y_val]
  x = pd.concat(x)
  y = pd.concat(y)

  x, y = data_reshape(x, y, 256)
  x, y = shuffle(x, y,random_state = 2021)
  
  img_H = x.shape[1]
  img_W = x.shape[2]
  img_D = x.shape[3]
  print (x.shape,y.shape)
  return x, y


#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  
  x, y = data_reshape(x, y)

  img_H = x.shape[1]
  img_W = x.shape[2]
  img_D = x.shape[3]
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train, y_train = data_reshape(x_train, y_train)
  x_val, y_val = data_reshape(x_val, y_val)
  x_test, y_test = data_reshape(x_test, y_test)

  img_H = x_train.shape[1]
  img_W = x_train.shape[2]
  img_D = x_train.shape[3]
  print(x_train.shape,y_train.shape)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)

  x_train, y_train = data_reshape(x_train, y_train)
  x_val, y_val = data_reshape(x_val, y_val)
  x_test, y_test = data_reshape(x_test, y_test)

  img_H = x_train.shape[1]
  img_W = x_train.shape[2]
  img_D = x_train.shape[3]
  print(x_train.shape,y_train.shape)
  return x_train, y_train, x_test, y_test, x_val, y_val


x, y = load_FAFEE()
# Out:
# (213, 256, 256, 1) (213, 1)

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 11 kB/s
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=db9cb20b01f5eefb2d9dff91622e3f8014d6e57075eb134a3ffcc88853417c73
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

new_H = 64
new_W = 64
def transform(img):
  if len(img.shape)>2:
    img = img.reshape(new_H,new_W)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*50)/math.log(mean)
  img = np.power(img, gamma).clip(0,50).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=new_H, output_width=new_W):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    
    if (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      img = img[y:y + h, x:x + w]
      img = cv2.resize(img, (new_H, new_W))
      
      img = transform(img)
      img = img.reshape(new_H, new_W,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      img = img[y:y + h, x:x + w]
      img = cv2.resize(img,(new_H, new_W))
      
      img = transform(img)
      img = img.reshape(new_H, new_W,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x, y = pre_process(x,y)
#x_train, y_train = pre_process(x_train, y_train)
#x_test, y_test = pre_process(x_test, y_test)
#x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
#trainx = x_train.copy()
#trainy = y_train.copy()
#testx = x_test.copy()
#testy = y_test.copy()
#valx = x_val.copy()
#valy = y_val.copy()

img_H = new_H
img_W = new_W

x.shape, y.shape
# Out:
# ((213, 64, 64, 1), (213, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels,start=0,end=50):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  pos = 0
  for i in range(start,end):
    plt.subplot(5,10,1+pos)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([img_H,img_W]), cmap='gray')
    plt.title(emotion[int(labels[i])])
    pos +=1
  plt.show()

plot_image(x,y)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import callbacks as cb

# Training parameters
batch_size = 14
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
dataset_type = 'JAFFE'


# Load dataset.
x_train, x_val, y_train, y_val = train_test_split(x, y,test_size=21, random_state=2021)
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=21, random_state=2021)

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255

# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= SGD(decay=2e-4, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = dataset_type + '_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.05
    if epoch >= (epochs*0.6):
      lr=0.005
    elif epoch >= (epochs*0.2):
      lr=0.01
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    #history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val), shuffle=True,callbacks=callbacks)
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),verbose=1,shuffle=True,callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    #history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.05
# 14/14 [==============================] - 9s 182ms/step - loss: 2.3027 - accuracy: 0.1302 - val_loss: 2.1162 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_accuracy improved from -inf to 0.00000, saving model to /content/saved_models/JAFFE_model.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 56ms/step - loss: 2.1209 - accuracy: 0.1510 - val_loss: 2.0847 - val_accuracy: 0.3333
#
# Epoch 00002: val_accuracy improved from 0.00000 to 0.33333, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 3/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 2.1096 - accuracy: 0.1146 - val_loss: 2.0982 - val_accuracy: 0.3333
#
# Epoch 00003: val_accuracy did not improve from 0.33333
# Epoch 4/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 2.1031 - accuracy: 0.1406 - val_loss: 2.1007 - val_accuracy: 0.1429
#
# Epoch 00004: val_accuracy did not improve from 0.33333
# Epoch 5/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 49ms/step - loss: 2.0981 - accuracy: 0.1562 - val_loss: 2.1116 - val_accuracy: 0.0476
#
# Epoch 00005: val_accuracy did not improve from 0.33333
# Epoch 6/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 2.1002 - accuracy: 0.1458 - val_loss: 2.1244 - val_accuracy: 0.1429
#
# Epoch 00006: val_accuracy did not improve from 0.33333
# Epoch 7/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 2.0979 - accuracy: 0.1667 - val_loss: 2.0992 - val_accuracy: 0.2381
#
# Epoch 00007: val_accuracy did not improve from 0.33333
# Epoch 8/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 55ms/step - loss: 2.0893 - accuracy: 0.1979 - val_loss: 2.0906 - val_accuracy: 0.0000e+00
#
# Epoch 00008: val_accuracy did not improve from 0.33333
# Epoch 9/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 2.0989 - accuracy: 0.1302 - val_loss: 2.0770 - val_accuracy: 0.3333
#
# Epoch 00009: val_accuracy did not improve from 0.33333
# Epoch 10/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 49ms/step - loss: 2.1018 - accuracy: 0.1771 - val_loss: 2.0942 - val_accuracy: 0.1429
#
# Epoch 00010: val_accuracy did not improve from 0.33333
# Epoch 11/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 2.0836 - accuracy: 0.2135 - val_loss: 2.0803 - val_accuracy: 0.3333
#
# Epoch 00011: val_accuracy did not improve from 0.33333
# Epoch 12/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 56ms/step - loss: 2.0829 - accuracy: 0.1719 - val_loss: 2.1082 - val_accuracy: 0.0000e+00
#
# Epoch 00012: val_accuracy did not improve from 0.33333
# Epoch 13/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 2.0820 - accuracy: 0.1562 - val_loss: 2.1060 - val_accuracy: 0.0000e+00
#
# Epoch 00013: val_accuracy did not improve from 0.33333
# Epoch 14/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 44ms/step - loss: 2.0634 - accuracy: 0.1979 - val_loss: 2.0948 - val_accuracy: 0.0000e+00
#
# Epoch 00014: val_accuracy did not improve from 0.33333
# Epoch 15/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 45ms/step - loss: 2.0706 - accuracy: 0.2344 - val_loss: 2.1046 - val_accuracy: 0.0000e+00
#
# Epoch 00015: val_accuracy did not improve from 0.33333
# Epoch 16/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 2.0547 - accuracy: 0.2188 - val_loss: 2.0880 - val_accuracy: 0.0000e+00
#
# Epoch 00016: val_accuracy did not improve from 0.33333
# Epoch 17/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 2.0683 - accuracy: 0.1771 - val_loss: 2.0842 - val_accuracy: 0.0000e+00
#
# Epoch 00017: val_accuracy did not improve from 0.33333
# Epoch 18/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 2.0425 - accuracy: 0.2188 - val_loss: 2.0760 - val_accuracy: 0.0000e+00
#
# Epoch 00018: val_accuracy did not improve from 0.33333
# Epoch 19/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 55ms/step - loss: 2.0021 - accuracy: 0.2135 - val_loss: 2.0909 - val_accuracy: 0.0000e+00
#
# Epoch 00019: val_accuracy did not improve from 0.33333
# Epoch 20/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 44ms/step - loss: 2.0151 - accuracy: 0.2240 - val_loss: 2.0771 - val_accuracy: 0.0000e+00
#
# Epoch 00020: val_accuracy did not improve from 0.33333
# Epoch 21/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 2.0066 - accuracy: 0.2396 - val_loss: 2.0776 - val_accuracy: 0.0000e+00
#
# Epoch 00021: val_accuracy did not improve from 0.33333
# Epoch 22/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 45ms/step - loss: 1.9829 - accuracy: 0.2604 - val_loss: 2.1165 - val_accuracy: 0.0000e+00
#
# Epoch 00022: val_accuracy did not improve from 0.33333
# Epoch 23/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 1.9174 - accuracy: 0.2500 - val_loss: 2.0689 - val_accuracy: 0.0000e+00
#
# Epoch 00023: val_accuracy did not improve from 0.33333
# Epoch 24/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 49ms/step - loss: 1.8273 - accuracy: 0.2812 - val_loss: 2.1084 - val_accuracy: 0.0000e+00
#
# Epoch 00024: val_accuracy did not improve from 0.33333
# Epoch 25/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 1.7525 - accuracy: 0.3281 - val_loss: 2.1128 - val_accuracy: 0.0000e+00
#
# Epoch 00025: val_accuracy did not improve from 0.33333
# Epoch 26/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 1.8579 - accuracy: 0.3490 - val_loss: 2.1176 - val_accuracy: 0.1429
#
# Epoch 00026: val_accuracy did not improve from 0.33333
# Epoch 27/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 55ms/step - loss: 1.6833 - accuracy: 0.3958 - val_loss: 2.6960 - val_accuracy: 0.0476
#
# Epoch 00027: val_accuracy did not improve from 0.33333
# Epoch 28/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 1.5680 - accuracy: 0.4844 - val_loss: 3.5025 - val_accuracy: 0.0476
#
# Epoch 00028: val_accuracy did not improve from 0.33333
# Epoch 29/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 53ms/step - loss: 1.4346 - accuracy: 0.5469 - val_loss: 14.4055 - val_accuracy: 0.0952
#
# Epoch 00029: val_accuracy did not improve from 0.33333
# Epoch 30/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 1.3004 - accuracy: 0.5885 - val_loss: 11.8430 - val_accuracy: 0.0476
#
# Epoch 00030: val_accuracy did not improve from 0.33333
# Epoch 31/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 1.2665 - accuracy: 0.5521 - val_loss: 2.7992 - val_accuracy: 0.0952
#
# Epoch 00031: val_accuracy did not improve from 0.33333
# Epoch 32/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 1.2807 - accuracy: 0.5677 - val_loss: 5.2562 - val_accuracy: 0.2381
#
# Epoch 00032: val_accuracy did not improve from 0.33333
# Epoch 33/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 1.1217 - accuracy: 0.6406 - val_loss: 2.4971 - val_accuracy: 0.4286
#
# Epoch 00033: val_accuracy improved from 0.33333 to 0.42857, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 34/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 50ms/step - loss: 1.1866 - accuracy: 0.5938 - val_loss: 3.0217 - val_accuracy: 0.3810
#
# Epoch 00034: val_accuracy did not improve from 0.42857
# Epoch 35/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 48ms/step - loss: 0.9754 - accuracy: 0.7031 - val_loss: 4.2646 - val_accuracy: 0.0952
#
# Epoch 00035: val_accuracy did not improve from 0.42857
# Epoch 36/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 1.1115 - accuracy: 0.6094 - val_loss: 36.9051 - val_accuracy: 0.3333
#
# Epoch 00036: val_accuracy did not improve from 0.42857
# Epoch 37/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 49ms/step - loss: 1.0444 - accuracy: 0.6406 - val_loss: 122.7675 - val_accuracy: 0.1429
#
# Epoch 00037: val_accuracy did not improve from 0.42857
# Epoch 38/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 56ms/step - loss: 1.0646 - accuracy: 0.6510 - val_loss: 9.4263 - val_accuracy: 0.2381
#
# Epoch 00038: val_accuracy did not improve from 0.42857
# Epoch 39/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 46ms/step - loss: 0.9559 - accuracy: 0.7031 - val_loss: 8.9305 - val_accuracy: 0.2381
#
# Epoch 00039: val_accuracy did not improve from 0.42857
# Epoch 40/200
# Learning rate:  0.05
# 14/14 [==============================] - 1s 47ms/step - loss: 0.9011 - accuracy: 0.7240 - val_loss: 5.3936 - val_accuracy: 0.1429
#
# Epoch 00040: val_accuracy did not improve from 0.42857
# Epoch 41/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 1.2883 - accuracy: 0.5833 - val_loss: 5.2263 - val_accuracy: 0.2857
#
# Epoch 00041: val_accuracy did not improve from 0.42857
# Epoch 42/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 1.0179 - accuracy: 0.6615 - val_loss: 1.9055 - val_accuracy: 0.3810
#
# Epoch 00042: val_accuracy did not improve from 0.42857
# Epoch 43/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.9470 - accuracy: 0.7135 - val_loss: 1.8970 - val_accuracy: 0.3333
#
# Epoch 00043: val_accuracy did not improve from 0.42857
# Epoch 44/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 54ms/step - loss: 0.7929 - accuracy: 0.7708 - val_loss: 2.0130 - val_accuracy: 0.3810
#
# Epoch 00044: val_accuracy did not improve from 0.42857
# Epoch 45/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.6417 - accuracy: 0.8490 - val_loss: 3.1247 - val_accuracy: 0.2857
#
# Epoch 00045: val_accuracy did not improve from 0.42857
# Epoch 46/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 54ms/step - loss: 0.6747 - accuracy: 0.8385 - val_loss: 2.9446 - val_accuracy: 0.4762
#
# Epoch 00046: val_accuracy improved from 0.42857 to 0.47619, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 47/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 56ms/step - loss: 0.6352 - accuracy: 0.8333 - val_loss: 1.2244 - val_accuracy: 0.5238
#
# Epoch 00047: val_accuracy improved from 0.47619 to 0.52381, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 48/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 56ms/step - loss: 0.5736 - accuracy: 0.8490 - val_loss: 1.0742 - val_accuracy: 0.5714
#
# Epoch 00048: val_accuracy improved from 0.52381 to 0.57143, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 49/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.5372 - accuracy: 0.8854 - val_loss: 1.1276 - val_accuracy: 0.6190
#
# Epoch 00049: val_accuracy improved from 0.57143 to 0.61905, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 50/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 54ms/step - loss: 0.5232 - accuracy: 0.8802 - val_loss: 1.0524 - val_accuracy: 0.7143
#
# Epoch 00050: val_accuracy improved from 0.61905 to 0.71429, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 51/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.5873 - accuracy: 0.8229 - val_loss: 1.3177 - val_accuracy: 0.6667
#
# Epoch 00051: val_accuracy did not improve from 0.71429
# Epoch 52/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.5357 - accuracy: 0.8698 - val_loss: 1.5915 - val_accuracy: 0.6190
#
# Epoch 00052: val_accuracy did not improve from 0.71429
# Epoch 53/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.5445 - accuracy: 0.8750 - val_loss: 0.8238 - val_accuracy: 0.7619
#
# Epoch 00053: val_accuracy improved from 0.71429 to 0.76190, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 54/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 52ms/step - loss: 0.5449 - accuracy: 0.8594 - val_loss: 0.7872 - val_accuracy: 0.7143
#
# Epoch 00054: val_accuracy did not improve from 0.76190
# Epoch 55/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.4831 - accuracy: 0.8854 - val_loss: 0.7834 - val_accuracy: 0.8095
#
# Epoch 00055: val_accuracy improved from 0.76190 to 0.80952, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 56/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.4624 - accuracy: 0.9115 - val_loss: 0.7497 - val_accuracy: 0.8095
#
# Epoch 00056: val_accuracy did not improve from 0.80952
# Epoch 57/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.4417 - accuracy: 0.8958 - val_loss: 0.8226 - val_accuracy: 0.8095
#
# Epoch 00057: val_accuracy did not improve from 0.80952
# Epoch 58/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.5060 - accuracy: 0.8802 - val_loss: 0.9625 - val_accuracy: 0.7143
#
# Epoch 00058: val_accuracy did not improve from 0.80952
# Epoch 59/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.4093 - accuracy: 0.9062 - val_loss: 0.6451 - val_accuracy: 0.9048
#
# Epoch 00059: val_accuracy improved from 0.80952 to 0.90476, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 60/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.5093 - accuracy: 0.8594 - val_loss: 1.1506 - val_accuracy: 0.6190
#
# Epoch 00060: val_accuracy did not improve from 0.90476
# Epoch 61/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 53ms/step - loss: 0.4454 - accuracy: 0.9062 - val_loss: 0.6662 - val_accuracy: 0.8571
#
# Epoch 00061: val_accuracy did not improve from 0.90476
# Epoch 62/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 49ms/step - loss: 0.3767 - accuracy: 0.9167 - val_loss: 1.0346 - val_accuracy: 0.8095
#
# Epoch 00062: val_accuracy did not improve from 0.90476
# Epoch 63/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 54ms/step - loss: 0.4103 - accuracy: 0.9167 - val_loss: 0.6089 - val_accuracy: 0.7619
#
# Epoch 00063: val_accuracy did not improve from 0.90476
# Epoch 64/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 53ms/step - loss: 0.3780 - accuracy: 0.9219 - val_loss: 0.5369 - val_accuracy: 0.9048
#
# Epoch 00064: val_accuracy did not improve from 0.90476
# Epoch 65/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 50ms/step - loss: 0.3497 - accuracy: 0.9635 - val_loss: 1.1743 - val_accuracy: 0.6667
#
# Epoch 00065: val_accuracy did not improve from 0.90476
# Epoch 66/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 52ms/step - loss: 0.3972 - accuracy: 0.9219 - val_loss: 0.6837 - val_accuracy: 0.8095
#
# Epoch 00066: val_accuracy did not improve from 0.90476
# Epoch 67/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 50ms/step - loss: 0.3597 - accuracy: 0.9427 - val_loss: 0.8593 - val_accuracy: 0.6667
#
# Epoch 00067: val_accuracy did not improve from 0.90476
# Epoch 68/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 53ms/step - loss: 0.3248 - accuracy: 0.9531 - val_loss: 0.6686 - val_accuracy: 0.7619
#
# Epoch 00068: val_accuracy did not improve from 0.90476
# Epoch 69/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 51ms/step - loss: 0.3339 - accuracy: 0.9375 - val_loss: 0.5749 - val_accuracy: 0.9048
#
# Epoch 00069: val_accuracy did not improve from 0.90476
# Epoch 70/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 44ms/step - loss: 0.3647 - accuracy: 0.9375 - val_loss: 0.7249 - val_accuracy: 0.8571
#
# Epoch 00070: val_accuracy did not improve from 0.90476
# Epoch 71/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.4347 - accuracy: 0.9010 - val_loss: 1.0120 - val_accuracy: 0.7143
#
# Epoch 00071: val_accuracy did not improve from 0.90476
# Epoch 72/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.4024 - accuracy: 0.9115 - val_loss: 1.7074 - val_accuracy: 0.6190
#
# Epoch 00072: val_accuracy did not improve from 0.90476
# Epoch 73/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 49ms/step - loss: 0.3197 - accuracy: 0.9583 - val_loss: 1.1397 - val_accuracy: 0.6190
#
# Epoch 00073: val_accuracy did not improve from 0.90476
# Epoch 74/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.3995 - accuracy: 0.9323 - val_loss: 0.5371 - val_accuracy: 0.8095
#
# Epoch 00074: val_accuracy did not improve from 0.90476
# Epoch 75/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.3191 - accuracy: 0.9635 - val_loss: 0.6794 - val_accuracy: 0.8095
#
# Epoch 00075: val_accuracy did not improve from 0.90476
# Epoch 76/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.3084 - accuracy: 0.9635 - val_loss: 0.9113 - val_accuracy: 0.5714
#
# Epoch 00076: val_accuracy did not improve from 0.90476
# Epoch 77/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.3078 - accuracy: 0.9688 - val_loss: 1.5241 - val_accuracy: 0.3810
#
# Epoch 00077: val_accuracy did not improve from 0.90476
# Epoch 78/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2872 - accuracy: 0.9375 - val_loss: 0.8921 - val_accuracy: 0.6190
#
# Epoch 00078: val_accuracy did not improve from 0.90476
# Epoch 79/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 52ms/step - loss: 0.3400 - accuracy: 0.9427 - val_loss: 1.3949 - val_accuracy: 0.6190
#
# Epoch 00079: val_accuracy did not improve from 0.90476
# Epoch 80/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 44ms/step - loss: 0.3409 - accuracy: 0.9531 - val_loss: 0.7599 - val_accuracy: 0.7619
#
# Epoch 00080: val_accuracy did not improve from 0.90476
# Epoch 81/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 55ms/step - loss: 0.3465 - accuracy: 0.9375 - val_loss: 0.7522 - val_accuracy: 0.7619
#
# Epoch 00081: val_accuracy did not improve from 0.90476
# Epoch 82/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 55ms/step - loss: 0.3350 - accuracy: 0.9479 - val_loss: 1.9226 - val_accuracy: 0.4286
#
# Epoch 00082: val_accuracy did not improve from 0.90476
# Epoch 83/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.3817 - accuracy: 0.9271 - val_loss: 0.9509 - val_accuracy: 0.6667
#
# Epoch 00083: val_accuracy did not improve from 0.90476
# Epoch 84/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 50ms/step - loss: 0.3134 - accuracy: 0.9479 - val_loss: 0.5096 - val_accuracy: 0.8571
#
# Epoch 00084: val_accuracy did not improve from 0.90476
# Epoch 85/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 55ms/step - loss: 0.3086 - accuracy: 0.9583 - val_loss: 0.4826 - val_accuracy: 0.8571
#
# Epoch 00085: val_accuracy did not improve from 0.90476
# Epoch 86/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2631 - accuracy: 0.9635 - val_loss: 0.8284 - val_accuracy: 0.7619
#
# Epoch 00086: val_accuracy did not improve from 0.90476
# Epoch 87/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2490 - accuracy: 0.9792 - val_loss: 0.6421 - val_accuracy: 0.8571
#
# Epoch 00087: val_accuracy did not improve from 0.90476
# Epoch 88/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2897 - accuracy: 0.9688 - val_loss: 0.8747 - val_accuracy: 0.8095
#
# Epoch 00088: val_accuracy did not improve from 0.90476
# Epoch 89/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2845 - accuracy: 0.9583 - val_loss: 0.9199 - val_accuracy: 0.7619
#
# Epoch 00089: val_accuracy did not improve from 0.90476
# Epoch 90/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2793 - accuracy: 0.9427 - val_loss: 0.8133 - val_accuracy: 0.9048
#
# Epoch 00090: val_accuracy did not improve from 0.90476
# Epoch 91/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2809 - accuracy: 0.9583 - val_loss: 0.6239 - val_accuracy: 0.8095
#
# Epoch 00091: val_accuracy did not improve from 0.90476
# Epoch 92/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 50ms/step - loss: 0.3206 - accuracy: 0.9531 - val_loss: 1.1038 - val_accuracy: 0.6190
#
# Epoch 00092: val_accuracy did not improve from 0.90476
# Epoch 93/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.3266 - accuracy: 0.9427 - val_loss: 1.0170 - val_accuracy: 0.7619
#
# Epoch 00093: val_accuracy did not improve from 0.90476
# Epoch 94/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.2399 - accuracy: 0.9792 - val_loss: 1.1155 - val_accuracy: 0.6667
#
# Epoch 00094: val_accuracy did not improve from 0.90476
# Epoch 95/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 44ms/step - loss: 0.2700 - accuracy: 0.9792 - val_loss: 0.8483 - val_accuracy: 0.8095
#
# Epoch 00095: val_accuracy did not improve from 0.90476
# Epoch 96/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2732 - accuracy: 0.9688 - val_loss: 0.6006 - val_accuracy: 0.8095
#
# Epoch 00096: val_accuracy did not improve from 0.90476
# Epoch 97/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2469 - accuracy: 0.9896 - val_loss: 0.6395 - val_accuracy: 0.8095
#
# Epoch 00097: val_accuracy did not improve from 0.90476
# Epoch 98/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2569 - accuracy: 0.9688 - val_loss: 0.3497 - val_accuracy: 0.9524
#
# Epoch 00098: val_accuracy improved from 0.90476 to 0.95238, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 99/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.3183 - accuracy: 0.9635 - val_loss: 0.6647 - val_accuracy: 0.7143
#
# Epoch 00099: val_accuracy did not improve from 0.95238
# Epoch 100/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 55ms/step - loss: 0.2758 - accuracy: 0.9583 - val_loss: 0.5309 - val_accuracy: 0.9524
#
# Epoch 00100: val_accuracy did not improve from 0.95238
# Epoch 101/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.3012 - accuracy: 0.9531 - val_loss: 0.7227 - val_accuracy: 0.8095
#
# Epoch 00101: val_accuracy did not improve from 0.95238
# Epoch 102/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 50ms/step - loss: 0.2451 - accuracy: 0.9792 - val_loss: 0.9805 - val_accuracy: 0.6667
#
# Epoch 00102: val_accuracy did not improve from 0.95238
# Epoch 103/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2683 - accuracy: 0.9531 - val_loss: 0.6912 - val_accuracy: 0.8095
#
# Epoch 00103: val_accuracy did not improve from 0.95238
# Epoch 104/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2919 - accuracy: 0.9479 - val_loss: 0.6705 - val_accuracy: 0.7619
#
# Epoch 00104: val_accuracy did not improve from 0.95238
# Epoch 105/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 44ms/step - loss: 0.2669 - accuracy: 0.9688 - val_loss: 1.1188 - val_accuracy: 0.6190
#
# Epoch 00105: val_accuracy did not improve from 0.95238
# Epoch 106/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2547 - accuracy: 0.9792 - val_loss: 0.6496 - val_accuracy: 0.8095
#
# Epoch 00106: val_accuracy did not improve from 0.95238
# Epoch 107/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2356 - accuracy: 0.9792 - val_loss: 0.3815 - val_accuracy: 0.9524
#
# Epoch 00107: val_accuracy did not improve from 0.95238
# Epoch 108/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.2597 - accuracy: 0.9635 - val_loss: 0.9056 - val_accuracy: 0.7619
#
# Epoch 00108: val_accuracy did not improve from 0.95238
# Epoch 109/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2480 - accuracy: 0.9792 - val_loss: 0.7149 - val_accuracy: 0.8571
#
# Epoch 00109: val_accuracy did not improve from 0.95238
# Epoch 110/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 46ms/step - loss: 0.3305 - accuracy: 0.9323 - val_loss: 3.0440 - val_accuracy: 0.3333
#
# Epoch 00110: val_accuracy did not improve from 0.95238
# Epoch 111/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 49ms/step - loss: 0.2395 - accuracy: 0.9792 - val_loss: 1.4270 - val_accuracy: 0.6667
#
# Epoch 00111: val_accuracy did not improve from 0.95238
# Epoch 112/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.2328 - accuracy: 0.9792 - val_loss: 0.4272 - val_accuracy: 0.9048
#
# Epoch 00112: val_accuracy did not improve from 0.95238
# Epoch 113/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 55ms/step - loss: 0.2576 - accuracy: 0.9740 - val_loss: 0.7601 - val_accuracy: 0.8571
#
# Epoch 00113: val_accuracy did not improve from 0.95238
# Epoch 114/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 48ms/step - loss: 0.2905 - accuracy: 0.9479 - val_loss: 0.7020 - val_accuracy: 0.8095
#
# Epoch 00114: val_accuracy did not improve from 0.95238
# Epoch 115/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 58ms/step - loss: 0.2501 - accuracy: 0.9792 - val_loss: 1.7856 - val_accuracy: 0.6190
#
# Epoch 00115: val_accuracy did not improve from 0.95238
# Epoch 116/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 56ms/step - loss: 0.2145 - accuracy: 0.9844 - val_loss: 1.3594 - val_accuracy: 0.5714
#
# Epoch 00116: val_accuracy did not improve from 0.95238
# Epoch 117/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 53ms/step - loss: 0.2679 - accuracy: 0.9635 - val_loss: 0.6372 - val_accuracy: 0.7619
#
# Epoch 00117: val_accuracy did not improve from 0.95238
# Epoch 118/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2248 - accuracy: 0.9792 - val_loss: 0.9226 - val_accuracy: 0.6667
#
# Epoch 00118: val_accuracy did not improve from 0.95238
# Epoch 119/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 45ms/step - loss: 0.2235 - accuracy: 0.9792 - val_loss: 1.4940 - val_accuracy: 0.6667
#
# Epoch 00119: val_accuracy did not improve from 0.95238
# Epoch 120/200
# Learning rate:  0.01
# 14/14 [==============================] - 1s 52ms/step - loss: 0.2761 - accuracy: 0.9635 - val_loss: 1.3999 - val_accuracy: 0.6667
#
# Epoch 00120: val_accuracy did not improve from 0.95238
# Epoch 121/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2087 - accuracy: 0.9896 - val_loss: 0.3223 - val_accuracy: 0.9048
#
# Epoch 00121: val_accuracy did not improve from 0.95238
# Epoch 122/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2203 - accuracy: 0.9896 - val_loss: 0.2672 - val_accuracy: 0.9524
#
# Epoch 00122: val_accuracy did not improve from 0.95238
# Epoch 123/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1982 - accuracy: 0.9844 - val_loss: 0.2606 - val_accuracy: 0.9524
#
# Epoch 00123: val_accuracy did not improve from 0.95238
# Epoch 124/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 58ms/step - loss: 0.2190 - accuracy: 0.9896 - val_loss: 0.4307 - val_accuracy: 0.9048
#
# Epoch 00124: val_accuracy did not improve from 0.95238
# Epoch 125/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.2033 - accuracy: 0.9844 - val_loss: 0.3047 - val_accuracy: 0.9048
#
# Epoch 00125: val_accuracy did not improve from 0.95238
# Epoch 126/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2127 - accuracy: 0.9896 - val_loss: 0.3117 - val_accuracy: 0.9524
#
# Epoch 00126: val_accuracy did not improve from 0.95238
# Epoch 127/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1966 - accuracy: 0.9896 - val_loss: 0.4319 - val_accuracy: 0.8571
#
# Epoch 00127: val_accuracy did not improve from 0.95238
# Epoch 128/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1807 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.8571
#
# Epoch 00128: val_accuracy did not improve from 0.95238
# Epoch 129/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1901 - accuracy: 0.9896 - val_loss: 0.5207 - val_accuracy: 0.8095
#
# Epoch 00129: val_accuracy did not improve from 0.95238
# Epoch 130/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1966 - accuracy: 0.9896 - val_loss: 0.4778 - val_accuracy: 0.8571
#
# Epoch 00130: val_accuracy did not improve from 0.95238
# Epoch 131/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1954 - accuracy: 0.9948 - val_loss: 0.3802 - val_accuracy: 0.8571
#
# Epoch 00131: val_accuracy did not improve from 0.95238
# Epoch 132/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1882 - accuracy: 1.0000 - val_loss: 0.5111 - val_accuracy: 0.8571
#
# Epoch 00132: val_accuracy did not improve from 0.95238
# Epoch 133/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1933 - accuracy: 0.9844 - val_loss: 0.5169 - val_accuracy: 0.8571
#
# Epoch 00133: val_accuracy did not improve from 0.95238
# Epoch 134/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1871 - accuracy: 0.9948 - val_loss: 0.3778 - val_accuracy: 0.8571
#
# Epoch 00134: val_accuracy did not improve from 0.95238
# Epoch 135/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 44ms/step - loss: 0.2303 - accuracy: 0.9792 - val_loss: 0.4020 - val_accuracy: 0.9524
#
# Epoch 00135: val_accuracy did not improve from 0.95238
# Epoch 136/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.2017 - accuracy: 0.9844 - val_loss: 0.5976 - val_accuracy: 0.8571
#
# Epoch 00136: val_accuracy did not improve from 0.95238
# Epoch 137/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.2087 - accuracy: 0.9896 - val_loss: 0.7392 - val_accuracy: 0.9048
#
# Epoch 00137: val_accuracy did not improve from 0.95238
# Epoch 138/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1922 - accuracy: 0.9948 - val_loss: 0.4459 - val_accuracy: 0.9524
#
# Epoch 00138: val_accuracy did not improve from 0.95238
# Epoch 139/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1813 - accuracy: 1.0000 - val_loss: 0.3474 - val_accuracy: 0.9524
#
# Epoch 00139: val_accuracy did not improve from 0.95238
# Epoch 140/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 44ms/step - loss: 0.1905 - accuracy: 0.9948 - val_loss: 0.3413 - val_accuracy: 0.9524
#
# Epoch 00140: val_accuracy did not improve from 0.95238
# Epoch 141/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1731 - accuracy: 1.0000 - val_loss: 0.4602 - val_accuracy: 0.8571
#
# Epoch 00141: val_accuracy did not improve from 0.95238
# Epoch 142/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 50ms/step - loss: 0.1999 - accuracy: 0.9844 - val_loss: 0.4458 - val_accuracy: 0.9048
#
# Epoch 00142: val_accuracy did not improve from 0.95238
# Epoch 143/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1907 - accuracy: 0.9948 - val_loss: 0.4373 - val_accuracy: 0.8571
#
# Epoch 00143: val_accuracy did not improve from 0.95238
# Epoch 144/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 57ms/step - loss: 0.1825 - accuracy: 0.9948 - val_loss: 0.5007 - val_accuracy: 0.8571
#
# Epoch 00144: val_accuracy did not improve from 0.95238
# Epoch 145/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1846 - accuracy: 1.0000 - val_loss: 0.4462 - val_accuracy: 0.8571
#
# Epoch 00145: val_accuracy did not improve from 0.95238
# Epoch 146/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1692 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.9048
#
# Epoch 00146: val_accuracy did not improve from 0.95238
# Epoch 147/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1791 - accuracy: 1.0000 - val_loss: 0.4070 - val_accuracy: 0.9048
#
# Epoch 00147: val_accuracy did not improve from 0.95238
# Epoch 148/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 49ms/step - loss: 0.1978 - accuracy: 0.9896 - val_loss: 0.4373 - val_accuracy: 0.9048
#
# Epoch 00148: val_accuracy did not improve from 0.95238
# Epoch 149/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1917 - accuracy: 0.9948 - val_loss: 0.4257 - val_accuracy: 0.9048
#
# Epoch 00149: val_accuracy did not improve from 0.95238
# Epoch 150/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1903 - accuracy: 0.9948 - val_loss: 0.4584 - val_accuracy: 0.8571
#
# Epoch 00150: val_accuracy did not improve from 0.95238
# Epoch 151/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1942 - accuracy: 0.9896 - val_loss: 0.9536 - val_accuracy: 0.7143
#
# Epoch 00151: val_accuracy did not improve from 0.95238
# Epoch 152/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 49ms/step - loss: 0.1706 - accuracy: 1.0000 - val_loss: 0.6112 - val_accuracy: 0.8571
#
# Epoch 00152: val_accuracy did not improve from 0.95238
# Epoch 153/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1718 - accuracy: 1.0000 - val_loss: 0.4849 - val_accuracy: 0.8571
#
# Epoch 00153: val_accuracy did not improve from 0.95238
# Epoch 154/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1784 - accuracy: 0.9948 - val_loss: 0.5571 - val_accuracy: 0.8095
#
# Epoch 00154: val_accuracy did not improve from 0.95238
# Epoch 155/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1793 - accuracy: 1.0000 - val_loss: 0.5056 - val_accuracy: 0.8095
#
# Epoch 00155: val_accuracy did not improve from 0.95238
# Epoch 156/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1805 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.8571
#
# Epoch 00156: val_accuracy did not improve from 0.95238
# Epoch 157/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1822 - accuracy: 1.0000 - val_loss: 0.5348 - val_accuracy: 0.8571
#
# Epoch 00157: val_accuracy did not improve from 0.95238
# Epoch 158/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1795 - accuracy: 0.9948 - val_loss: 0.3837 - val_accuracy: 0.9048
#
# Epoch 00158: val_accuracy did not improve from 0.95238
# Epoch 159/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1862 - accuracy: 0.9948 - val_loss: 0.5072 - val_accuracy: 0.8571
#
# Epoch 00159: val_accuracy did not improve from 0.95238
# Epoch 160/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1743 - accuracy: 1.0000 - val_loss: 0.7304 - val_accuracy: 0.8095
#
# Epoch 00160: val_accuracy did not improve from 0.95238
# Epoch 161/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1815 - accuracy: 0.9948 - val_loss: 0.4094 - val_accuracy: 0.8571
#
# Epoch 00161: val_accuracy did not improve from 0.95238
# Epoch 162/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.2007 - accuracy: 0.9896 - val_loss: 0.3477 - val_accuracy: 0.9048
#
# Epoch 00162: val_accuracy did not improve from 0.95238
# Epoch 163/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1826 - accuracy: 0.9948 - val_loss: 0.2954 - val_accuracy: 0.9048
#
# Epoch 00163: val_accuracy did not improve from 0.95238
# Epoch 164/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1855 - accuracy: 1.0000 - val_loss: 0.3073 - val_accuracy: 0.9524
#
# Epoch 00164: val_accuracy did not improve from 0.95238
# Epoch 165/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 57ms/step - loss: 0.1877 - accuracy: 0.9948 - val_loss: 0.2576 - val_accuracy: 1.0000
#
# Epoch 00165: val_accuracy improved from 0.95238 to 1.00000, saving model to /content/saved_models/JAFFE_model.h5
# Epoch 166/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 59ms/step - loss: 0.1859 - accuracy: 0.9844 - val_loss: 0.2420 - val_accuracy: 1.0000
#
# Epoch 00166: val_accuracy did not improve from 1.00000
# Epoch 167/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1773 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 1.0000
#
# Epoch 00167: val_accuracy did not improve from 1.00000
# Epoch 168/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1755 - accuracy: 0.9948 - val_loss: 0.3713 - val_accuracy: 0.9048
#
# Epoch 00168: val_accuracy did not improve from 1.00000
# Epoch 169/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1829 - accuracy: 0.9896 - val_loss: 0.4785 - val_accuracy: 0.8095
#
# Epoch 00169: val_accuracy did not improve from 1.00000
# Epoch 170/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1757 - accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.8095
#
# Epoch 00170: val_accuracy did not improve from 1.00000
# Epoch 171/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1693 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.9048
#
# Epoch 00171: val_accuracy did not improve from 1.00000
# Epoch 172/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1795 - accuracy: 0.9948 - val_loss: 0.4036 - val_accuracy: 0.8571
#
# Epoch 00172: val_accuracy did not improve from 1.00000
# Epoch 173/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 49ms/step - loss: 0.1714 - accuracy: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.9048
#
# Epoch 00173: val_accuracy did not improve from 1.00000
# Epoch 174/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1897 - accuracy: 0.9948 - val_loss: 0.3100 - val_accuracy: 0.9048
#
# Epoch 00174: val_accuracy did not improve from 1.00000
# Epoch 175/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 57ms/step - loss: 0.1764 - accuracy: 0.9948 - val_loss: 0.3690 - val_accuracy: 0.9048
#
# Epoch 00175: val_accuracy did not improve from 1.00000
# Epoch 176/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1718 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9524
#
# Epoch 00176: val_accuracy did not improve from 1.00000
# Epoch 177/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 50ms/step - loss: 0.1623 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.9524
#
# Epoch 00177: val_accuracy did not improve from 1.00000
# Epoch 178/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1718 - accuracy: 0.9948 - val_loss: 0.2911 - val_accuracy: 0.9524
#
# Epoch 00178: val_accuracy did not improve from 1.00000
# Epoch 179/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.2063 - accuracy: 0.9792 - val_loss: 0.3581 - val_accuracy: 0.9048
#
# Epoch 00179: val_accuracy did not improve from 1.00000
# Epoch 180/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 50ms/step - loss: 0.1884 - accuracy: 0.9948 - val_loss: 0.3499 - val_accuracy: 0.9048
#
# Epoch 00180: val_accuracy did not improve from 1.00000
# Epoch 181/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1823 - accuracy: 0.9948 - val_loss: 0.2949 - val_accuracy: 0.9524
#
# Epoch 00181: val_accuracy did not improve from 1.00000
# Epoch 182/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1747 - accuracy: 0.9948 - val_loss: 0.2886 - val_accuracy: 0.9524
#
# Epoch 00182: val_accuracy did not improve from 1.00000
# Epoch 183/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1715 - accuracy: 1.0000 - val_loss: 0.3295 - val_accuracy: 0.9524
#
# Epoch 00183: val_accuracy did not improve from 1.00000
# Epoch 184/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 59ms/step - loss: 0.1690 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9048
#
# Epoch 00184: val_accuracy did not improve from 1.00000
# Epoch 185/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1740 - accuracy: 0.9948 - val_loss: 0.2998 - val_accuracy: 0.9524
#
# Epoch 00185: val_accuracy did not improve from 1.00000
# Epoch 186/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 49ms/step - loss: 0.1639 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.9524
#
# Epoch 00186: val_accuracy did not improve from 1.00000
# Epoch 187/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1718 - accuracy: 0.9948 - val_loss: 0.3213 - val_accuracy: 0.9524
#
# Epoch 00187: val_accuracy did not improve from 1.00000
# Epoch 188/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1834 - accuracy: 0.9896 - val_loss: 0.3069 - val_accuracy: 0.9524
#
# Epoch 00188: val_accuracy did not improve from 1.00000
# Epoch 189/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 56ms/step - loss: 0.1826 - accuracy: 0.9948 - val_loss: 0.2613 - val_accuracy: 1.0000
#
# Epoch 00189: val_accuracy did not improve from 1.00000
# Epoch 190/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 45ms/step - loss: 0.1701 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 1.0000
#
# Epoch 00190: val_accuracy did not improve from 1.00000
# Epoch 191/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1654 - accuracy: 1.0000 - val_loss: 0.3034 - val_accuracy: 0.9524
#
# Epoch 00191: val_accuracy did not improve from 1.00000
# Epoch 192/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1632 - accuracy: 1.0000 - val_loss: 0.3075 - val_accuracy: 0.9048
#
# Epoch 00192: val_accuracy did not improve from 1.00000
# Epoch 193/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 48ms/step - loss: 0.1745 - accuracy: 0.9948 - val_loss: 0.2423 - val_accuracy: 1.0000
#
# Epoch 00193: val_accuracy did not improve from 1.00000
# Epoch 194/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1647 - accuracy: 1.0000 - val_loss: 0.2354 - val_accuracy: 1.0000
#
# Epoch 00194: val_accuracy did not improve from 1.00000
# Epoch 195/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1838 - accuracy: 0.9896 - val_loss: 0.2822 - val_accuracy: 0.9048
#
# Epoch 00195: val_accuracy did not improve from 1.00000
# Epoch 196/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 50ms/step - loss: 0.1761 - accuracy: 0.9948 - val_loss: 0.4224 - val_accuracy: 0.9048
#
# Epoch 00196: val_accuracy did not improve from 1.00000
# Epoch 197/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 57ms/step - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.3232 - val_accuracy: 0.9048
#
# Epoch 00197: val_accuracy did not improve from 1.00000
# Epoch 198/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 46ms/step - loss: 0.1860 - accuracy: 0.9948 - val_loss: 0.3477 - val_accuracy: 0.9524
#
# Epoch 00198: val_accuracy did not improve from 1.00000
# Epoch 199/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1859 - accuracy: 0.9896 - val_loss: 0.5039 - val_accuracy: 0.9048
#
# Epoch 00199: val_accuracy did not improve from 1.00000
# Epoch 200/200
# Learning rate:  0.005
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1658 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.8571
#
# Epoch 00200: val_accuracy did not improve from 1.00000
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
#Testing the predition
best_model = keras.models.load_model('/content/saved_models/'+ dataset_type + '_model.h5')
scores = best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.2576 - accuracy: 1.0000

# %%
#test images
from sklearn.metrics import confusion_matrix
import seaborn as sn
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE

print('Labels Dictionary:')
print(emotion)
print('Number of predition samples = ', len(x_test))
pred = best_model.predict(x_test)
cm = confusion_matrix( np.argmax(y_test,1),pred.argmax(1),normalize='pred')
#cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize =(10,6))
sn.heatmap(cm, annot=True, annot_kws={"size": 12},cmap=plt.cm.Blues) # font size
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Labels Dictionary:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
# Number of predition samples =  21

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 21 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=a89bc60cf15f8c7a94178351f427ed03bd4935b5402b9518b6a96206ea00d9a8
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*100)/math.log(mean)
  img = np.power(img, gamma).clip(0,100).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      #img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      #img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((22279, 48, 48, 1), (2755, 48, 48, 1), (2749, 48, 48, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import callbacks as cb

# Training parameter
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
dataset_type = 'FER2013'


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = dataset_type + '_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.8):
      lr = 0.0001
    elif epoch >= (epochs*0.3):
      lr=0.001
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    datagen.fit(x_train)
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.01
# 44/44 [==============================] - 30s 503ms/step - loss: 1.9469 - accuracy: 0.2723 - val_loss: 1.9342 - val_accuracy: 0.2776
#
# Epoch 00001: val_accuracy improved from -inf to 0.27756, saving model to /content/saved_models/FER2013_model.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 447ms/step - loss: 1.8084 - accuracy: 0.3194 - val_loss: 2.0640 - val_accuracy: 0.2677
#
# Epoch 00002: val_accuracy did not improve from 0.27756
# Epoch 3/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 446ms/step - loss: 1.5431 - accuracy: 0.4622 - val_loss: 2.6666 - val_accuracy: 0.2914
#
# Epoch 00003: val_accuracy improved from 0.27756 to 0.29138, saving model to /content/saved_models/FER2013_model.h5
# Epoch 4/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 453ms/step - loss: 1.4113 - accuracy: 0.5123 - val_loss: 2.1918 - val_accuracy: 0.3798
#
# Epoch 00004: val_accuracy improved from 0.29138 to 0.37977, saving model to /content/saved_models/FER2013_model.h5
# Epoch 5/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 453ms/step - loss: 1.3487 - accuracy: 0.5395 - val_loss: 2.1039 - val_accuracy: 0.3790
#
# Epoch 00005: val_accuracy did not improve from 0.37977
# Epoch 6/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 450ms/step - loss: 1.3035 - accuracy: 0.5542 - val_loss: 1.4375 - val_accuracy: 0.4965
#
# Epoch 00006: val_accuracy improved from 0.37977 to 0.49654, saving model to /content/saved_models/FER2013_model.h5
# Epoch 7/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 453ms/step - loss: 1.2607 - accuracy: 0.5736 - val_loss: 1.5260 - val_accuracy: 0.4656
#
# Epoch 00007: val_accuracy did not improve from 0.49654
# Epoch 8/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2410 - accuracy: 0.5844 - val_loss: 1.6593 - val_accuracy: 0.3838
#
# Epoch 00008: val_accuracy did not improve from 0.49654
# Epoch 9/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2337 - accuracy: 0.5886 - val_loss: 1.5304 - val_accuracy: 0.4947
#
# Epoch 00009: val_accuracy did not improve from 0.49654
# Epoch 10/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.2111 - accuracy: 0.5940 - val_loss: 1.5137 - val_accuracy: 0.4533
#
# Epoch 00010: val_accuracy did not improve from 0.49654
# Epoch 11/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.1930 - accuracy: 0.6074 - val_loss: 1.5057 - val_accuracy: 0.4689
#
# Epoch 00011: val_accuracy did not improve from 0.49654
# Epoch 12/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.1918 - accuracy: 0.6087 - val_loss: 1.7395 - val_accuracy: 0.4012
#
# Epoch 00012: val_accuracy did not improve from 0.49654
# Epoch 13/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.1918 - accuracy: 0.6128 - val_loss: 1.3630 - val_accuracy: 0.5453
#
# Epoch 00013: val_accuracy improved from 0.49654 to 0.54529, saving model to /content/saved_models/FER2013_model.h5
# Epoch 14/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.1639 - accuracy: 0.6185 - val_loss: 1.3453 - val_accuracy: 0.5497
#
# Epoch 00014: val_accuracy improved from 0.54529 to 0.54965, saving model to /content/saved_models/FER2013_model.h5
# Epoch 15/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.1464 - accuracy: 0.6224 - val_loss: 1.3672 - val_accuracy: 0.5544
#
# Epoch 00015: val_accuracy improved from 0.54965 to 0.55438, saving model to /content/saved_models/FER2013_model.h5
# Epoch 16/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.1557 - accuracy: 0.6218 - val_loss: 1.3260 - val_accuracy: 0.5664
#
# Epoch 00016: val_accuracy improved from 0.55438 to 0.56639, saving model to /content/saved_models/FER2013_model.h5
# Epoch 17/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.1392 - accuracy: 0.6273 - val_loss: 1.5735 - val_accuracy: 0.4282
#
# Epoch 00017: val_accuracy did not improve from 0.56639
# Epoch 18/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.1274 - accuracy: 0.6321 - val_loss: 1.6025 - val_accuracy: 0.4362
#
# Epoch 00018: val_accuracy did not improve from 0.56639
# Epoch 19/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.1268 - accuracy: 0.6365 - val_loss: 1.2612 - val_accuracy: 0.5860
#
# Epoch 00019: val_accuracy improved from 0.56639 to 0.58603, saving model to /content/saved_models/FER2013_model.h5
# Epoch 20/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.1199 - accuracy: 0.6348 - val_loss: 1.5402 - val_accuracy: 0.4878
#
# Epoch 00020: val_accuracy did not improve from 0.58603
# Epoch 21/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1090 - accuracy: 0.6414 - val_loss: 1.4763 - val_accuracy: 0.5315
#
# Epoch 00021: val_accuracy did not improve from 0.58603
# Epoch 22/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.1132 - accuracy: 0.6402 - val_loss: 1.4353 - val_accuracy: 0.5300
#
# Epoch 00022: val_accuracy did not improve from 0.58603
# Epoch 23/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.1193 - accuracy: 0.6370 - val_loss: 1.4829 - val_accuracy: 0.4794
#
# Epoch 00023: val_accuracy did not improve from 0.58603
# Epoch 24/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.1015 - accuracy: 0.6452 - val_loss: 1.6158 - val_accuracy: 0.5118
#
# Epoch 00024: val_accuracy did not improve from 0.58603
# Epoch 25/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.1128 - accuracy: 0.6428 - val_loss: 1.3386 - val_accuracy: 0.5649
#
# Epoch 00025: val_accuracy did not improve from 0.58603
# Epoch 26/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0961 - accuracy: 0.6455 - val_loss: 1.3532 - val_accuracy: 0.5518
#
# Epoch 00026: val_accuracy did not improve from 0.58603
# Epoch 27/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0996 - accuracy: 0.6477 - val_loss: 1.3573 - val_accuracy: 0.5566
#
# Epoch 00027: val_accuracy did not improve from 0.58603
# Epoch 28/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.0890 - accuracy: 0.6488 - val_loss: 1.5267 - val_accuracy: 0.5322
#
# Epoch 00028: val_accuracy did not improve from 0.58603
# Epoch 29/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0864 - accuracy: 0.6536 - val_loss: 1.3461 - val_accuracy: 0.5446
#
# Epoch 00029: val_accuracy did not improve from 0.58603
# Epoch 30/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.0880 - accuracy: 0.6524 - val_loss: 1.4408 - val_accuracy: 0.5336
#
# Epoch 00030: val_accuracy did not improve from 0.58603
# Epoch 31/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0832 - accuracy: 0.6540 - val_loss: 1.3829 - val_accuracy: 0.5293
#
# Epoch 00031: val_accuracy did not improve from 0.58603
# Epoch 32/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.0768 - accuracy: 0.6570 - val_loss: 1.2559 - val_accuracy: 0.5857
#
# Epoch 00032: val_accuracy did not improve from 0.58603
# Epoch 33/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.0790 - accuracy: 0.6568 - val_loss: 1.2842 - val_accuracy: 0.5864
#
# Epoch 00033: val_accuracy improved from 0.58603 to 0.58640, saving model to /content/saved_models/FER2013_model.h5
# Epoch 34/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0717 - accuracy: 0.6584 - val_loss: 1.2812 - val_accuracy: 0.5795
#
# Epoch 00034: val_accuracy did not improve from 0.58640
# Epoch 35/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 473ms/step - loss: 1.0688 - accuracy: 0.6564 - val_loss: 1.3183 - val_accuracy: 0.5511
#
# Epoch 00035: val_accuracy did not improve from 0.58640
# Epoch 36/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.0793 - accuracy: 0.6520 - val_loss: 1.2894 - val_accuracy: 0.5526
#
# Epoch 00036: val_accuracy did not improve from 0.58640
# Epoch 37/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0820 - accuracy: 0.6564 - val_loss: 1.3070 - val_accuracy: 0.5682
#
# Epoch 00037: val_accuracy did not improve from 0.58640
# Epoch 38/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0603 - accuracy: 0.6621 - val_loss: 1.2852 - val_accuracy: 0.5697
#
# Epoch 00038: val_accuracy did not improve from 0.58640
# Epoch 39/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 472ms/step - loss: 1.0717 - accuracy: 0.6580 - val_loss: 1.3100 - val_accuracy: 0.5700
#
# Epoch 00039: val_accuracy did not improve from 0.58640
# Epoch 40/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.0669 - accuracy: 0.6608 - val_loss: 1.2649 - val_accuracy: 0.5809
#
# Epoch 00040: val_accuracy did not improve from 0.58640
# Epoch 41/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0620 - accuracy: 0.6619 - val_loss: 1.4056 - val_accuracy: 0.5253
#
# Epoch 00041: val_accuracy did not improve from 0.58640
# Epoch 42/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.0522 - accuracy: 0.6598 - val_loss: 1.2856 - val_accuracy: 0.5806
#
# Epoch 00042: val_accuracy did not improve from 0.58640
# Epoch 43/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0558 - accuracy: 0.6629 - val_loss: 1.7072 - val_accuracy: 0.4805
#
# Epoch 00043: val_accuracy did not improve from 0.58640
# Epoch 44/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.0588 - accuracy: 0.6641 - val_loss: 1.2686 - val_accuracy: 0.5904
#
# Epoch 00044: val_accuracy improved from 0.58640 to 0.59040, saving model to /content/saved_models/FER2013_model.h5
# Epoch 45/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.0561 - accuracy: 0.6658 - val_loss: 1.3531 - val_accuracy: 0.5780
#
# Epoch 00045: val_accuracy did not improve from 0.59040
# Epoch 46/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.0524 - accuracy: 0.6641 - val_loss: 1.3286 - val_accuracy: 0.5711
#
# Epoch 00046: val_accuracy did not improve from 0.59040
# Epoch 47/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0496 - accuracy: 0.6646 - val_loss: 1.3542 - val_accuracy: 0.5286
#
# Epoch 00047: val_accuracy did not improve from 0.59040
# Epoch 48/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.0386 - accuracy: 0.6705 - val_loss: 1.3726 - val_accuracy: 0.5507
#
# Epoch 00048: val_accuracy did not improve from 0.59040
# Epoch 49/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0542 - accuracy: 0.6658 - val_loss: 1.3253 - val_accuracy: 0.5769
#
# Epoch 00049: val_accuracy did not improve from 0.59040
# Epoch 50/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.0510 - accuracy: 0.6631 - val_loss: 1.2329 - val_accuracy: 0.6049
#
# Epoch 00050: val_accuracy improved from 0.59040 to 0.60495, saving model to /content/saved_models/FER2013_model.h5
# Epoch 51/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 471ms/step - loss: 1.0479 - accuracy: 0.6704 - val_loss: 1.1779 - val_accuracy: 0.6173
#
# Epoch 00051: val_accuracy improved from 0.60495 to 0.61732, saving model to /content/saved_models/FER2013_model.h5
# Epoch 52/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.0390 - accuracy: 0.6699 - val_loss: 1.5728 - val_accuracy: 0.4707
#
# Epoch 00052: val_accuracy did not improve from 0.61732
# Epoch 53/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0471 - accuracy: 0.6678 - val_loss: 1.2482 - val_accuracy: 0.5969
#
# Epoch 00053: val_accuracy did not improve from 0.61732
# Epoch 54/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.0482 - accuracy: 0.6676 - val_loss: 1.1827 - val_accuracy: 0.6159
#
# Epoch 00054: val_accuracy did not improve from 0.61732
# Epoch 55/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.0358 - accuracy: 0.6716 - val_loss: 1.3188 - val_accuracy: 0.5798
#
# Epoch 00055: val_accuracy did not improve from 0.61732
# Epoch 56/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.0374 - accuracy: 0.6732 - val_loss: 1.3830 - val_accuracy: 0.5387
#
# Epoch 00056: val_accuracy did not improve from 0.61732
# Epoch 57/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 476ms/step - loss: 1.0305 - accuracy: 0.6723 - val_loss: 1.1888 - val_accuracy: 0.6140
#
# Epoch 00057: val_accuracy did not improve from 0.61732
# Epoch 58/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0285 - accuracy: 0.6727 - val_loss: 1.2171 - val_accuracy: 0.6115
#
# Epoch 00058: val_accuracy did not improve from 0.61732
# Epoch 59/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.0263 - accuracy: 0.6765 - val_loss: 1.3201 - val_accuracy: 0.5711
#
# Epoch 00059: val_accuracy did not improve from 0.61732
# Epoch 60/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.0371 - accuracy: 0.6719 - val_loss: 1.4469 - val_accuracy: 0.5507
#
# Epoch 00060: val_accuracy did not improve from 0.61732
# Epoch 61/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.9691 - accuracy: 0.6999 - val_loss: 1.1328 - val_accuracy: 0.6344
#
# Epoch 00061: val_accuracy improved from 0.61732 to 0.63441, saving model to /content/saved_models/FER2013_model.h5
# Epoch 62/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.9240 - accuracy: 0.7127 - val_loss: 1.1138 - val_accuracy: 0.6468
#
# Epoch 00062: val_accuracy improved from 0.63441 to 0.64678, saving model to /content/saved_models/FER2013_model.h5
# Epoch 63/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.9080 - accuracy: 0.7205 - val_loss: 1.0534 - val_accuracy: 0.6621
#
# Epoch 00063: val_accuracy improved from 0.64678 to 0.66206, saving model to /content/saved_models/FER2013_model.h5
# Epoch 64/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8943 - accuracy: 0.7220 - val_loss: 1.0341 - val_accuracy: 0.6770
#
# Epoch 00064: val_accuracy improved from 0.66206 to 0.67697, saving model to /content/saved_models/FER2013_model.h5
# Epoch 65/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.8885 - accuracy: 0.7238 - val_loss: 1.0448 - val_accuracy: 0.6722
#
# Epoch 00065: val_accuracy did not improve from 0.67697
# Epoch 66/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8688 - accuracy: 0.7330 - val_loss: 1.0098 - val_accuracy: 0.6777
#
# Epoch 00066: val_accuracy improved from 0.67697 to 0.67770, saving model to /content/saved_models/FER2013_model.h5
# Epoch 67/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8625 - accuracy: 0.7326 - val_loss: 1.0307 - val_accuracy: 0.6737
#
# Epoch 00067: val_accuracy did not improve from 0.67770
# Epoch 68/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8524 - accuracy: 0.7346 - val_loss: 1.0174 - val_accuracy: 0.6748
#
# Epoch 00068: val_accuracy did not improve from 0.67770
# Epoch 69/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.8454 - accuracy: 0.7373 - val_loss: 1.0194 - val_accuracy: 0.6781
#
# Epoch 00069: val_accuracy improved from 0.67770 to 0.67806, saving model to /content/saved_models/FER2013_model.h5
# Epoch 70/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8388 - accuracy: 0.7386 - val_loss: 1.0368 - val_accuracy: 0.6657
#
# Epoch 00070: val_accuracy did not improve from 0.67806
# Epoch 71/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8327 - accuracy: 0.7398 - val_loss: 1.0238 - val_accuracy: 0.6690
#
# Epoch 00071: val_accuracy did not improve from 0.67806
# Epoch 72/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.8245 - accuracy: 0.7450 - val_loss: 1.0195 - val_accuracy: 0.6733
#
# Epoch 00072: val_accuracy did not improve from 0.67806
# Epoch 73/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.8106 - accuracy: 0.7489 - val_loss: 1.0144 - val_accuracy: 0.6722
#
# Epoch 00073: val_accuracy did not improve from 0.67806
# Epoch 74/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.8064 - accuracy: 0.7493 - val_loss: 1.0310 - val_accuracy: 0.6679
#
# Epoch 00074: val_accuracy did not improve from 0.67806
# Epoch 75/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.8005 - accuracy: 0.7512 - val_loss: 1.0121 - val_accuracy: 0.6828
#
# Epoch 00075: val_accuracy improved from 0.67806 to 0.68279, saving model to /content/saved_models/FER2013_model.h5
# Epoch 76/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7941 - accuracy: 0.7507 - val_loss: 1.0418 - val_accuracy: 0.6661
#
# Epoch 00076: val_accuracy did not improve from 0.68279
# Epoch 77/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7948 - accuracy: 0.7522 - val_loss: 1.0434 - val_accuracy: 0.6642
#
# Epoch 00077: val_accuracy did not improve from 0.68279
# Epoch 78/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7821 - accuracy: 0.7589 - val_loss: 1.0489 - val_accuracy: 0.6595
#
# Epoch 00078: val_accuracy did not improve from 0.68279
# Epoch 79/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.7765 - accuracy: 0.7595 - val_loss: 1.0232 - val_accuracy: 0.6726
#
# Epoch 00079: val_accuracy did not improve from 0.68279
# Epoch 80/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7694 - accuracy: 0.7622 - val_loss: 1.0150 - val_accuracy: 0.6755
#
# Epoch 00080: val_accuracy did not improve from 0.68279
# Epoch 81/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7678 - accuracy: 0.7631 - val_loss: 1.0475 - val_accuracy: 0.6657
#
# Epoch 00081: val_accuracy did not improve from 0.68279
# Epoch 82/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7559 - accuracy: 0.7661 - val_loss: 1.0458 - val_accuracy: 0.6752
#
# Epoch 00082: val_accuracy did not improve from 0.68279
# Epoch 83/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.7606 - accuracy: 0.7658 - val_loss: 1.0790 - val_accuracy: 0.6657
#
# Epoch 00083: val_accuracy did not improve from 0.68279
# Epoch 84/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7506 - accuracy: 0.7665 - val_loss: 1.0539 - val_accuracy: 0.6657
#
# Epoch 00084: val_accuracy did not improve from 0.68279
# Epoch 85/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7460 - accuracy: 0.7680 - val_loss: 1.0435 - val_accuracy: 0.6730
#
# Epoch 00085: val_accuracy did not improve from 0.68279
# Epoch 86/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7414 - accuracy: 0.7714 - val_loss: 1.0474 - val_accuracy: 0.6748
#
# Epoch 00086: val_accuracy did not improve from 0.68279
# Epoch 87/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7322 - accuracy: 0.7750 - val_loss: 1.0368 - val_accuracy: 0.6704
#
# Epoch 00087: val_accuracy did not improve from 0.68279
# Epoch 88/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7307 - accuracy: 0.7710 - val_loss: 1.0984 - val_accuracy: 0.6639
#
# Epoch 00088: val_accuracy did not improve from 0.68279
# Epoch 89/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7295 - accuracy: 0.7736 - val_loss: 1.0510 - val_accuracy: 0.6755
#
# Epoch 00089: val_accuracy did not improve from 0.68279
# Epoch 90/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7270 - accuracy: 0.7744 - val_loss: 1.0406 - val_accuracy: 0.6733
#
# Epoch 00090: val_accuracy did not improve from 0.68279
# Epoch 91/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7153 - accuracy: 0.7817 - val_loss: 1.0474 - val_accuracy: 0.6773
#
# Epoch 00091: val_accuracy did not improve from 0.68279
# Epoch 92/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7128 - accuracy: 0.7792 - val_loss: 1.0990 - val_accuracy: 0.6577
#
# Epoch 00092: val_accuracy did not improve from 0.68279
# Epoch 93/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7097 - accuracy: 0.7809 - val_loss: 1.0484 - val_accuracy: 0.6748
#
# Epoch 00093: val_accuracy did not improve from 0.68279
# Epoch 94/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7020 - accuracy: 0.7830 - val_loss: 1.0510 - val_accuracy: 0.6697
#
# Epoch 00094: val_accuracy did not improve from 0.68279
# Epoch 95/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.7010 - accuracy: 0.7863 - val_loss: 1.1049 - val_accuracy: 0.6613
#
# Epoch 00095: val_accuracy did not improve from 0.68279
# Epoch 96/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6944 - accuracy: 0.7837 - val_loss: 1.0724 - val_accuracy: 0.6672
#
# Epoch 00096: val_accuracy did not improve from 0.68279
# Epoch 97/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6969 - accuracy: 0.7864 - val_loss: 1.0994 - val_accuracy: 0.6566
#
# Epoch 00097: val_accuracy did not improve from 0.68279
# Epoch 98/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.6909 - accuracy: 0.7878 - val_loss: 1.0864 - val_accuracy: 0.6650
#
# Epoch 00098: val_accuracy did not improve from 0.68279
# Epoch 99/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6864 - accuracy: 0.7884 - val_loss: 1.0869 - val_accuracy: 0.6762
#
# Epoch 00099: val_accuracy did not improve from 0.68279
# Epoch 100/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6810 - accuracy: 0.7898 - val_loss: 1.1223 - val_accuracy: 0.6628
#
# Epoch 00100: val_accuracy did not improve from 0.68279
# Epoch 101/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6712 - accuracy: 0.7935 - val_loss: 1.0588 - val_accuracy: 0.6788
#
# Epoch 00101: val_accuracy did not improve from 0.68279
# Epoch 102/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6757 - accuracy: 0.7926 - val_loss: 1.0990 - val_accuracy: 0.6744
#
# Epoch 00102: val_accuracy did not improve from 0.68279
# Epoch 103/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6630 - accuracy: 0.8001 - val_loss: 1.1935 - val_accuracy: 0.6497
#
# Epoch 00103: val_accuracy did not improve from 0.68279
# Epoch 104/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.6676 - accuracy: 0.7969 - val_loss: 1.1116 - val_accuracy: 0.6715
#
# Epoch 00104: val_accuracy did not improve from 0.68279
# Epoch 105/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6627 - accuracy: 0.8008 - val_loss: 1.1232 - val_accuracy: 0.6595
#
# Epoch 00105: val_accuracy did not improve from 0.68279
# Epoch 106/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6572 - accuracy: 0.7968 - val_loss: 1.1187 - val_accuracy: 0.6657
#
# Epoch 00106: val_accuracy did not improve from 0.68279
# Epoch 107/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6572 - accuracy: 0.8018 - val_loss: 1.1078 - val_accuracy: 0.6733
#
# Epoch 00107: val_accuracy did not improve from 0.68279
# Epoch 108/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.6552 - accuracy: 0.7999 - val_loss: 1.1182 - val_accuracy: 0.6701
#
# Epoch 00108: val_accuracy did not improve from 0.68279
# Epoch 109/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6466 - accuracy: 0.8039 - val_loss: 1.1281 - val_accuracy: 0.6744
#
# Epoch 00109: val_accuracy did not improve from 0.68279
# Epoch 110/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6444 - accuracy: 0.8024 - val_loss: 1.1385 - val_accuracy: 0.6682
#
# Epoch 00110: val_accuracy did not improve from 0.68279
# Epoch 111/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.6417 - accuracy: 0.8049 - val_loss: 1.1571 - val_accuracy: 0.6675
#
# Epoch 00111: val_accuracy did not improve from 0.68279
# Epoch 112/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6338 - accuracy: 0.8082 - val_loss: 1.0984 - val_accuracy: 0.6722
#
# Epoch 00112: val_accuracy did not improve from 0.68279
# Epoch 113/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6355 - accuracy: 0.8070 - val_loss: 1.1182 - val_accuracy: 0.6752
#
# Epoch 00113: val_accuracy did not improve from 0.68279
# Epoch 114/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6316 - accuracy: 0.8106 - val_loss: 1.1768 - val_accuracy: 0.6577
#
# Epoch 00114: val_accuracy did not improve from 0.68279
# Epoch 115/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6271 - accuracy: 0.8098 - val_loss: 1.1856 - val_accuracy: 0.6664
#
# Epoch 00115: val_accuracy did not improve from 0.68279
# Epoch 116/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6290 - accuracy: 0.8116 - val_loss: 1.1438 - val_accuracy: 0.6690
#
# Epoch 00116: val_accuracy did not improve from 0.68279
# Epoch 117/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6160 - accuracy: 0.8136 - val_loss: 1.1685 - val_accuracy: 0.6712
#
# Epoch 00117: val_accuracy did not improve from 0.68279
# Epoch 118/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 458ms/step - loss: 0.6213 - accuracy: 0.8152 - val_loss: 1.1362 - val_accuracy: 0.6624
#
# Epoch 00118: val_accuracy did not improve from 0.68279
# Epoch 119/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.6212 - accuracy: 0.8114 - val_loss: 1.1499 - val_accuracy: 0.6719
#
# Epoch 00119: val_accuracy did not improve from 0.68279
# Epoch 120/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.6122 - accuracy: 0.8172 - val_loss: 1.1254 - val_accuracy: 0.6719
#
# Epoch 00120: val_accuracy did not improve from 0.68279
# Epoch 121/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6116 - accuracy: 0.8191 - val_loss: 1.1486 - val_accuracy: 0.6766
#
# Epoch 00121: val_accuracy did not improve from 0.68279
# Epoch 122/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6118 - accuracy: 0.8181 - val_loss: 1.1342 - val_accuracy: 0.6773
#
# Epoch 00122: val_accuracy did not improve from 0.68279
# Epoch 123/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6139 - accuracy: 0.8169 - val_loss: 1.1461 - val_accuracy: 0.6726
#
# Epoch 00123: val_accuracy did not improve from 0.68279
# Epoch 124/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 476ms/step - loss: 0.6026 - accuracy: 0.8231 - val_loss: 1.1799 - val_accuracy: 0.6686
#
# Epoch 00124: val_accuracy did not improve from 0.68279
# Epoch 125/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5993 - accuracy: 0.8215 - val_loss: 1.1682 - val_accuracy: 0.6730
#
# Epoch 00125: val_accuracy did not improve from 0.68279
# Epoch 126/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6024 - accuracy: 0.8209 - val_loss: 1.1988 - val_accuracy: 0.6639
#
# Epoch 00126: val_accuracy did not improve from 0.68279
# Epoch 127/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5967 - accuracy: 0.8212 - val_loss: 1.1830 - val_accuracy: 0.6759
#
# Epoch 00127: val_accuracy did not improve from 0.68279
# Epoch 128/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5891 - accuracy: 0.8256 - val_loss: 1.2285 - val_accuracy: 0.6726
#
# Epoch 00128: val_accuracy did not improve from 0.68279
# Epoch 129/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5891 - accuracy: 0.8252 - val_loss: 1.1873 - val_accuracy: 0.6752
#
# Epoch 00129: val_accuracy did not improve from 0.68279
# Epoch 130/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5883 - accuracy: 0.8256 - val_loss: 1.2129 - val_accuracy: 0.6668
#
# Epoch 00130: val_accuracy did not improve from 0.68279
# Epoch 131/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5826 - accuracy: 0.8280 - val_loss: 1.2631 - val_accuracy: 0.6544
#
# Epoch 00131: val_accuracy did not improve from 0.68279
# Epoch 132/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5845 - accuracy: 0.8259 - val_loss: 1.2299 - val_accuracy: 0.6530
#
# Epoch 00132: val_accuracy did not improve from 0.68279
# Epoch 133/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5858 - accuracy: 0.8264 - val_loss: 1.1758 - val_accuracy: 0.6821
#
# Epoch 00133: val_accuracy did not improve from 0.68279
# Epoch 134/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5749 - accuracy: 0.8294 - val_loss: 1.2297 - val_accuracy: 0.6693
#
# Epoch 00134: val_accuracy did not improve from 0.68279
# Epoch 135/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.5684 - accuracy: 0.8337 - val_loss: 1.2677 - val_accuracy: 0.6417
#
# Epoch 00135: val_accuracy did not improve from 0.68279
# Epoch 136/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5790 - accuracy: 0.8293 - val_loss: 1.2666 - val_accuracy: 0.6541
#
# Epoch 00136: val_accuracy did not improve from 0.68279
# Epoch 137/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5721 - accuracy: 0.8299 - val_loss: 1.1871 - val_accuracy: 0.6599
#
# Epoch 00137: val_accuracy did not improve from 0.68279
# Epoch 138/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5694 - accuracy: 0.8332 - val_loss: 1.1888 - val_accuracy: 0.6893
#
# Epoch 00138: val_accuracy improved from 0.68279 to 0.68934, saving model to /content/saved_models/FER2013_model.h5
# Epoch 139/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5564 - accuracy: 0.8380 - val_loss: 1.3033 - val_accuracy: 0.6537
#
# Epoch 00139: val_accuracy did not improve from 0.68934
# Epoch 140/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5680 - accuracy: 0.8352 - val_loss: 1.2397 - val_accuracy: 0.6737
#
# Epoch 00140: val_accuracy did not improve from 0.68934
# Epoch 141/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5555 - accuracy: 0.8394 - val_loss: 1.2216 - val_accuracy: 0.6777
#
# Epoch 00141: val_accuracy did not improve from 0.68934
# Epoch 142/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5619 - accuracy: 0.8355 - val_loss: 1.2572 - val_accuracy: 0.6639
#
# Epoch 00142: val_accuracy did not improve from 0.68934
# Epoch 143/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5519 - accuracy: 0.8387 - val_loss: 1.2202 - val_accuracy: 0.6755
#
# Epoch 00143: val_accuracy did not improve from 0.68934
# Epoch 144/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.5612 - accuracy: 0.8336 - val_loss: 1.2722 - val_accuracy: 0.6588
#
# Epoch 00144: val_accuracy did not improve from 0.68934
# Epoch 145/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5597 - accuracy: 0.8343 - val_loss: 1.2361 - val_accuracy: 0.6792
#
# Epoch 00145: val_accuracy did not improve from 0.68934
# Epoch 146/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5447 - accuracy: 0.8399 - val_loss: 1.2351 - val_accuracy: 0.6744
#
# Epoch 00146: val_accuracy did not improve from 0.68934
# Epoch 147/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5448 - accuracy: 0.8432 - val_loss: 1.2529 - val_accuracy: 0.6628
#
# Epoch 00147: val_accuracy did not improve from 0.68934
# Epoch 148/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5536 - accuracy: 0.8396 - val_loss: 1.2226 - val_accuracy: 0.6650
#
# Epoch 00148: val_accuracy did not improve from 0.68934
# Epoch 149/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5430 - accuracy: 0.8418 - val_loss: 1.2397 - val_accuracy: 0.6686
#
# Epoch 00149: val_accuracy did not improve from 0.68934
# Epoch 150/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.5417 - accuracy: 0.8455 - val_loss: 1.2947 - val_accuracy: 0.6664
#
# Epoch 00150: val_accuracy did not improve from 0.68934
# Epoch 151/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5421 - accuracy: 0.8442 - val_loss: 1.3382 - val_accuracy: 0.6559
#
# Epoch 00151: val_accuracy did not improve from 0.68934
# Epoch 152/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5416 - accuracy: 0.8407 - val_loss: 1.2364 - val_accuracy: 0.6661
#
# Epoch 00152: val_accuracy did not improve from 0.68934
# Epoch 153/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5368 - accuracy: 0.8442 - val_loss: 1.2527 - val_accuracy: 0.6675
#
# Epoch 00153: val_accuracy did not improve from 0.68934
# Epoch 154/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.5325 - accuracy: 0.8454 - val_loss: 1.2640 - val_accuracy: 0.6682
#
# Epoch 00154: val_accuracy did not improve from 0.68934
# Epoch 155/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5342 - accuracy: 0.8468 - val_loss: 1.2257 - val_accuracy: 0.6752
#
# Epoch 00155: val_accuracy did not improve from 0.68934
# Epoch 156/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5251 - accuracy: 0.8490 - val_loss: 1.2504 - val_accuracy: 0.6682
#
# Epoch 00156: val_accuracy did not improve from 0.68934
# Epoch 157/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5225 - accuracy: 0.8512 - val_loss: 1.3003 - val_accuracy: 0.6588
#
# Epoch 00157: val_accuracy did not improve from 0.68934
# Epoch 158/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5271 - accuracy: 0.8477 - val_loss: 1.3357 - val_accuracy: 0.6562
#
# Epoch 00158: val_accuracy did not improve from 0.68934
# Epoch 159/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5285 - accuracy: 0.8486 - val_loss: 1.3098 - val_accuracy: 0.6591
#
# Epoch 00159: val_accuracy did not improve from 0.68934
# Epoch 160/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5185 - accuracy: 0.8497 - val_loss: 1.2870 - val_accuracy: 0.6657
#
# Epoch 00160: val_accuracy did not improve from 0.68934
# Epoch 161/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.4954 - accuracy: 0.8630 - val_loss: 1.2380 - val_accuracy: 0.6810
#
# Epoch 00161: val_accuracy did not improve from 0.68934
# Epoch 162/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4765 - accuracy: 0.8685 - val_loss: 1.2271 - val_accuracy: 0.6842
#
# Epoch 00162: val_accuracy did not improve from 0.68934
# Epoch 163/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.4674 - accuracy: 0.8735 - val_loss: 1.2324 - val_accuracy: 0.6853
#
# Epoch 00163: val_accuracy did not improve from 0.68934
# Epoch 164/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.4643 - accuracy: 0.8723 - val_loss: 1.2351 - val_accuracy: 0.6912
#
# Epoch 00164: val_accuracy improved from 0.68934 to 0.69116, saving model to /content/saved_models/FER2013_model.h5
# Epoch 165/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.4700 - accuracy: 0.8698 - val_loss: 1.2540 - val_accuracy: 0.6890
#
# Epoch 00165: val_accuracy did not improve from 0.69116
# Epoch 166/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4561 - accuracy: 0.8778 - val_loss: 1.2464 - val_accuracy: 0.6802
#
# Epoch 00166: val_accuracy did not improve from 0.69116
# Epoch 167/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4587 - accuracy: 0.8761 - val_loss: 1.2543 - val_accuracy: 0.6908
#
# Epoch 00167: val_accuracy did not improve from 0.69116
# Epoch 168/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4565 - accuracy: 0.8767 - val_loss: 1.2576 - val_accuracy: 0.6850
#
# Epoch 00168: val_accuracy did not improve from 0.69116
# Epoch 169/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.4502 - accuracy: 0.8769 - val_loss: 1.2645 - val_accuracy: 0.6893
#
# Epoch 00169: val_accuracy did not improve from 0.69116
# Epoch 170/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4523 - accuracy: 0.8789 - val_loss: 1.2825 - val_accuracy: 0.6886
#
# Epoch 00170: val_accuracy did not improve from 0.69116
# Epoch 171/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4470 - accuracy: 0.8802 - val_loss: 1.2700 - val_accuracy: 0.6861
#
# Epoch 00171: val_accuracy did not improve from 0.69116
# Epoch 172/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4471 - accuracy: 0.8793 - val_loss: 1.2946 - val_accuracy: 0.6872
#
# Epoch 00172: val_accuracy did not improve from 0.69116
# Epoch 173/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4447 - accuracy: 0.8832 - val_loss: 1.2804 - val_accuracy: 0.6846
#
# Epoch 00173: val_accuracy did not improve from 0.69116
# Epoch 174/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 476ms/step - loss: 0.4424 - accuracy: 0.8811 - val_loss: 1.2728 - val_accuracy: 0.6890
#
# Epoch 00174: val_accuracy did not improve from 0.69116
# Epoch 175/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4422 - accuracy: 0.8800 - val_loss: 1.2901 - val_accuracy: 0.6853
#
# Epoch 00175: val_accuracy did not improve from 0.69116
# Epoch 176/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.4425 - accuracy: 0.8828 - val_loss: 1.2999 - val_accuracy: 0.6875
#
# Epoch 00176: val_accuracy did not improve from 0.69116
# Epoch 177/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4386 - accuracy: 0.8840 - val_loss: 1.3053 - val_accuracy: 0.6824
#
# Epoch 00177: val_accuracy did not improve from 0.69116
# Epoch 178/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.4448 - accuracy: 0.8823 - val_loss: 1.3057 - val_accuracy: 0.6850
#
# Epoch 00178: val_accuracy did not improve from 0.69116
# Epoch 179/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.4408 - accuracy: 0.8838 - val_loss: 1.2950 - val_accuracy: 0.6893
#
# Epoch 00179: val_accuracy did not improve from 0.69116
# Epoch 180/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.4319 - accuracy: 0.8867 - val_loss: 1.2898 - val_accuracy: 0.6828
#
# Epoch 00180: val_accuracy did not improve from 0.69116
# Epoch 181/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4348 - accuracy: 0.8833 - val_loss: 1.3001 - val_accuracy: 0.6835
#
# Epoch 00181: val_accuracy did not improve from 0.69116
# Epoch 182/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4302 - accuracy: 0.8872 - val_loss: 1.3033 - val_accuracy: 0.6835
#
# Epoch 00182: val_accuracy did not improve from 0.69116
# Epoch 183/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.4348 - accuracy: 0.8842 - val_loss: 1.3043 - val_accuracy: 0.6828
#
# Epoch 00183: val_accuracy did not improve from 0.69116
# Epoch 184/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.4347 - accuracy: 0.8836 - val_loss: 1.3135 - val_accuracy: 0.6842
#
# Epoch 00184: val_accuracy did not improve from 0.69116
# Epoch 185/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.4348 - accuracy: 0.8836 - val_loss: 1.3071 - val_accuracy: 0.6861
#
# Epoch 00185: val_accuracy did not improve from 0.69116
# Epoch 186/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.4283 - accuracy: 0.8881 - val_loss: 1.3155 - val_accuracy: 0.6842
#
# Epoch 00186: val_accuracy did not improve from 0.69116
# Epoch 187/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.4305 - accuracy: 0.8861 - val_loss: 1.3050 - val_accuracy: 0.6802
#
# Epoch 00187: val_accuracy did not improve from 0.69116
# Epoch 188/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.4315 - accuracy: 0.8847 - val_loss: 1.3231 - val_accuracy: 0.6839
#
# Epoch 00188: val_accuracy did not improve from 0.69116
# Epoch 189/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4323 - accuracy: 0.8847 - val_loss: 1.3103 - val_accuracy: 0.6802
#
# Epoch 00189: val_accuracy did not improve from 0.69116
# Epoch 190/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4294 - accuracy: 0.8851 - val_loss: 1.3286 - val_accuracy: 0.6810
#
# Epoch 00190: val_accuracy did not improve from 0.69116
# Epoch 191/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4273 - accuracy: 0.8867 - val_loss: 1.3209 - val_accuracy: 0.6795
#
# Epoch 00191: val_accuracy did not improve from 0.69116
# Epoch 192/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.4239 - accuracy: 0.8879 - val_loss: 1.3229 - val_accuracy: 0.6817
#
# Epoch 00192: val_accuracy did not improve from 0.69116
# Epoch 193/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4291 - accuracy: 0.8859 - val_loss: 1.3313 - val_accuracy: 0.6850
#
# Epoch 00193: val_accuracy did not improve from 0.69116
# Epoch 194/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.4288 - accuracy: 0.8866 - val_loss: 1.3153 - val_accuracy: 0.6861
#
# Epoch 00194: val_accuracy did not improve from 0.69116
# Epoch 195/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.4212 - accuracy: 0.8895 - val_loss: 1.3257 - val_accuracy: 0.6832
#
# Epoch 00195: val_accuracy did not improve from 0.69116
# Epoch 196/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.4246 - accuracy: 0.8874 - val_loss: 1.3333 - val_accuracy: 0.6802
#
# Epoch 00196: val_accuracy did not improve from 0.69116
# Epoch 197/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.4172 - accuracy: 0.8891 - val_loss: 1.3294 - val_accuracy: 0.6784
#
# Epoch 00197: val_accuracy did not improve from 0.69116
# Epoch 198/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4184 - accuracy: 0.8907 - val_loss: 1.3401 - val_accuracy: 0.6777
#
# Epoch 00198: val_accuracy did not improve from 0.69116
# Epoch 199/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.4210 - accuracy: 0.8912 - val_loss: 1.3244 - val_accuracy: 0.6759
#
# Epoch 00199: val_accuracy did not improve from 0.69116
# Epoch 200/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.4177 - accuracy: 0.8879 - val_loss: 1.3111 - val_accuracy: 0.6773
#
# Epoch 00200: val_accuracy did not improve from 0.69116
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
best_model = keras.models.load_model('/content/saved_models/FER2013_model.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 87/87 [==============================] - 4s 24ms/step - loss: 1.1314 - accuracy: 0.7089
# [1.1313532590866089, 0.7088929414749146]

# %%
#test images
from sklearn.metrics import confusion_matrix
import seaborn as sn
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE

print('Labels Dictionary:')
print(emotion)
print('Number of predition samples = ', len(x_test))
pred = model.predict(x_test)
cm = confusion_matrix( np.argmax(y_test,1),pred.argmax(1),normalize='pred')
#cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize =(10,6))
sn.heatmap(cm, annot=True, annot_kws={"size": 12},cmap=plt.cm.Blues) # font size
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Labels Dictionary:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
# Number of predition samples =  2755

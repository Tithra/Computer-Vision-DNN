# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

img_H = 0
img_W = 0
img_D = 0

#Reshare csv array to image
def data_reshape(x,y,shape=48,depth=1):
  x = np.array(x)
  x = x.reshape(len(x),shape,shape,depth)
  y = np.array(y)
  return x, y

#Load FAFFE
def load_FAFEE():
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/y_val.csv",header=None)
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/x_train.csv",header=None)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/JAFFE/y_train.csv",header=None)

  x = [x_train,x_val]
  y = [y_train,y_val]
  x = pd.concat(x)
  y = pd.concat(y)

  x, y = data_reshape(x, y, 256)
  x, y = shuffle(x, y,random_state = 2021)
  
  img_H = x.shape[1]
  img_W = x.shape[2]
  img_D = x.shape[3]
  print (x.shape,y.shape)
  return x, y


#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  
  x, y = data_reshape(x, y)

  img_H = x.shape[1]
  img_W = x.shape[2]
  img_D = x.shape[3]
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=98, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=98, random_state=2021)

  x_train, y_train = data_reshape(x_train, y_train)
  x_val, y_val = data_reshape(x_val, y_val)
  x_test, y_test = data_reshape(x_test, y_test)

  img_H = x_train.shape[1]
  img_W = x_train.shape[2]
  img_D = x_train.shape[3]
  print(x_train.shape,y_train.shape)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_val.csv",header=None)

  x_train, y_train = data_reshape(x_train, y_train)
  x_val, y_val = data_reshape(x_val, y_val)
  x_test, y_test = data_reshape(x_test, y_test)

  img_H = x_train.shape[1]
  img_W = x_train.shape[2]
  img_D = x_train.shape[3]
  print(x_train.shape,y_train.shape)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_CKplus_split()
# Out:
# (785, 48, 48, 1) (785, 1)

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 24 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=0ab445c41aa07a2a744e3a909c2cc5a544576f78c622cca7296d39ff8bd442e4
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

new_H = 48
new_W = 48
def transform(img):
  if len(img.shape)>2:
    img = img.reshape(new_H,new_W)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*100)/math.log(mean)
  img = np.power(img, gamma).clip(0,100).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=new_H, output_width=new_W):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    
    if (len(face_detect_2)>0):
      #(x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (new_H, new_W))
      
      img = transform(img)
      img = img.reshape(new_H, new_W,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_1)>0):
      #(y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(new_H, new_W))
      
      img = transform(img)
      img = img.reshape(new_H, new_W,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

img_H = new_H
img_W = new_W

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
#emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_test,y_test)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM with cross validation

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import os

# Training parameters
batch_size = 50
epochs = 80
data_augmentation = True
num_classes = 7
subtract_pixel_mean = False  # Subtracting pixel mean improves accuracy
base_model = 'MobileNet'
# Choose what attention_module to use: cbam_block / se_block / None
attention_module = 'cbam_block'
database_type = 'CKplus'


# Load the copy of Dataset
x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255

# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()


# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = database_type + 'model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.5):
      lr = 0.001
    elif epoch >=(epochs*0.2):
      lr=0.005
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    #history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val), shuffle=True,callbacks=callbacks)
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    #history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)


def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Using real-time data augmentation.
# Epoch 1/80
# Learning rate:  0.01
# 16/16 [==============================] - 10s 185ms/step - loss: 1.9967 - accuracy: 0.2828 - val_loss: 2.2078 - val_accuracy: 0.2551
#
# Epoch 00001: val_accuracy improved from -inf to 0.25510, saving model to /content/saved_models/CKplusmodel.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 81ms/step - loss: 1.7907 - accuracy: 0.4051 - val_loss: 4.7343 - val_accuracy: 0.2449
#
# Epoch 00002: val_accuracy did not improve from 0.25510
# Epoch 3/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 73ms/step - loss: 1.4585 - accuracy: 0.5045 - val_loss: 3.7437 - val_accuracy: 0.2143
#
# Epoch 00003: val_accuracy did not improve from 0.25510
# Epoch 4/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 77ms/step - loss: 1.1309 - accuracy: 0.6318 - val_loss: 4.9395 - val_accuracy: 0.1735
#
# Epoch 00004: val_accuracy did not improve from 0.25510
# Epoch 5/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 78ms/step - loss: 0.9512 - accuracy: 0.7223 - val_loss: 4.5217 - val_accuracy: 0.3061
#
# Epoch 00005: val_accuracy improved from 0.25510 to 0.30612, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 6/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 76ms/step - loss: 0.8539 - accuracy: 0.7516 - val_loss: 14.2884 - val_accuracy: 0.1531
#
# Epoch 00006: val_accuracy did not improve from 0.30612
# Epoch 7/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 75ms/step - loss: 0.7814 - accuracy: 0.7809 - val_loss: 6.3261 - val_accuracy: 0.0918
#
# Epoch 00007: val_accuracy did not improve from 0.30612
# Epoch 8/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 74ms/step - loss: 0.7639 - accuracy: 0.7949 - val_loss: 7.7633 - val_accuracy: 0.0714
#
# Epoch 00008: val_accuracy did not improve from 0.30612
# Epoch 9/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 79ms/step - loss: 0.6740 - accuracy: 0.8446 - val_loss: 6.3769 - val_accuracy: 0.0612
#
# Epoch 00009: val_accuracy did not improve from 0.30612
# Epoch 10/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 73ms/step - loss: 0.5993 - accuracy: 0.8599 - val_loss: 14.6537 - val_accuracy: 0.1735
#
# Epoch 00010: val_accuracy did not improve from 0.30612
# Epoch 11/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 78ms/step - loss: 0.6003 - accuracy: 0.8662 - val_loss: 6.6839 - val_accuracy: 0.2041
#
# Epoch 00011: val_accuracy did not improve from 0.30612
# Epoch 12/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 73ms/step - loss: 0.5689 - accuracy: 0.8611 - val_loss: 7.0777 - val_accuracy: 0.0612
#
# Epoch 00012: val_accuracy did not improve from 0.30612
# Epoch 13/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 78ms/step - loss: 0.5135 - accuracy: 0.8968 - val_loss: 4.7741 - val_accuracy: 0.1429
#
# Epoch 00013: val_accuracy did not improve from 0.30612
# Epoch 14/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 78ms/step - loss: 0.4546 - accuracy: 0.9146 - val_loss: 4.2259 - val_accuracy: 0.2347
#
# Epoch 00014: val_accuracy did not improve from 0.30612
# Epoch 15/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 81ms/step - loss: 0.4397 - accuracy: 0.9236 - val_loss: 5.5071 - val_accuracy: 0.2653
#
# Epoch 00015: val_accuracy did not improve from 0.30612
# Epoch 16/80
# Learning rate:  0.01
# 16/16 [==============================] - 1s 80ms/step - loss: 0.4270 - accuracy: 0.9248 - val_loss: 5.7153 - val_accuracy: 0.2755
#
# Epoch 00016: val_accuracy did not improve from 0.30612
# Epoch 17/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 76ms/step - loss: 0.3866 - accuracy: 0.9287 - val_loss: 4.0346 - val_accuracy: 0.1735
#
# Epoch 00017: val_accuracy did not improve from 0.30612
# Epoch 18/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 80ms/step - loss: 0.2979 - accuracy: 0.9694 - val_loss: 4.4549 - val_accuracy: 0.2245
#
# Epoch 00018: val_accuracy did not improve from 0.30612
# Epoch 19/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 80ms/step - loss: 0.2805 - accuracy: 0.9656 - val_loss: 3.4767 - val_accuracy: 0.2041
#
# Epoch 00019: val_accuracy did not improve from 0.30612
# Epoch 20/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 73ms/step - loss: 0.2810 - accuracy: 0.9694 - val_loss: 4.1392 - val_accuracy: 0.1633
#
# Epoch 00020: val_accuracy did not improve from 0.30612
# Epoch 21/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 74ms/step - loss: 0.2590 - accuracy: 0.9720 - val_loss: 3.7573 - val_accuracy: 0.3163
#
# Epoch 00021: val_accuracy improved from 0.30612 to 0.31633, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 22/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2416 - accuracy: 0.9860 - val_loss: 3.4156 - val_accuracy: 0.2755
#
# Epoch 00022: val_accuracy did not improve from 0.31633
# Epoch 23/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 73ms/step - loss: 0.2340 - accuracy: 0.9783 - val_loss: 2.1634 - val_accuracy: 0.3673
#
# Epoch 00023: val_accuracy improved from 0.31633 to 0.36735, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 24/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 71ms/step - loss: 0.2284 - accuracy: 0.9834 - val_loss: 2.7168 - val_accuracy: 0.2857
#
# Epoch 00024: val_accuracy did not improve from 0.36735
# Epoch 25/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 77ms/step - loss: 0.2302 - accuracy: 0.9809 - val_loss: 2.6861 - val_accuracy: 0.3571
#
# Epoch 00025: val_accuracy did not improve from 0.36735
# Epoch 26/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 78ms/step - loss: 0.2203 - accuracy: 0.9809 - val_loss: 2.1245 - val_accuracy: 0.5000
#
# Epoch 00026: val_accuracy improved from 0.36735 to 0.50000, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 27/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 78ms/step - loss: 0.2386 - accuracy: 0.9783 - val_loss: 1.7091 - val_accuracy: 0.4490
#
# Epoch 00027: val_accuracy did not improve from 0.50000
# Epoch 28/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 76ms/step - loss: 0.2377 - accuracy: 0.9732 - val_loss: 1.1929 - val_accuracy: 0.6122
#
# Epoch 00028: val_accuracy improved from 0.50000 to 0.61224, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 29/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 77ms/step - loss: 0.2271 - accuracy: 0.9771 - val_loss: 1.2619 - val_accuracy: 0.6531
#
# Epoch 00029: val_accuracy improved from 0.61224 to 0.65306, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 30/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 77ms/step - loss: 0.2198 - accuracy: 0.9732 - val_loss: 1.7803 - val_accuracy: 0.4592
#
# Epoch 00030: val_accuracy did not improve from 0.65306
# Epoch 31/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 74ms/step - loss: 0.2130 - accuracy: 0.9822 - val_loss: 1.0173 - val_accuracy: 0.7041
#
# Epoch 00031: val_accuracy improved from 0.65306 to 0.70408, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 32/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 73ms/step - loss: 0.2092 - accuracy: 0.9873 - val_loss: 1.0531 - val_accuracy: 0.6531
#
# Epoch 00032: val_accuracy did not improve from 0.70408
# Epoch 33/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 76ms/step - loss: 0.2063 - accuracy: 0.9822 - val_loss: 1.1069 - val_accuracy: 0.6224
#
# Epoch 00033: val_accuracy did not improve from 0.70408
# Epoch 34/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 80ms/step - loss: 0.2223 - accuracy: 0.9783 - val_loss: 2.4988 - val_accuracy: 0.4184
#
# Epoch 00034: val_accuracy did not improve from 0.70408
# Epoch 35/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2290 - accuracy: 0.9707 - val_loss: 1.8866 - val_accuracy: 0.4184
#
# Epoch 00035: val_accuracy did not improve from 0.70408
# Epoch 36/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 77ms/step - loss: 0.2298 - accuracy: 0.9771 - val_loss: 1.1164 - val_accuracy: 0.6939
#
# Epoch 00036: val_accuracy did not improve from 0.70408
# Epoch 37/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 72ms/step - loss: 0.2013 - accuracy: 0.9847 - val_loss: 0.6417 - val_accuracy: 0.7959
#
# Epoch 00037: val_accuracy improved from 0.70408 to 0.79592, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 38/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 80ms/step - loss: 0.1970 - accuracy: 0.9847 - val_loss: 0.5094 - val_accuracy: 0.8571
#
# Epoch 00038: val_accuracy improved from 0.79592 to 0.85714, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 39/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 78ms/step - loss: 0.2441 - accuracy: 0.9669 - val_loss: 1.1373 - val_accuracy: 0.6735
#
# Epoch 00039: val_accuracy did not improve from 0.85714
# Epoch 40/80
# Learning rate:  0.005
# 16/16 [==============================] - 1s 76ms/step - loss: 0.2040 - accuracy: 0.9809 - val_loss: 0.5490 - val_accuracy: 0.8776
#
# Epoch 00040: val_accuracy improved from 0.85714 to 0.87755, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 41/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 81ms/step - loss: 0.1765 - accuracy: 0.9936 - val_loss: 0.4012 - val_accuracy: 0.9082
#
# Epoch 00041: val_accuracy improved from 0.87755 to 0.90816, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 42/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1653 - accuracy: 0.9936 - val_loss: 0.3272 - val_accuracy: 0.9388
#
# Epoch 00042: val_accuracy improved from 0.90816 to 0.93878, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 43/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 70ms/step - loss: 0.1572 - accuracy: 0.9975 - val_loss: 0.2786 - val_accuracy: 0.9490
#
# Epoch 00043: val_accuracy improved from 0.93878 to 0.94898, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 44/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1571 - accuracy: 0.9962 - val_loss: 0.2089 - val_accuracy: 0.9796
#
# Epoch 00044: val_accuracy improved from 0.94898 to 0.97959, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 45/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 74ms/step - loss: 0.1517 - accuracy: 0.9987 - val_loss: 0.1895 - val_accuracy: 0.9796
#
# Epoch 00045: val_accuracy did not improve from 0.97959
# Epoch 46/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 82ms/step - loss: 0.1457 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9898
#
# Epoch 00046: val_accuracy improved from 0.97959 to 0.98980, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 47/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1437 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 1.0000
#
# Epoch 00047: val_accuracy improved from 0.98980 to 1.00000, saving model to /content/saved_models/CKplusmodel.h5
# Epoch 48/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 80ms/step - loss: 0.1435 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 1.0000
#
# Epoch 00048: val_accuracy did not improve from 1.00000
# Epoch 49/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1408 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 1.0000
#
# Epoch 00049: val_accuracy did not improve from 1.00000
# Epoch 50/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 81ms/step - loss: 0.1387 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 1.0000
#
# Epoch 00050: val_accuracy did not improve from 1.00000
# Epoch 51/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1356 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 1.0000
#
# Epoch 00051: val_accuracy did not improve from 1.00000
# Epoch 52/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1348 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 1.0000
#
# Epoch 00052: val_accuracy did not improve from 1.00000
# Epoch 53/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1342 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 1.0000
#
# Epoch 00053: val_accuracy did not improve from 1.00000
# Epoch 54/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 80ms/step - loss: 0.1321 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 1.0000
#
# Epoch 00054: val_accuracy did not improve from 1.00000
# Epoch 55/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1297 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 1.0000
#
# Epoch 00055: val_accuracy did not improve from 1.00000
# Epoch 56/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1285 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 1.0000
#
# Epoch 00056: val_accuracy did not improve from 1.00000
# Epoch 57/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1270 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 1.0000
#
# Epoch 00057: val_accuracy did not improve from 1.00000
# Epoch 58/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 78ms/step - loss: 0.1275 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 1.0000
#
# Epoch 00058: val_accuracy did not improve from 1.00000
# Epoch 59/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1267 - accuracy: 0.9987 - val_loss: 0.1354 - val_accuracy: 1.0000
#
# Epoch 00059: val_accuracy did not improve from 1.00000
# Epoch 60/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1269 - accuracy: 0.9975 - val_loss: 0.1330 - val_accuracy: 1.0000
#
# Epoch 00060: val_accuracy did not improve from 1.00000
# Epoch 61/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1234 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 1.0000
#
# Epoch 00061: val_accuracy did not improve from 1.00000
# Epoch 62/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 71ms/step - loss: 0.1229 - accuracy: 0.9987 - val_loss: 0.1386 - val_accuracy: 0.9898
#
# Epoch 00062: val_accuracy did not improve from 1.00000
# Epoch 63/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1204 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9898
#
# Epoch 00063: val_accuracy did not improve from 1.00000
# Epoch 64/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1176 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9796
#
# Epoch 00064: val_accuracy did not improve from 1.00000
# Epoch 65/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1160 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9796
#
# Epoch 00065: val_accuracy did not improve from 1.00000
# Epoch 66/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1156 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 1.0000
#
# Epoch 00066: val_accuracy did not improve from 1.00000
# Epoch 67/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1143 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 1.0000
#
# Epoch 00067: val_accuracy did not improve from 1.00000
# Epoch 68/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1146 - accuracy: 0.9987 - val_loss: 0.1251 - val_accuracy: 1.0000
#
# Epoch 00068: val_accuracy did not improve from 1.00000
# Epoch 69/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 78ms/step - loss: 0.1118 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9898
#
# Epoch 00069: val_accuracy did not improve from 1.00000
# Epoch 70/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1129 - accuracy: 0.9987 - val_loss: 0.1220 - val_accuracy: 1.0000
#
# Epoch 00070: val_accuracy did not improve from 1.00000
# Epoch 71/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 78ms/step - loss: 0.1099 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 1.0000
#
# Epoch 00071: val_accuracy did not improve from 1.00000
# Epoch 72/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 82ms/step - loss: 0.1092 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9898
#
# Epoch 00072: val_accuracy did not improve from 1.00000
# Epoch 73/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1090 - accuracy: 0.9987 - val_loss: 0.1418 - val_accuracy: 0.9898
#
# Epoch 00073: val_accuracy did not improve from 1.00000
# Epoch 74/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1104 - accuracy: 0.9975 - val_loss: 0.1152 - val_accuracy: 1.0000
#
# Epoch 00074: val_accuracy did not improve from 1.00000
# Epoch 75/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1097 - accuracy: 0.9975 - val_loss: 0.1178 - val_accuracy: 1.0000
#
# Epoch 00075: val_accuracy did not improve from 1.00000
# Epoch 76/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1097 - accuracy: 0.9975 - val_loss: 0.1300 - val_accuracy: 0.9898
#
# Epoch 00076: val_accuracy did not improve from 1.00000
# Epoch 77/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 81ms/step - loss: 0.1060 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 1.0000
#
# Epoch 00077: val_accuracy did not improve from 1.00000
# Epoch 78/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 74ms/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 1.0000
#
# Epoch 00078: val_accuracy did not improve from 1.00000
# Epoch 79/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 74ms/step - loss: 0.1034 - accuracy: 0.9987 - val_loss: 0.1067 - val_accuracy: 1.0000
#
# Epoch 00079: val_accuracy did not improve from 1.00000
# Epoch 80/80
# Learning rate:  0.001
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1000 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 1.0000
#
# Epoch 00080: val_accuracy did not improve from 1.00000
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
best_model = keras.models.load_model('/content/saved_models/CKplusmodel.h5')
scores = best_model.evaluate(x_test,y_test)
# Out:
# 4/4 [==============================] - 2s 22ms/step - loss: 0.1662 - accuracy: 1.0000

# %%
#test images
from sklearn.metrics import confusion_matrix
import seaborn as sn
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE

print('Labels Dictionary:')
print(emotion)
print('Number of predition samples = ', len(x_test))
pred = best_model.predict(x_test)
cm = confusion_matrix( np.argmax(y_test,1),pred.argmax(1),normalize='pred')
#cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize =(10,6))
sn.heatmap(cm, annot=True, annot_kws={"size": 12},cmap=plt.cm.Blues) # font size
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Labels Dictionary:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
# Number of predition samples =  98

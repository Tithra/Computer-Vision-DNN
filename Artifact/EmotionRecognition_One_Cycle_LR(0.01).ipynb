# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/CKplus/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/FER2013/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 14 kB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=31b79faf879f4e5409009ded11917286e458e6f7c4f9b54c530b0c59825ce630
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*255)/math.log(mean)
  img = np.power(img, gamma).clip(0,255).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, y_train.shape
# Out:
# ((22279, 48, 48, 1), (22279, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
from one_cycle_lr import OneCycleLr

# Training parameters
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
# Choose what attention_module to use: cbam_block / se_block / None
model_type = base_model if attention_module==None else base_model+' '+attention_module


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'model.{epoch:03d}.h5' + model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)
# 1 cycle learning rate
one_c = OneCycleLr(max_lr=0.01, steps_per_epoch=len(x_train), epochs=epochs)


lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [one_c, lr_reducer]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    #history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val), shuffle=True,callbacks=callbacks)
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    #history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Score trained model.
#scores = model.evaluate(x_test, y_test, verbose=1,batch_size=batch_size,)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
#  6/44 [===>..........................] - ETA: 14s - loss: 2.5989 - accuracy: 0.1911WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1686s vs `on_train_batch_end` time: 0.2109s). Check your callbacks.
# 44/44 [==============================] - 29s 495ms/step - loss: 2.1087 - accuracy: 0.2532 - val_loss: 2.0165 - val_accuracy: 0.1953
# Epoch 2/200
# 44/44 [==============================] - 20s 442ms/step - loss: 1.9272 - accuracy: 0.2738 - val_loss: 1.9963 - val_accuracy: 0.2539
# Epoch 3/200
# 44/44 [==============================] - 20s 443ms/step - loss: 1.9037 - accuracy: 0.2848 - val_loss: 1.9964 - val_accuracy: 0.2717
# Epoch 4/200
# 44/44 [==============================] - 20s 449ms/step - loss: 1.8631 - accuracy: 0.3091 - val_loss: 2.0479 - val_accuracy: 0.2681
# Epoch 5/200
# 44/44 [==============================] - 20s 445ms/step - loss: 1.7903 - accuracy: 0.3454 - val_loss: 2.3370 - val_accuracy: 0.2859
# Epoch 6/200
# 44/44 [==============================] - 20s 447ms/step - loss: 1.7101 - accuracy: 0.3881 - val_loss: 2.6646 - val_accuracy: 0.2936
# Epoch 7/200
# 44/44 [==============================] - 20s 447ms/step - loss: 1.6155 - accuracy: 0.4387 - val_loss: 2.0172 - val_accuracy: 0.3125
# Epoch 8/200
# 44/44 [==============================] - 20s 447ms/step - loss: 1.5316 - accuracy: 0.4713 - val_loss: 3.0473 - val_accuracy: 0.2710
# Epoch 9/200
# 44/44 [==============================] - 20s 450ms/step - loss: 1.4766 - accuracy: 0.4935 - val_loss: 1.7666 - val_accuracy: 0.3994
# Epoch 10/200
# 44/44 [==============================] - 20s 448ms/step - loss: 1.4312 - accuracy: 0.5101 - val_loss: 2.2586 - val_accuracy: 0.3958
# Epoch 11/200
# 44/44 [==============================] - 20s 448ms/step - loss: 1.3976 - accuracy: 0.5220 - val_loss: 2.2089 - val_accuracy: 0.3849
# Epoch 12/200
# 44/44 [==============================] - 20s 453ms/step - loss: 1.3653 - accuracy: 0.5350 - val_loss: 1.7000 - val_accuracy: 0.4744
# Epoch 13/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.3441 - accuracy: 0.5423 - val_loss: 1.4632 - val_accuracy: 0.5133
# Epoch 14/200
# 44/44 [==============================] - 20s 453ms/step - loss: 1.3115 - accuracy: 0.5519 - val_loss: 1.4074 - val_accuracy: 0.5304
# Epoch 15/200
# 44/44 [==============================] - 20s 454ms/step - loss: 1.2894 - accuracy: 0.5627 - val_loss: 1.4971 - val_accuracy: 0.4900
# Epoch 16/200
# 44/44 [==============================] - 21s 456ms/step - loss: 1.2744 - accuracy: 0.5693 - val_loss: 1.4265 - val_accuracy: 0.5340
# Epoch 17/200
# 44/44 [==============================] - 21s 455ms/step - loss: 1.2528 - accuracy: 0.5758 - val_loss: 1.3675 - val_accuracy: 0.5329
# Epoch 18/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.2292 - accuracy: 0.5868 - val_loss: 1.3186 - val_accuracy: 0.5602
# Epoch 19/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.2097 - accuracy: 0.5963 - val_loss: 1.3331 - val_accuracy: 0.5624
# Epoch 20/200
# 44/44 [==============================] - 21s 457ms/step - loss: 1.1980 - accuracy: 0.5964 - val_loss: 1.2927 - val_accuracy: 0.5551
# Epoch 21/200
# 44/44 [==============================] - 21s 457ms/step - loss: 1.1814 - accuracy: 0.6033 - val_loss: 1.2307 - val_accuracy: 0.5798
# Epoch 22/200
# 44/44 [==============================] - 20s 447ms/step - loss: 1.1701 - accuracy: 0.6101 - val_loss: 1.2869 - val_accuracy: 0.5718
# Epoch 23/200
# 44/44 [==============================] - 20s 451ms/step - loss: 1.1571 - accuracy: 0.6134 - val_loss: 1.2208 - val_accuracy: 0.5842
# Epoch 24/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.1456 - accuracy: 0.6166 - val_loss: 1.2020 - val_accuracy: 0.5962
# Epoch 25/200
# 44/44 [==============================] - 20s 451ms/step - loss: 1.1386 - accuracy: 0.6186 - val_loss: 1.2132 - val_accuracy: 0.5882
# Epoch 26/200
# 44/44 [==============================] - 21s 456ms/step - loss: 1.1327 - accuracy: 0.6215 - val_loss: 1.2341 - val_accuracy: 0.5929
# Epoch 27/200
# 44/44 [==============================] - 21s 456ms/step - loss: 1.1143 - accuracy: 0.6273 - val_loss: 1.2094 - val_accuracy: 0.5919
# Epoch 28/200
# 44/44 [==============================] - 21s 457ms/step - loss: 1.1025 - accuracy: 0.6334 - val_loss: 1.2734 - val_accuracy: 0.5777
# Epoch 29/200
# 44/44 [==============================] - 21s 458ms/step - loss: 1.0876 - accuracy: 0.6402 - val_loss: 1.2422 - val_accuracy: 0.5922
# Epoch 30/200
# 44/44 [==============================] - 20s 454ms/step - loss: 1.0784 - accuracy: 0.6417 - val_loss: 1.2176 - val_accuracy: 0.5915
# Epoch 31/200
# 44/44 [==============================] - 21s 459ms/step - loss: 1.0725 - accuracy: 0.6448 - val_loss: 1.1720 - val_accuracy: 0.6089
# Epoch 32/200
# 44/44 [==============================] - 21s 455ms/step - loss: 1.0657 - accuracy: 0.6486 - val_loss: 1.2257 - val_accuracy: 0.5966
# Epoch 33/200
# 44/44 [==============================] - 20s 453ms/step - loss: 1.0562 - accuracy: 0.6520 - val_loss: 1.1515 - val_accuracy: 0.6151
# Epoch 34/200
# 44/44 [==============================] - 21s 456ms/step - loss: 1.0461 - accuracy: 0.6556 - val_loss: 1.2682 - val_accuracy: 0.5969
# Epoch 35/200
# 44/44 [==============================] - 20s 448ms/step - loss: 1.0357 - accuracy: 0.6597 - val_loss: 1.2420 - val_accuracy: 0.5831
# Epoch 36/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.0314 - accuracy: 0.6589 - val_loss: 1.2120 - val_accuracy: 0.6049
# Epoch 37/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.0155 - accuracy: 0.6687 - val_loss: 1.1820 - val_accuracy: 0.6064
# Epoch 38/200
# 44/44 [==============================] - 20s 455ms/step - loss: 1.0170 - accuracy: 0.6661 - val_loss: 1.2098 - val_accuracy: 0.5926
# Epoch 39/200
# 44/44 [==============================] - 20s 452ms/step - loss: 1.0143 - accuracy: 0.6716 - val_loss: 1.1605 - val_accuracy: 0.6253
# Epoch 40/200
# 44/44 [==============================] - 21s 459ms/step - loss: 0.9996 - accuracy: 0.6709 - val_loss: 1.2301 - val_accuracy: 0.5995
# Epoch 41/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.9900 - accuracy: 0.6764 - val_loss: 1.1664 - val_accuracy: 0.6217
# Epoch 42/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.9873 - accuracy: 0.6746 - val_loss: 1.1748 - val_accuracy: 0.6188
# Epoch 43/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.9822 - accuracy: 0.6789 - val_loss: 1.1971 - val_accuracy: 0.6035
# Epoch 44/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.9732 - accuracy: 0.6808 - val_loss: 1.2802 - val_accuracy: 0.6024
# Epoch 45/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.9662 - accuracy: 0.6887 - val_loss: 1.1839 - val_accuracy: 0.6049
# Epoch 46/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.9581 - accuracy: 0.6878 - val_loss: 1.1748 - val_accuracy: 0.6140
# Epoch 47/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.9459 - accuracy: 0.6929 - val_loss: 1.1288 - val_accuracy: 0.6253
# Epoch 48/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.9436 - accuracy: 0.6979 - val_loss: 1.3366 - val_accuracy: 0.5784
# Epoch 49/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.9391 - accuracy: 0.6955 - val_loss: 1.4207 - val_accuracy: 0.5584
# Epoch 50/200
# 44/44 [==============================] - 21s 459ms/step - loss: 0.9350 - accuracy: 0.6953 - val_loss: 1.1257 - val_accuracy: 0.6282
# Epoch 51/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.9192 - accuracy: 0.7005 - val_loss: 1.1431 - val_accuracy: 0.6293
# Epoch 52/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.9154 - accuracy: 0.7036 - val_loss: 1.2572 - val_accuracy: 0.6009
# Epoch 53/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.9133 - accuracy: 0.7041 - val_loss: 1.2116 - val_accuracy: 0.6082
# Epoch 54/200
# 44/44 [==============================] - 20s 457ms/step - loss: 0.9037 - accuracy: 0.7078 - val_loss: 1.2151 - val_accuracy: 0.6137
# Epoch 55/200
# 44/44 [==============================] - 21s 459ms/step - loss: 0.8991 - accuracy: 0.7136 - val_loss: 1.1316 - val_accuracy: 0.6399
# Epoch 56/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8903 - accuracy: 0.7133 - val_loss: 1.1643 - val_accuracy: 0.6250
# Epoch 57/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.8873 - accuracy: 0.7177 - val_loss: 1.2289 - val_accuracy: 0.6024
# Epoch 58/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8812 - accuracy: 0.7192 - val_loss: 1.2236 - val_accuracy: 0.6148
# Epoch 59/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.8798 - accuracy: 0.7174 - val_loss: 1.1633 - val_accuracy: 0.6286
# Epoch 60/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.8678 - accuracy: 0.7248 - val_loss: 1.1889 - val_accuracy: 0.6188
# Epoch 61/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.8606 - accuracy: 0.7275 - val_loss: 1.0978 - val_accuracy: 0.6450
# Epoch 62/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.8518 - accuracy: 0.7292 - val_loss: 1.2361 - val_accuracy: 0.5842
# Epoch 63/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.8543 - accuracy: 0.7293 - val_loss: 1.1415 - val_accuracy: 0.6220
# Epoch 64/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.8484 - accuracy: 0.7306 - val_loss: 1.1601 - val_accuracy: 0.6246
# Epoch 65/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.8425 - accuracy: 0.7323 - val_loss: 1.1496 - val_accuracy: 0.6337
# Epoch 66/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.8358 - accuracy: 0.7363 - val_loss: 1.1989 - val_accuracy: 0.6333
# Epoch 67/200
# 44/44 [==============================] - 20s 450ms/step - loss: 0.8326 - accuracy: 0.7408 - val_loss: 1.1369 - val_accuracy: 0.6359
# Epoch 68/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.8227 - accuracy: 0.7416 - val_loss: 1.2107 - val_accuracy: 0.6239
# Epoch 69/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.8161 - accuracy: 0.7429 - val_loss: 1.1811 - val_accuracy: 0.6246
# Epoch 70/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.8162 - accuracy: 0.7450 - val_loss: 1.2494 - val_accuracy: 0.6115
# Epoch 71/200
# 44/44 [==============================] - 20s 450ms/step - loss: 0.8136 - accuracy: 0.7448 - val_loss: 1.3108 - val_accuracy: 0.6064
# Epoch 72/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.8131 - accuracy: 0.7451 - val_loss: 1.2245 - val_accuracy: 0.6195
# Epoch 73/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8040 - accuracy: 0.7486 - val_loss: 1.3585 - val_accuracy: 0.6064
# Epoch 74/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.8004 - accuracy: 0.7514 - val_loss: 1.3286 - val_accuracy: 0.5999
# Epoch 75/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.8008 - accuracy: 0.7496 - val_loss: 1.2333 - val_accuracy: 0.6359
# Epoch 76/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.7915 - accuracy: 0.7500 - val_loss: 1.1433 - val_accuracy: 0.6410
# Epoch 77/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.7763 - accuracy: 0.7602 - val_loss: 1.1411 - val_accuracy: 0.6508
# Epoch 78/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.7758 - accuracy: 0.7604 - val_loss: 1.1867 - val_accuracy: 0.6279
# Epoch 79/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.7712 - accuracy: 0.7588 - val_loss: 1.1875 - val_accuracy: 0.6159
# Epoch 80/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7647 - accuracy: 0.7638 - val_loss: 1.1415 - val_accuracy: 0.6399
# Epoch 81/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7627 - accuracy: 0.7672 - val_loss: 1.1992 - val_accuracy: 0.6340
# Epoch 82/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.7625 - accuracy: 0.7627 - val_loss: 1.1855 - val_accuracy: 0.6337
# Epoch 83/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.7553 - accuracy: 0.7640 - val_loss: 1.2428 - val_accuracy: 0.6115
# Epoch 84/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.7511 - accuracy: 0.7702 - val_loss: 1.1667 - val_accuracy: 0.6475
# Epoch 85/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7434 - accuracy: 0.7711 - val_loss: 1.2918 - val_accuracy: 0.6140
# Epoch 86/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.7400 - accuracy: 0.7710 - val_loss: 1.2350 - val_accuracy: 0.6388
# Epoch 87/200
# 44/44 [==============================] - 20s 450ms/step - loss: 0.7337 - accuracy: 0.7771 - val_loss: 1.2096 - val_accuracy: 0.6431
# Epoch 88/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.7243 - accuracy: 0.7813 - val_loss: 1.1968 - val_accuracy: 0.6515
# Epoch 89/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7332 - accuracy: 0.7735 - val_loss: 1.2914 - val_accuracy: 0.6333
# Epoch 90/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.7229 - accuracy: 0.7786 - val_loss: 1.1911 - val_accuracy: 0.6351
# Epoch 91/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.7228 - accuracy: 0.7806 - val_loss: 1.1879 - val_accuracy: 0.6511
# Epoch 92/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.7084 - accuracy: 0.7819 - val_loss: 1.2055 - val_accuracy: 0.6373
# Epoch 93/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.7050 - accuracy: 0.7858 - val_loss: 1.2249 - val_accuracy: 0.6275
# Epoch 94/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.7030 - accuracy: 0.7874 - val_loss: 1.2184 - val_accuracy: 0.6268
# Epoch 95/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.7055 - accuracy: 0.7847 - val_loss: 1.2941 - val_accuracy: 0.6104
# Epoch 96/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6923 - accuracy: 0.7940 - val_loss: 1.3066 - val_accuracy: 0.6133
# Epoch 97/200
# 44/44 [==============================] - 21s 454ms/step - loss: 0.6916 - accuracy: 0.7925 - val_loss: 1.2885 - val_accuracy: 0.6217
# Epoch 98/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.6809 - accuracy: 0.7986 - val_loss: 1.2237 - val_accuracy: 0.6399
# Epoch 99/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.6894 - accuracy: 0.7923 - val_loss: 1.3712 - val_accuracy: 0.6130
# Epoch 100/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.6910 - accuracy: 0.7905 - val_loss: 1.4936 - val_accuracy: 0.6079
# Epoch 101/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.6821 - accuracy: 0.7938 - val_loss: 1.2969 - val_accuracy: 0.6177
# Epoch 102/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.6688 - accuracy: 0.7990 - val_loss: 1.2181 - val_accuracy: 0.6508
# Epoch 103/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.6608 - accuracy: 0.8033 - val_loss: 1.1735 - val_accuracy: 0.6511
# Epoch 104/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.6601 - accuracy: 0.8032 - val_loss: 1.1930 - val_accuracy: 0.6439
# Epoch 105/200
# 44/44 [==============================] - 21s 454ms/step - loss: 0.6596 - accuracy: 0.8041 - val_loss: 1.1801 - val_accuracy: 0.6373
# Epoch 106/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6615 - accuracy: 0.8050 - val_loss: 1.2243 - val_accuracy: 0.6421
# Epoch 107/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.6452 - accuracy: 0.8105 - val_loss: 1.3151 - val_accuracy: 0.6366
# Epoch 108/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.6437 - accuracy: 0.8104 - val_loss: 1.4055 - val_accuracy: 0.6042
# Epoch 109/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.6448 - accuracy: 0.8087 - val_loss: 1.2316 - val_accuracy: 0.6373
# Epoch 110/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.6430 - accuracy: 0.8082 - val_loss: 1.3055 - val_accuracy: 0.6220
# Epoch 111/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.6429 - accuracy: 0.8109 - val_loss: 1.2565 - val_accuracy: 0.6406
# Epoch 112/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.6314 - accuracy: 0.8161 - val_loss: 1.3003 - val_accuracy: 0.6206
# Epoch 113/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.6372 - accuracy: 0.8096 - val_loss: 1.2487 - val_accuracy: 0.6544
# Epoch 114/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.6258 - accuracy: 0.8174 - val_loss: 1.3879 - val_accuracy: 0.6377
# Epoch 115/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6304 - accuracy: 0.8147 - val_loss: 1.2967 - val_accuracy: 0.6322
# Epoch 116/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.6223 - accuracy: 0.8197 - val_loss: 1.3695 - val_accuracy: 0.6224
# Epoch 117/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6111 - accuracy: 0.8239 - val_loss: 1.3895 - val_accuracy: 0.6442
# Epoch 118/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6121 - accuracy: 0.8216 - val_loss: 1.2999 - val_accuracy: 0.6450
# Epoch 119/200
# 44/44 [==============================] - 21s 462ms/step - loss: 0.6187 - accuracy: 0.8173 - val_loss: 1.4836 - val_accuracy: 0.5933
# Epoch 120/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.6120 - accuracy: 0.8213 - val_loss: 1.3579 - val_accuracy: 0.6119
# Epoch 121/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.6036 - accuracy: 0.8243 - val_loss: 1.2244 - val_accuracy: 0.6370
# Epoch 122/200
# 44/44 [==============================] - 21s 454ms/step - loss: 0.6108 - accuracy: 0.8231 - val_loss: 1.3429 - val_accuracy: 0.6282
# Epoch 123/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.6059 - accuracy: 0.8232 - val_loss: 1.3114 - val_accuracy: 0.6322
# Epoch 124/200
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5999 - accuracy: 0.8258 - val_loss: 1.4386 - val_accuracy: 0.6035
# Epoch 125/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5897 - accuracy: 0.8312 - val_loss: 1.3287 - val_accuracy: 0.6461
# Epoch 126/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5967 - accuracy: 0.8262 - val_loss: 1.3336 - val_accuracy: 0.6493
# Epoch 127/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5840 - accuracy: 0.8256 - val_loss: 1.3024 - val_accuracy: 0.6533
# Epoch 128/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5794 - accuracy: 0.8323 - val_loss: 1.3015 - val_accuracy: 0.6599
# Epoch 129/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.5849 - accuracy: 0.8312 - val_loss: 1.3255 - val_accuracy: 0.6395
# Epoch 130/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.5833 - accuracy: 0.8333 - val_loss: 1.3003 - val_accuracy: 0.6362
# Epoch 131/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5732 - accuracy: 0.8360 - val_loss: 1.3054 - val_accuracy: 0.6468
# Epoch 132/200
# 44/44 [==============================] - 21s 459ms/step - loss: 0.5673 - accuracy: 0.8375 - val_loss: 1.4263 - val_accuracy: 0.6231
# Epoch 133/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5722 - accuracy: 0.8366 - val_loss: 1.3180 - val_accuracy: 0.6457
# Epoch 134/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5688 - accuracy: 0.8347 - val_loss: 1.3152 - val_accuracy: 0.6417
# Epoch 135/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5701 - accuracy: 0.8356 - val_loss: 1.4187 - val_accuracy: 0.6275
# Epoch 136/200
# 44/44 [==============================] - 20s 457ms/step - loss: 0.5638 - accuracy: 0.8391 - val_loss: 1.3108 - val_accuracy: 0.6388
# Epoch 137/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.5585 - accuracy: 0.8403 - val_loss: 1.2978 - val_accuracy: 0.6479
# Epoch 138/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.5524 - accuracy: 0.8417 - val_loss: 1.2586 - val_accuracy: 0.6559
# Epoch 139/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5435 - accuracy: 0.8464 - val_loss: 1.3021 - val_accuracy: 0.6493
# Epoch 140/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.5480 - accuracy: 0.8458 - val_loss: 1.3256 - val_accuracy: 0.6577
# Epoch 141/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5369 - accuracy: 0.8492 - val_loss: 1.3831 - val_accuracy: 0.6104
# Epoch 142/200
# 44/44 [==============================] - 21s 454ms/step - loss: 0.5471 - accuracy: 0.8458 - val_loss: 1.3795 - val_accuracy: 0.6515
# Epoch 143/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5487 - accuracy: 0.8462 - val_loss: 1.3452 - val_accuracy: 0.6486
# Epoch 144/200
# 44/44 [==============================] - 21s 460ms/step - loss: 0.5426 - accuracy: 0.8476 - val_loss: 1.3688 - val_accuracy: 0.6348
# Epoch 145/200
# 44/44 [==============================] - 20s 456ms/step - loss: 0.5392 - accuracy: 0.8506 - val_loss: 1.2911 - val_accuracy: 0.6497
# Epoch 146/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5372 - accuracy: 0.8501 - val_loss: 1.4862 - val_accuracy: 0.6170
# Epoch 147/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5313 - accuracy: 0.8486 - val_loss: 1.4059 - val_accuracy: 0.6468
# Epoch 148/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.5227 - accuracy: 0.8540 - val_loss: 1.4122 - val_accuracy: 0.6511
# Epoch 149/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5202 - accuracy: 0.8545 - val_loss: 1.3289 - val_accuracy: 0.6315
# Epoch 150/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.5174 - accuracy: 0.8580 - val_loss: 1.7130 - val_accuracy: 0.5817
# Epoch 151/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5158 - accuracy: 0.8596 - val_loss: 1.4492 - val_accuracy: 0.6370
# Epoch 152/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5192 - accuracy: 0.8543 - val_loss: 1.3396 - val_accuracy: 0.6359
# Epoch 153/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.5086 - accuracy: 0.8598 - val_loss: 1.4031 - val_accuracy: 0.6497
# Epoch 154/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.5106 - accuracy: 0.8580 - val_loss: 1.4087 - val_accuracy: 0.6402
# Epoch 155/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.5023 - accuracy: 0.8602 - val_loss: 1.4896 - val_accuracy: 0.6377
# Epoch 156/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.5079 - accuracy: 0.8590 - val_loss: 1.5525 - val_accuracy: 0.6042
# Epoch 157/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.5116 - accuracy: 0.8577 - val_loss: 1.3791 - val_accuracy: 0.6431
# Epoch 158/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.5064 - accuracy: 0.8612 - val_loss: 1.6140 - val_accuracy: 0.5995
# Epoch 159/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4952 - accuracy: 0.8646 - val_loss: 1.4376 - val_accuracy: 0.6239
# Epoch 160/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4968 - accuracy: 0.8618 - val_loss: 1.5573 - val_accuracy: 0.6326
# Epoch 161/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4935 - accuracy: 0.8663 - val_loss: 1.4153 - val_accuracy: 0.6435
# Epoch 162/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4909 - accuracy: 0.8666 - val_loss: 1.4559 - val_accuracy: 0.6340
# Epoch 163/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4904 - accuracy: 0.8667 - val_loss: 1.4071 - val_accuracy: 0.6493
# Epoch 164/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4996 - accuracy: 0.8638 - val_loss: 1.4061 - val_accuracy: 0.6315
# Epoch 165/200
# 44/44 [==============================] - 21s 460ms/step - loss: 0.4995 - accuracy: 0.8622 - val_loss: 1.4105 - val_accuracy: 0.6413
# Epoch 166/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4841 - accuracy: 0.8678 - val_loss: 1.5070 - val_accuracy: 0.6468
# Epoch 167/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4789 - accuracy: 0.8727 - val_loss: 1.5073 - val_accuracy: 0.6202
# Epoch 168/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4763 - accuracy: 0.8719 - val_loss: 1.4670 - val_accuracy: 0.6377
# Epoch 169/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4740 - accuracy: 0.8732 - val_loss: 1.4369 - val_accuracy: 0.6286
# Epoch 170/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4826 - accuracy: 0.8708 - val_loss: 1.4768 - val_accuracy: 0.6428
# Epoch 171/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.4754 - accuracy: 0.8702 - val_loss: 1.4318 - val_accuracy: 0.6264
# Epoch 172/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4773 - accuracy: 0.8709 - val_loss: 1.5469 - val_accuracy: 0.6239
# Epoch 173/200
# 44/44 [==============================] - 20s 451ms/step - loss: 0.4774 - accuracy: 0.8679 - val_loss: 1.5121 - val_accuracy: 0.6235
# Epoch 174/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4726 - accuracy: 0.8734 - val_loss: 1.5096 - val_accuracy: 0.6431
# Epoch 175/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4690 - accuracy: 0.8760 - val_loss: 1.5211 - val_accuracy: 0.6417
# Epoch 176/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4754 - accuracy: 0.8723 - val_loss: 1.5158 - val_accuracy: 0.6202
# Epoch 177/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4760 - accuracy: 0.8718 - val_loss: 1.4961 - val_accuracy: 0.6391
# Epoch 178/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4691 - accuracy: 0.8741 - val_loss: 1.4012 - val_accuracy: 0.6421
# Epoch 179/200
# 44/44 [==============================] - 21s 455ms/step - loss: 0.4582 - accuracy: 0.8780 - val_loss: 1.5383 - val_accuracy: 0.6231
# Epoch 180/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4550 - accuracy: 0.8808 - val_loss: 1.5941 - val_accuracy: 0.6279
# Epoch 181/200
# 44/44 [==============================] - 21s 466ms/step - loss: 0.4621 - accuracy: 0.8766 - val_loss: 1.3922 - val_accuracy: 0.6370
# Epoch 182/200
# 44/44 [==============================] - 21s 459ms/step - loss: 0.4610 - accuracy: 0.8779 - val_loss: 1.4071 - val_accuracy: 0.6344
# Epoch 183/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4578 - accuracy: 0.8767 - val_loss: 1.5385 - val_accuracy: 0.6246
# Epoch 184/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4494 - accuracy: 0.8817 - val_loss: 1.5011 - val_accuracy: 0.6504
# Epoch 185/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4518 - accuracy: 0.8815 - val_loss: 1.4196 - val_accuracy: 0.6351
# Epoch 186/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4404 - accuracy: 0.8833 - val_loss: 1.5354 - val_accuracy: 0.6348
# Epoch 187/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4495 - accuracy: 0.8818 - val_loss: 1.6273 - val_accuracy: 0.6337
# Epoch 188/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4546 - accuracy: 0.8802 - val_loss: 1.5834 - val_accuracy: 0.6253
# Epoch 189/200
# 44/44 [==============================] - 21s 461ms/step - loss: 0.4609 - accuracy: 0.8757 - val_loss: 1.4450 - val_accuracy: 0.6431
# Epoch 190/200
# 44/44 [==============================] - 21s 458ms/step - loss: 0.4436 - accuracy: 0.8841 - val_loss: 1.5751 - val_accuracy: 0.6362
# Epoch 191/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4351 - accuracy: 0.8837 - val_loss: 1.5863 - val_accuracy: 0.6297
# Epoch 192/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4437 - accuracy: 0.8831 - val_loss: 1.5747 - val_accuracy: 0.6140
# Epoch 193/200
# 44/44 [==============================] - 20s 454ms/step - loss: 0.4424 - accuracy: 0.8839 - val_loss: 1.5153 - val_accuracy: 0.6344
# Epoch 194/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4394 - accuracy: 0.8844 - val_loss: 1.3749 - val_accuracy: 0.6544
# Epoch 195/200
# 44/44 [==============================] - 21s 457ms/step - loss: 0.4445 - accuracy: 0.8831 - val_loss: 1.5518 - val_accuracy: 0.6333
# Epoch 196/200
# 44/44 [==============================] - 20s 455ms/step - loss: 0.4289 - accuracy: 0.8907 - val_loss: 1.5827 - val_accuracy: 0.6199
# Epoch 197/200
# 44/44 [==============================] - 21s 456ms/step - loss: 0.4263 - accuracy: 0.8897 - val_loss: 1.5460 - val_accuracy: 0.6355
# Epoch 198/200
# 44/44 [==============================] - 20s 453ms/step - loss: 0.4304 - accuracy: 0.8868 - val_loss: 1.5888 - val_accuracy: 0.6271
# Epoch 199/200
# 44/44 [==============================] - 21s 460ms/step - loss: 0.4177 - accuracy: 0.8929 - val_loss: 1.5691 - val_accuracy: 0.6381
# Epoch 200/200
# 44/44 [==============================] - 20s 452ms/step - loss: 0.4236 - accuracy: 0.8889 - val_loss: 1.6939 - val_accuracy: 0.6060
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 21 kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=a89bc60cf15f8c7a94178351f427ed03bd4935b5402b9518b6a96206ea00d9a8
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*100)/math.log(mean)
  img = np.power(img, gamma).clip(0,100).astype(np.uint8)

  img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  img = local_binary_pattern(img, 30, 1)
  img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((22279, 48, 48, 1), (2755, 48, 48, 1), (2749, 48, 48, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import callbacks as cb

# Training parameter
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
dataset_type = 'FER2013'


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = dataset_type + '_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.8):
      lr = 0.0001
    elif epoch >= (epochs*0.3):
      lr=0.001
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    datagen.fit(x_train)
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.01
# 44/44 [==============================] - 35s 514ms/step - loss: 1.9769 - accuracy: 0.2652 - val_loss: 2.2877 - val_accuracy: 0.2288
#
# Epoch 00001: val_accuracy improved from -inf to 0.22881, saving model to /content/saved_models/FER2013_model.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 446ms/step - loss: 1.8110 - accuracy: 0.3122 - val_loss: 2.3330 - val_accuracy: 0.1895
#
# Epoch 00002: val_accuracy did not improve from 0.22881
# Epoch 3/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 450ms/step - loss: 1.6638 - accuracy: 0.4029 - val_loss: 4.8866 - val_accuracy: 0.2255
#
# Epoch 00003: val_accuracy did not improve from 0.22881
# Epoch 4/200
# Learning rate:  0.01
# 44/44 [==============================] - 20s 450ms/step - loss: 1.5867 - accuracy: 0.4403 - val_loss: 2.2422 - val_accuracy: 0.3525
#
# Epoch 00004: val_accuracy improved from 0.22881 to 0.35249, saving model to /content/saved_models/FER2013_model.h5
# Epoch 5/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 456ms/step - loss: 1.5107 - accuracy: 0.4762 - val_loss: 2.3154 - val_accuracy: 0.2412
#
# Epoch 00005: val_accuracy did not improve from 0.35249
# Epoch 6/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 453ms/step - loss: 1.4691 - accuracy: 0.4923 - val_loss: 1.7397 - val_accuracy: 0.3903
#
# Epoch 00006: val_accuracy improved from 0.35249 to 0.39032, saving model to /content/saved_models/FER2013_model.h5
# Epoch 7/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 459ms/step - loss: 1.4364 - accuracy: 0.5060 - val_loss: 1.8421 - val_accuracy: 0.3619
#
# Epoch 00007: val_accuracy did not improve from 0.39032
# Epoch 8/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 459ms/step - loss: 1.4148 - accuracy: 0.5176 - val_loss: 2.2510 - val_accuracy: 0.2656
#
# Epoch 00008: val_accuracy did not improve from 0.39032
# Epoch 9/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.3998 - accuracy: 0.5239 - val_loss: 2.1383 - val_accuracy: 0.2728
#
# Epoch 00009: val_accuracy did not improve from 0.39032
# Epoch 10/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.3716 - accuracy: 0.5338 - val_loss: 1.5625 - val_accuracy: 0.4445
#
# Epoch 00010: val_accuracy improved from 0.39032 to 0.44453, saving model to /content/saved_models/FER2013_model.h5
# Epoch 11/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.3672 - accuracy: 0.5393 - val_loss: 1.8010 - val_accuracy: 0.3358
#
# Epoch 00011: val_accuracy did not improve from 0.44453
# Epoch 12/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.3400 - accuracy: 0.5483 - val_loss: 1.8513 - val_accuracy: 0.2950
#
# Epoch 00012: val_accuracy did not improve from 0.44453
# Epoch 13/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.3368 - accuracy: 0.5519 - val_loss: 1.3952 - val_accuracy: 0.5173
#
# Epoch 00013: val_accuracy improved from 0.44453 to 0.51728, saving model to /content/saved_models/FER2013_model.h5
# Epoch 14/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 461ms/step - loss: 1.3307 - accuracy: 0.5550 - val_loss: 1.4456 - val_accuracy: 0.5169
#
# Epoch 00014: val_accuracy did not improve from 0.51728
# Epoch 15/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.3207 - accuracy: 0.5576 - val_loss: 1.7373 - val_accuracy: 0.3830
#
# Epoch 00015: val_accuracy did not improve from 0.51728
# Epoch 16/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 461ms/step - loss: 1.3035 - accuracy: 0.5633 - val_loss: 1.5916 - val_accuracy: 0.4576
#
# Epoch 00016: val_accuracy did not improve from 0.51728
# Epoch 17/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.3078 - accuracy: 0.5631 - val_loss: 1.5671 - val_accuracy: 0.4482
#
# Epoch 00017: val_accuracy did not improve from 0.51728
# Epoch 18/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.2920 - accuracy: 0.5699 - val_loss: 1.4306 - val_accuracy: 0.5191
#
# Epoch 00018: val_accuracy improved from 0.51728 to 0.51910, saving model to /content/saved_models/FER2013_model.h5
# Epoch 19/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.2785 - accuracy: 0.5739 - val_loss: 1.5602 - val_accuracy: 0.4147
#
# Epoch 00019: val_accuracy did not improve from 0.51910
# Epoch 20/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2832 - accuracy: 0.5761 - val_loss: 1.6147 - val_accuracy: 0.4129
#
# Epoch 00020: val_accuracy did not improve from 0.51910
# Epoch 21/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.2799 - accuracy: 0.5745 - val_loss: 1.4308 - val_accuracy: 0.5136
#
# Epoch 00021: val_accuracy did not improve from 0.51910
# Epoch 22/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.2767 - accuracy: 0.5766 - val_loss: 1.3867 - val_accuracy: 0.5311
#
# Epoch 00022: val_accuracy improved from 0.51910 to 0.53110, saving model to /content/saved_models/FER2013_model.h5
# Epoch 23/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.2732 - accuracy: 0.5782 - val_loss: 1.5397 - val_accuracy: 0.4802
#
# Epoch 00023: val_accuracy did not improve from 0.53110
# Epoch 24/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.2629 - accuracy: 0.5832 - val_loss: 1.4805 - val_accuracy: 0.4725
#
# Epoch 00024: val_accuracy did not improve from 0.53110
# Epoch 25/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2563 - accuracy: 0.5880 - val_loss: 1.3980 - val_accuracy: 0.5391
#
# Epoch 00025: val_accuracy improved from 0.53110 to 0.53911, saving model to /content/saved_models/FER2013_model.h5
# Epoch 26/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2575 - accuracy: 0.5846 - val_loss: 1.5050 - val_accuracy: 0.4707
#
# Epoch 00026: val_accuracy did not improve from 0.53911
# Epoch 27/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.2483 - accuracy: 0.5871 - val_loss: 1.4261 - val_accuracy: 0.5151
#
# Epoch 00027: val_accuracy did not improve from 0.53911
# Epoch 28/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2493 - accuracy: 0.5906 - val_loss: 1.4534 - val_accuracy: 0.5380
#
# Epoch 00028: val_accuracy did not improve from 0.53911
# Epoch 29/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2522 - accuracy: 0.5869 - val_loss: 1.4234 - val_accuracy: 0.5246
#
# Epoch 00029: val_accuracy did not improve from 0.53911
# Epoch 30/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.2452 - accuracy: 0.5923 - val_loss: 1.3637 - val_accuracy: 0.5377
#
# Epoch 00030: val_accuracy did not improve from 0.53911
# Epoch 31/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2466 - accuracy: 0.5921 - val_loss: 1.4058 - val_accuracy: 0.5286
#
# Epoch 00031: val_accuracy did not improve from 0.53911
# Epoch 32/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2321 - accuracy: 0.5954 - val_loss: 1.9141 - val_accuracy: 0.3336
#
# Epoch 00032: val_accuracy did not improve from 0.53911
# Epoch 33/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2337 - accuracy: 0.5959 - val_loss: 1.4848 - val_accuracy: 0.5260
#
# Epoch 00033: val_accuracy did not improve from 0.53911
# Epoch 34/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 470ms/step - loss: 1.2341 - accuracy: 0.5960 - val_loss: 1.4371 - val_accuracy: 0.5180
#
# Epoch 00034: val_accuracy did not improve from 0.53911
# Epoch 35/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2268 - accuracy: 0.5999 - val_loss: 1.6195 - val_accuracy: 0.4547
#
# Epoch 00035: val_accuracy did not improve from 0.53911
# Epoch 36/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 468ms/step - loss: 1.2277 - accuracy: 0.6010 - val_loss: 1.7045 - val_accuracy: 0.3736
#
# Epoch 00036: val_accuracy did not improve from 0.53911
# Epoch 37/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.2221 - accuracy: 0.5992 - val_loss: 1.4391 - val_accuracy: 0.5133
#
# Epoch 00037: val_accuracy did not improve from 0.53911
# Epoch 38/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.2173 - accuracy: 0.6030 - val_loss: 1.6192 - val_accuracy: 0.4322
#
# Epoch 00038: val_accuracy did not improve from 0.53911
# Epoch 39/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.2240 - accuracy: 0.6002 - val_loss: 1.3827 - val_accuracy: 0.5497
#
# Epoch 00039: val_accuracy improved from 0.53911 to 0.54965, saving model to /content/saved_models/FER2013_model.h5
# Epoch 40/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.2206 - accuracy: 0.6025 - val_loss: 1.9398 - val_accuracy: 0.3430
#
# Epoch 00040: val_accuracy did not improve from 0.54965
# Epoch 41/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.2084 - accuracy: 0.6047 - val_loss: 1.5122 - val_accuracy: 0.4787
#
# Epoch 00041: val_accuracy did not improve from 0.54965
# Epoch 42/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 469ms/step - loss: 1.2190 - accuracy: 0.6016 - val_loss: 1.4846 - val_accuracy: 0.5158
#
# Epoch 00042: val_accuracy did not improve from 0.54965
# Epoch 43/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.2167 - accuracy: 0.6064 - val_loss: 1.5147 - val_accuracy: 0.4805
#
# Epoch 00043: val_accuracy did not improve from 0.54965
# Epoch 44/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 459ms/step - loss: 1.2005 - accuracy: 0.6059 - val_loss: 1.3881 - val_accuracy: 0.5449
#
# Epoch 00044: val_accuracy did not improve from 0.54965
# Epoch 45/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2111 - accuracy: 0.6038 - val_loss: 1.3229 - val_accuracy: 0.5533
#
# Epoch 00045: val_accuracy improved from 0.54965 to 0.55329, saving model to /content/saved_models/FER2013_model.h5
# Epoch 46/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.2022 - accuracy: 0.6088 - val_loss: 1.5172 - val_accuracy: 0.4904
#
# Epoch 00046: val_accuracy did not improve from 0.55329
# Epoch 47/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 461ms/step - loss: 1.2062 - accuracy: 0.6078 - val_loss: 1.4976 - val_accuracy: 0.4867
#
# Epoch 00047: val_accuracy did not improve from 0.55329
# Epoch 48/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2026 - accuracy: 0.6058 - val_loss: 1.3617 - val_accuracy: 0.5431
#
# Epoch 00048: val_accuracy did not improve from 0.55329
# Epoch 49/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 463ms/step - loss: 1.2086 - accuracy: 0.6057 - val_loss: 1.3917 - val_accuracy: 0.5227
#
# Epoch 00049: val_accuracy did not improve from 0.55329
# Epoch 50/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 461ms/step - loss: 1.2018 - accuracy: 0.6086 - val_loss: 1.5246 - val_accuracy: 0.4765
#
# Epoch 00050: val_accuracy did not improve from 0.55329
# Epoch 51/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.1926 - accuracy: 0.6115 - val_loss: 1.5282 - val_accuracy: 0.4682
#
# Epoch 00051: val_accuracy did not improve from 0.55329
# Epoch 52/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 466ms/step - loss: 1.1910 - accuracy: 0.6116 - val_loss: 1.3775 - val_accuracy: 0.5293
#
# Epoch 00052: val_accuracy did not improve from 0.55329
# Epoch 53/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 467ms/step - loss: 1.2026 - accuracy: 0.6081 - val_loss: 1.3475 - val_accuracy: 0.5402
#
# Epoch 00053: val_accuracy did not improve from 0.55329
# Epoch 54/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.2020 - accuracy: 0.6097 - val_loss: 1.4765 - val_accuracy: 0.5220
#
# Epoch 00054: val_accuracy did not improve from 0.55329
# Epoch 55/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.1976 - accuracy: 0.6096 - val_loss: 1.3829 - val_accuracy: 0.5304
#
# Epoch 00055: val_accuracy did not improve from 0.55329
# Epoch 56/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 460ms/step - loss: 1.1932 - accuracy: 0.6147 - val_loss: 1.3544 - val_accuracy: 0.5420
#
# Epoch 00056: val_accuracy did not improve from 0.55329
# Epoch 57/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 458ms/step - loss: 1.1797 - accuracy: 0.6190 - val_loss: 1.3405 - val_accuracy: 0.5558
#
# Epoch 00057: val_accuracy improved from 0.55329 to 0.55584, saving model to /content/saved_models/FER2013_model.h5
# Epoch 58/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 464ms/step - loss: 1.1833 - accuracy: 0.6143 - val_loss: 1.4417 - val_accuracy: 0.5078
#
# Epoch 00058: val_accuracy did not improve from 0.55584
# Epoch 59/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 462ms/step - loss: 1.1816 - accuracy: 0.6151 - val_loss: 1.3354 - val_accuracy: 0.5504
#
# Epoch 00059: val_accuracy did not improve from 0.55584
# Epoch 60/200
# Learning rate:  0.01
# 44/44 [==============================] - 21s 465ms/step - loss: 1.1869 - accuracy: 0.6141 - val_loss: 1.7519 - val_accuracy: 0.4231
#
# Epoch 00060: val_accuracy did not improve from 0.55584
# Epoch 61/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 1.1225 - accuracy: 0.6396 - val_loss: 1.2370 - val_accuracy: 0.5940
#
# Epoch 00061: val_accuracy improved from 0.55584 to 0.59403, saving model to /content/saved_models/FER2013_model.h5
# Epoch 62/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 460ms/step - loss: 1.0813 - accuracy: 0.6535 - val_loss: 1.2224 - val_accuracy: 0.5919
#
# Epoch 00062: val_accuracy did not improve from 0.59403
# Epoch 63/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 1.0649 - accuracy: 0.6590 - val_loss: 1.2064 - val_accuracy: 0.5944
#
# Epoch 00063: val_accuracy improved from 0.59403 to 0.59440, saving model to /content/saved_models/FER2013_model.h5
# Epoch 64/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 1.0436 - accuracy: 0.6656 - val_loss: 1.1895 - val_accuracy: 0.6042
#
# Epoch 00064: val_accuracy improved from 0.59440 to 0.60422, saving model to /content/saved_models/FER2013_model.h5
# Epoch 65/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 1.0352 - accuracy: 0.6706 - val_loss: 1.2144 - val_accuracy: 0.5969
#
# Epoch 00065: val_accuracy did not improve from 0.60422
# Epoch 66/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 1.0235 - accuracy: 0.6727 - val_loss: 1.1858 - val_accuracy: 0.6071
#
# Epoch 00066: val_accuracy improved from 0.60422 to 0.60713, saving model to /content/saved_models/FER2013_model.h5
# Epoch 67/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 1.0114 - accuracy: 0.6738 - val_loss: 1.1754 - val_accuracy: 0.6031
#
# Epoch 00067: val_accuracy did not improve from 0.60713
# Epoch 68/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.9980 - accuracy: 0.6805 - val_loss: 1.1791 - val_accuracy: 0.6104
#
# Epoch 00068: val_accuracy improved from 0.60713 to 0.61040, saving model to /content/saved_models/FER2013_model.h5
# Epoch 69/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 460ms/step - loss: 0.9946 - accuracy: 0.6812 - val_loss: 1.1917 - val_accuracy: 0.5977
#
# Epoch 00069: val_accuracy did not improve from 0.61040
# Epoch 70/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.9836 - accuracy: 0.6876 - val_loss: 1.1868 - val_accuracy: 0.6057
#
# Epoch 00070: val_accuracy did not improve from 0.61040
# Epoch 71/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.9781 - accuracy: 0.6835 - val_loss: 1.1766 - val_accuracy: 0.6122
#
# Epoch 00071: val_accuracy improved from 0.61040 to 0.61222, saving model to /content/saved_models/FER2013_model.h5
# Epoch 72/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.9730 - accuracy: 0.6874 - val_loss: 1.1501 - val_accuracy: 0.6162
#
# Epoch 00072: val_accuracy improved from 0.61222 to 0.61622, saving model to /content/saved_models/FER2013_model.h5
# Epoch 73/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.9627 - accuracy: 0.6888 - val_loss: 1.1626 - val_accuracy: 0.6053
#
# Epoch 00073: val_accuracy did not improve from 0.61622
# Epoch 74/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.9568 - accuracy: 0.6943 - val_loss: 1.1935 - val_accuracy: 0.6104
#
# Epoch 00074: val_accuracy did not improve from 0.61622
# Epoch 75/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.9509 - accuracy: 0.6945 - val_loss: 1.1724 - val_accuracy: 0.6155
#
# Epoch 00075: val_accuracy did not improve from 0.61622
# Epoch 76/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.9463 - accuracy: 0.6954 - val_loss: 1.1837 - val_accuracy: 0.6064
#
# Epoch 00076: val_accuracy did not improve from 0.61622
# Epoch 77/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.9425 - accuracy: 0.6987 - val_loss: 1.1853 - val_accuracy: 0.6068
#
# Epoch 00077: val_accuracy did not improve from 0.61622
# Epoch 78/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 460ms/step - loss: 0.9300 - accuracy: 0.6972 - val_loss: 1.1763 - val_accuracy: 0.6100
#
# Epoch 00078: val_accuracy did not improve from 0.61622
# Epoch 79/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.9221 - accuracy: 0.7003 - val_loss: 1.1738 - val_accuracy: 0.6075
#
# Epoch 00079: val_accuracy did not improve from 0.61622
# Epoch 80/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.9179 - accuracy: 0.7045 - val_loss: 1.1680 - val_accuracy: 0.6148
#
# Epoch 00080: val_accuracy did not improve from 0.61622
# Epoch 81/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.9134 - accuracy: 0.7048 - val_loss: 1.1889 - val_accuracy: 0.6119
#
# Epoch 00081: val_accuracy did not improve from 0.61622
# Epoch 82/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.9044 - accuracy: 0.7085 - val_loss: 1.2033 - val_accuracy: 0.6097
#
# Epoch 00082: val_accuracy did not improve from 0.61622
# Epoch 83/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.9019 - accuracy: 0.7063 - val_loss: 1.2451 - val_accuracy: 0.5962
#
# Epoch 00083: val_accuracy did not improve from 0.61622
# Epoch 84/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.9005 - accuracy: 0.7127 - val_loss: 1.1993 - val_accuracy: 0.6057
#
# Epoch 00084: val_accuracy did not improve from 0.61622
# Epoch 85/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.8882 - accuracy: 0.7149 - val_loss: 1.1841 - val_accuracy: 0.6104
#
# Epoch 00085: val_accuracy did not improve from 0.61622
# Epoch 86/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.8860 - accuracy: 0.7173 - val_loss: 1.1971 - val_accuracy: 0.6039
#
# Epoch 00086: val_accuracy did not improve from 0.61622
# Epoch 87/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.8828 - accuracy: 0.7151 - val_loss: 1.1841 - val_accuracy: 0.6126
#
# Epoch 00087: val_accuracy did not improve from 0.61622
# Epoch 88/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8752 - accuracy: 0.7174 - val_loss: 1.2050 - val_accuracy: 0.5929
#
# Epoch 00088: val_accuracy did not improve from 0.61622
# Epoch 89/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8722 - accuracy: 0.7218 - val_loss: 1.2098 - val_accuracy: 0.6119
#
# Epoch 00089: val_accuracy did not improve from 0.61622
# Epoch 90/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.8663 - accuracy: 0.7201 - val_loss: 1.1931 - val_accuracy: 0.6133
#
# Epoch 00090: val_accuracy did not improve from 0.61622
# Epoch 91/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8567 - accuracy: 0.7258 - val_loss: 1.2200 - val_accuracy: 0.6075
#
# Epoch 00091: val_accuracy did not improve from 0.61622
# Epoch 92/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.8580 - accuracy: 0.7251 - val_loss: 1.2146 - val_accuracy: 0.6082
#
# Epoch 00092: val_accuracy did not improve from 0.61622
# Epoch 93/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8503 - accuracy: 0.7273 - val_loss: 1.2445 - val_accuracy: 0.6013
#
# Epoch 00093: val_accuracy did not improve from 0.61622
# Epoch 94/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8490 - accuracy: 0.7292 - val_loss: 1.2170 - val_accuracy: 0.6049
#
# Epoch 00094: val_accuracy did not improve from 0.61622
# Epoch 95/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8451 - accuracy: 0.7291 - val_loss: 1.2405 - val_accuracy: 0.6035
#
# Epoch 00095: val_accuracy did not improve from 0.61622
# Epoch 96/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8369 - accuracy: 0.7332 - val_loss: 1.2579 - val_accuracy: 0.5988
#
# Epoch 00096: val_accuracy did not improve from 0.61622
# Epoch 97/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.8276 - accuracy: 0.7355 - val_loss: 1.2592 - val_accuracy: 0.6060
#
# Epoch 00097: val_accuracy did not improve from 0.61622
# Epoch 98/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.8291 - accuracy: 0.7349 - val_loss: 1.2514 - val_accuracy: 0.6082
#
# Epoch 00098: val_accuracy did not improve from 0.61622
# Epoch 99/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8238 - accuracy: 0.7358 - val_loss: 1.2679 - val_accuracy: 0.5897
#
# Epoch 00099: val_accuracy did not improve from 0.61622
# Epoch 100/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.8192 - accuracy: 0.7426 - val_loss: 1.2911 - val_accuracy: 0.5915
#
# Epoch 00100: val_accuracy did not improve from 0.61622
# Epoch 101/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.8131 - accuracy: 0.7437 - val_loss: 1.2500 - val_accuracy: 0.6086
#
# Epoch 00101: val_accuracy did not improve from 0.61622
# Epoch 102/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.8129 - accuracy: 0.7433 - val_loss: 1.2719 - val_accuracy: 0.6068
#
# Epoch 00102: val_accuracy did not improve from 0.61622
# Epoch 103/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.8069 - accuracy: 0.7466 - val_loss: 1.3106 - val_accuracy: 0.5955
#
# Epoch 00103: val_accuracy did not improve from 0.61622
# Epoch 104/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.8008 - accuracy: 0.7478 - val_loss: 1.3003 - val_accuracy: 0.5951
#
# Epoch 00104: val_accuracy did not improve from 0.61622
# Epoch 105/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7918 - accuracy: 0.7515 - val_loss: 1.2877 - val_accuracy: 0.6122
#
# Epoch 00105: val_accuracy did not improve from 0.61622
# Epoch 106/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7980 - accuracy: 0.7465 - val_loss: 1.3049 - val_accuracy: 0.5995
#
# Epoch 00106: val_accuracy did not improve from 0.61622
# Epoch 107/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7900 - accuracy: 0.7516 - val_loss: 1.2890 - val_accuracy: 0.6049
#
# Epoch 00107: val_accuracy did not improve from 0.61622
# Epoch 108/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.7831 - accuracy: 0.7538 - val_loss: 1.3706 - val_accuracy: 0.5897
#
# Epoch 00108: val_accuracy did not improve from 0.61622
# Epoch 109/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7873 - accuracy: 0.7496 - val_loss: 1.3161 - val_accuracy: 0.6093
#
# Epoch 00109: val_accuracy did not improve from 0.61622
# Epoch 110/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.7803 - accuracy: 0.7525 - val_loss: 1.2695 - val_accuracy: 0.5966
#
# Epoch 00110: val_accuracy did not improve from 0.61622
# Epoch 111/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7722 - accuracy: 0.7578 - val_loss: 1.2473 - val_accuracy: 0.6064
#
# Epoch 00111: val_accuracy did not improve from 0.61622
# Epoch 112/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7695 - accuracy: 0.7566 - val_loss: 1.2753 - val_accuracy: 0.6079
#
# Epoch 00112: val_accuracy did not improve from 0.61622
# Epoch 113/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7597 - accuracy: 0.7636 - val_loss: 1.3061 - val_accuracy: 0.5999
#
# Epoch 00113: val_accuracy did not improve from 0.61622
# Epoch 114/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7665 - accuracy: 0.7605 - val_loss: 1.4038 - val_accuracy: 0.5879
#
# Epoch 00114: val_accuracy did not improve from 0.61622
# Epoch 115/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7571 - accuracy: 0.7634 - val_loss: 1.2970 - val_accuracy: 0.6075
#
# Epoch 00115: val_accuracy did not improve from 0.61622
# Epoch 116/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.7568 - accuracy: 0.7623 - val_loss: 1.3841 - val_accuracy: 0.6119
#
# Epoch 00116: val_accuracy did not improve from 0.61622
# Epoch 117/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7531 - accuracy: 0.7631 - val_loss: 1.2982 - val_accuracy: 0.6115
#
# Epoch 00117: val_accuracy did not improve from 0.61622
# Epoch 118/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7448 - accuracy: 0.7674 - val_loss: 1.3267 - val_accuracy: 0.6057
#
# Epoch 00118: val_accuracy did not improve from 0.61622
# Epoch 119/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7516 - accuracy: 0.7645 - val_loss: 1.3253 - val_accuracy: 0.5940
#
# Epoch 00119: val_accuracy did not improve from 0.61622
# Epoch 120/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.7438 - accuracy: 0.7674 - val_loss: 1.2954 - val_accuracy: 0.6053
#
# Epoch 00120: val_accuracy did not improve from 0.61622
# Epoch 121/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.7337 - accuracy: 0.7728 - val_loss: 1.3427 - val_accuracy: 0.5864
#
# Epoch 00121: val_accuracy did not improve from 0.61622
# Epoch 122/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7330 - accuracy: 0.7713 - val_loss: 1.3227 - val_accuracy: 0.6079
#
# Epoch 00122: val_accuracy did not improve from 0.61622
# Epoch 123/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7316 - accuracy: 0.7692 - val_loss: 1.3571 - val_accuracy: 0.6057
#
# Epoch 00123: val_accuracy did not improve from 0.61622
# Epoch 124/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.7322 - accuracy: 0.7688 - val_loss: 1.3385 - val_accuracy: 0.5937
#
# Epoch 00124: val_accuracy did not improve from 0.61622
# Epoch 125/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.7262 - accuracy: 0.7752 - val_loss: 1.4069 - val_accuracy: 0.5919
#
# Epoch 00125: val_accuracy did not improve from 0.61622
# Epoch 126/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.7304 - accuracy: 0.7713 - val_loss: 1.3139 - val_accuracy: 0.5984
#
# Epoch 00126: val_accuracy did not improve from 0.61622
# Epoch 127/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7235 - accuracy: 0.7742 - val_loss: 1.3403 - val_accuracy: 0.5853
#
# Epoch 00127: val_accuracy did not improve from 0.61622
# Epoch 128/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.7229 - accuracy: 0.7721 - val_loss: 1.3581 - val_accuracy: 0.6009
#
# Epoch 00128: val_accuracy did not improve from 0.61622
# Epoch 129/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.7116 - accuracy: 0.7793 - val_loss: 1.4257 - val_accuracy: 0.6046
#
# Epoch 00129: val_accuracy did not improve from 0.61622
# Epoch 130/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.7087 - accuracy: 0.7821 - val_loss: 1.3495 - val_accuracy: 0.6053
#
# Epoch 00130: val_accuracy did not improve from 0.61622
# Epoch 131/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.7071 - accuracy: 0.7814 - val_loss: 1.4079 - val_accuracy: 0.6020
#
# Epoch 00131: val_accuracy did not improve from 0.61622
# Epoch 132/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 474ms/step - loss: 0.7070 - accuracy: 0.7818 - val_loss: 1.4153 - val_accuracy: 0.5893
#
# Epoch 00132: val_accuracy did not improve from 0.61622
# Epoch 133/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6945 - accuracy: 0.7856 - val_loss: 1.4220 - val_accuracy: 0.5966
#
# Epoch 00133: val_accuracy did not improve from 0.61622
# Epoch 134/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6968 - accuracy: 0.7874 - val_loss: 1.4365 - val_accuracy: 0.6006
#
# Epoch 00134: val_accuracy did not improve from 0.61622
# Epoch 135/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6987 - accuracy: 0.7828 - val_loss: 1.4458 - val_accuracy: 0.5988
#
# Epoch 00135: val_accuracy did not improve from 0.61622
# Epoch 136/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6909 - accuracy: 0.7875 - val_loss: 1.3529 - val_accuracy: 0.6035
#
# Epoch 00136: val_accuracy did not improve from 0.61622
# Epoch 137/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6931 - accuracy: 0.7896 - val_loss: 1.4162 - val_accuracy: 0.5955
#
# Epoch 00137: val_accuracy did not improve from 0.61622
# Epoch 138/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 471ms/step - loss: 0.6831 - accuracy: 0.7889 - val_loss: 1.4095 - val_accuracy: 0.6002
#
# Epoch 00138: val_accuracy did not improve from 0.61622
# Epoch 139/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6872 - accuracy: 0.7872 - val_loss: 1.4320 - val_accuracy: 0.5886
#
# Epoch 00139: val_accuracy did not improve from 0.61622
# Epoch 140/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6845 - accuracy: 0.7892 - val_loss: 1.4016 - val_accuracy: 0.5988
#
# Epoch 00140: val_accuracy did not improve from 0.61622
# Epoch 141/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 473ms/step - loss: 0.6736 - accuracy: 0.7950 - val_loss: 1.4422 - val_accuracy: 0.5977
#
# Epoch 00141: val_accuracy did not improve from 0.61622
# Epoch 142/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6851 - accuracy: 0.7897 - val_loss: 1.4066 - val_accuracy: 0.5995
#
# Epoch 00142: val_accuracy did not improve from 0.61622
# Epoch 143/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6812 - accuracy: 0.7895 - val_loss: 1.3785 - val_accuracy: 0.5977
#
# Epoch 00143: val_accuracy did not improve from 0.61622
# Epoch 144/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.6685 - accuracy: 0.7959 - val_loss: 1.4162 - val_accuracy: 0.6035
#
# Epoch 00144: val_accuracy did not improve from 0.61622
# Epoch 145/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6727 - accuracy: 0.7938 - val_loss: 1.4057 - val_accuracy: 0.6144
#
# Epoch 00145: val_accuracy did not improve from 0.61622
# Epoch 146/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.6636 - accuracy: 0.7971 - val_loss: 1.4557 - val_accuracy: 0.6002
#
# Epoch 00146: val_accuracy did not improve from 0.61622
# Epoch 147/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6587 - accuracy: 0.7989 - val_loss: 1.5298 - val_accuracy: 0.5820
#
# Epoch 00147: val_accuracy did not improve from 0.61622
# Epoch 148/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 459ms/step - loss: 0.6552 - accuracy: 0.8010 - val_loss: 1.4548 - val_accuracy: 0.5955
#
# Epoch 00148: val_accuracy did not improve from 0.61622
# Epoch 149/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.6595 - accuracy: 0.7969 - val_loss: 1.5045 - val_accuracy: 0.5966
#
# Epoch 00149: val_accuracy did not improve from 0.61622
# Epoch 150/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.6587 - accuracy: 0.8006 - val_loss: 1.5780 - val_accuracy: 0.5988
#
# Epoch 00150: val_accuracy did not improve from 0.61622
# Epoch 151/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6601 - accuracy: 0.7997 - val_loss: 1.4967 - val_accuracy: 0.5875
#
# Epoch 00151: val_accuracy did not improve from 0.61622
# Epoch 152/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6476 - accuracy: 0.8036 - val_loss: 1.5016 - val_accuracy: 0.5838
#
# Epoch 00152: val_accuracy did not improve from 0.61622
# Epoch 153/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6470 - accuracy: 0.8021 - val_loss: 1.4594 - val_accuracy: 0.6002
#
# Epoch 00153: val_accuracy did not improve from 0.61622
# Epoch 154/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.6478 - accuracy: 0.8061 - val_loss: 1.4978 - val_accuracy: 0.6039
#
# Epoch 00154: val_accuracy did not improve from 0.61622
# Epoch 155/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.6451 - accuracy: 0.8010 - val_loss: 1.5646 - val_accuracy: 0.5926
#
# Epoch 00155: val_accuracy did not improve from 0.61622
# Epoch 156/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.6313 - accuracy: 0.8101 - val_loss: 1.6156 - val_accuracy: 0.5897
#
# Epoch 00156: val_accuracy did not improve from 0.61622
# Epoch 157/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6382 - accuracy: 0.8071 - val_loss: 1.4983 - val_accuracy: 0.5962
#
# Epoch 00157: val_accuracy did not improve from 0.61622
# Epoch 158/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.6357 - accuracy: 0.8069 - val_loss: 1.5022 - val_accuracy: 0.5922
#
# Epoch 00158: val_accuracy did not improve from 0.61622
# Epoch 159/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.6331 - accuracy: 0.8083 - val_loss: 1.5308 - val_accuracy: 0.6060
#
# Epoch 00159: val_accuracy did not improve from 0.61622
# Epoch 160/200
# Learning rate:  0.001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.6391 - accuracy: 0.8085 - val_loss: 1.5336 - val_accuracy: 0.5875
#
# Epoch 00160: val_accuracy did not improve from 0.61622
# Epoch 161/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 459ms/step - loss: 0.6093 - accuracy: 0.8201 - val_loss: 1.4700 - val_accuracy: 0.6170
#
# Epoch 00161: val_accuracy improved from 0.61622 to 0.61695, saving model to /content/saved_models/FER2013_model.h5
# Epoch 162/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5866 - accuracy: 0.8288 - val_loss: 1.4796 - val_accuracy: 0.6140
#
# Epoch 00162: val_accuracy did not improve from 0.61695
# Epoch 163/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5754 - accuracy: 0.8321 - val_loss: 1.4811 - val_accuracy: 0.6100
#
# Epoch 00163: val_accuracy did not improve from 0.61695
# Epoch 164/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5741 - accuracy: 0.8331 - val_loss: 1.4917 - val_accuracy: 0.6097
#
# Epoch 00164: val_accuracy did not improve from 0.61695
# Epoch 165/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5718 - accuracy: 0.8327 - val_loss: 1.4972 - val_accuracy: 0.6108
#
# Epoch 00165: val_accuracy did not improve from 0.61695
# Epoch 166/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.5709 - accuracy: 0.8336 - val_loss: 1.5049 - val_accuracy: 0.6140
#
# Epoch 00166: val_accuracy did not improve from 0.61695
# Epoch 167/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5690 - accuracy: 0.8345 - val_loss: 1.5005 - val_accuracy: 0.6082
#
# Epoch 00167: val_accuracy did not improve from 0.61695
# Epoch 168/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5615 - accuracy: 0.8383 - val_loss: 1.5079 - val_accuracy: 0.6111
#
# Epoch 00168: val_accuracy did not improve from 0.61695
# Epoch 169/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 465ms/step - loss: 0.5558 - accuracy: 0.8426 - val_loss: 1.5251 - val_accuracy: 0.6137
#
# Epoch 00169: val_accuracy did not improve from 0.61695
# Epoch 170/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5527 - accuracy: 0.8405 - val_loss: 1.5241 - val_accuracy: 0.6089
#
# Epoch 00170: val_accuracy did not improve from 0.61695
# Epoch 171/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5486 - accuracy: 0.8441 - val_loss: 1.5371 - val_accuracy: 0.6100
#
# Epoch 00171: val_accuracy did not improve from 0.61695
# Epoch 172/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5497 - accuracy: 0.8441 - val_loss: 1.5390 - val_accuracy: 0.6097
#
# Epoch 00172: val_accuracy did not improve from 0.61695
# Epoch 173/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5481 - accuracy: 0.8425 - val_loss: 1.5434 - val_accuracy: 0.6104
#
# Epoch 00173: val_accuracy did not improve from 0.61695
# Epoch 174/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5520 - accuracy: 0.8419 - val_loss: 1.5394 - val_accuracy: 0.6086
#
# Epoch 00174: val_accuracy did not improve from 0.61695
# Epoch 175/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 480ms/step - loss: 0.5446 - accuracy: 0.8442 - val_loss: 1.5454 - val_accuracy: 0.6126
#
# Epoch 00175: val_accuracy did not improve from 0.61695
# Epoch 176/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5419 - accuracy: 0.8477 - val_loss: 1.5411 - val_accuracy: 0.6144
#
# Epoch 00176: val_accuracy did not improve from 0.61695
# Epoch 177/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.5498 - accuracy: 0.8427 - val_loss: 1.5411 - val_accuracy: 0.6104
#
# Epoch 00177: val_accuracy did not improve from 0.61695
# Epoch 178/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 460ms/step - loss: 0.5573 - accuracy: 0.8350 - val_loss: 1.5440 - val_accuracy: 0.6060
#
# Epoch 00178: val_accuracy did not improve from 0.61695
# Epoch 179/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5387 - accuracy: 0.8460 - val_loss: 1.5479 - val_accuracy: 0.6075
#
# Epoch 00179: val_accuracy did not improve from 0.61695
# Epoch 180/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5423 - accuracy: 0.8458 - val_loss: 1.5589 - val_accuracy: 0.6100
#
# Epoch 00180: val_accuracy did not improve from 0.61695
# Epoch 181/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5433 - accuracy: 0.8478 - val_loss: 1.5578 - val_accuracy: 0.6089
#
# Epoch 00181: val_accuracy did not improve from 0.61695
# Epoch 182/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 463ms/step - loss: 0.5379 - accuracy: 0.8483 - val_loss: 1.5666 - val_accuracy: 0.6122
#
# Epoch 00182: val_accuracy did not improve from 0.61695
# Epoch 183/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5445 - accuracy: 0.8447 - val_loss: 1.5588 - val_accuracy: 0.6079
#
# Epoch 00183: val_accuracy did not improve from 0.61695
# Epoch 184/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5381 - accuracy: 0.8470 - val_loss: 1.5594 - val_accuracy: 0.6111
#
# Epoch 00184: val_accuracy did not improve from 0.61695
# Epoch 185/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 461ms/step - loss: 0.5412 - accuracy: 0.8465 - val_loss: 1.5644 - val_accuracy: 0.6130
#
# Epoch 00185: val_accuracy did not improve from 0.61695
# Epoch 186/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5415 - accuracy: 0.8443 - val_loss: 1.5673 - val_accuracy: 0.6137
#
# Epoch 00186: val_accuracy did not improve from 0.61695
# Epoch 187/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5361 - accuracy: 0.8483 - val_loss: 1.5566 - val_accuracy: 0.6079
#
# Epoch 00187: val_accuracy did not improve from 0.61695
# Epoch 188/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5320 - accuracy: 0.8484 - val_loss: 1.5582 - val_accuracy: 0.6111
#
# Epoch 00188: val_accuracy did not improve from 0.61695
# Epoch 189/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 466ms/step - loss: 0.5299 - accuracy: 0.8491 - val_loss: 1.5576 - val_accuracy: 0.6137
#
# Epoch 00189: val_accuracy did not improve from 0.61695
# Epoch 190/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5307 - accuracy: 0.8488 - val_loss: 1.5616 - val_accuracy: 0.6144
#
# Epoch 00190: val_accuracy did not improve from 0.61695
# Epoch 191/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 468ms/step - loss: 0.5341 - accuracy: 0.8485 - val_loss: 1.5771 - val_accuracy: 0.6079
#
# Epoch 00191: val_accuracy did not improve from 0.61695
# Epoch 192/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5334 - accuracy: 0.8455 - val_loss: 1.5808 - val_accuracy: 0.6042
#
# Epoch 00192: val_accuracy did not improve from 0.61695
# Epoch 193/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5339 - accuracy: 0.8471 - val_loss: 1.5951 - val_accuracy: 0.6079
#
# Epoch 00193: val_accuracy did not improve from 0.61695
# Epoch 194/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5238 - accuracy: 0.8518 - val_loss: 1.6055 - val_accuracy: 0.6108
#
# Epoch 00194: val_accuracy did not improve from 0.61695
# Epoch 195/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 469ms/step - loss: 0.5303 - accuracy: 0.8464 - val_loss: 1.5957 - val_accuracy: 0.6064
#
# Epoch 00195: val_accuracy did not improve from 0.61695
# Epoch 196/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 462ms/step - loss: 0.5267 - accuracy: 0.8509 - val_loss: 1.5877 - val_accuracy: 0.6086
#
# Epoch 00196: val_accuracy did not improve from 0.61695
# Epoch 197/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 464ms/step - loss: 0.5282 - accuracy: 0.8489 - val_loss: 1.6015 - val_accuracy: 0.6108
#
# Epoch 00197: val_accuracy did not improve from 0.61695
# Epoch 198/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 470ms/step - loss: 0.5206 - accuracy: 0.8537 - val_loss: 1.5858 - val_accuracy: 0.6082
#
# Epoch 00198: val_accuracy did not improve from 0.61695
# Epoch 199/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 467ms/step - loss: 0.5250 - accuracy: 0.8508 - val_loss: 1.5903 - val_accuracy: 0.6082
#
# Epoch 00199: val_accuracy did not improve from 0.61695
# Epoch 200/200
# Learning rate:  0.0001
# 44/44 [==============================] - 21s 472ms/step - loss: 0.5229 - accuracy: 0.8523 - val_loss: 1.5858 - val_accuracy: 0.6097
#
# Epoch 00200: val_accuracy did not improve from 0.61695
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
best_model = keras.models.load_model('/content/saved_models/FER2013_model.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 87/87 [==============================] - 4s 26ms/step - loss: 1.3179 - accuracy: 0.6505
# [1.3179157972335815, 0.6504537463188171]

# %%
#test images
from sklearn.metrics import confusion_matrix
import seaborn as sn
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013, JAFFE

print('Labels Dictionary:')
print(emotion)
print('Number of predition samples = ', len(x_test))
pred = model.predict(x_test)
cm = confusion_matrix( np.argmax(y_test,1),pred.argmax(1),normalize='pred')
#cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize =(10,6))
sn.heatmap(cm, annot=True, annot_kws={"size": 12},cmap=plt.cm.Blues) # font size
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Labels Dictionary:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
# Number of predition samples =  2755

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x,y = load_CKplus_full()

x.shape, y.shape
# Out:
# ((981, 48, 48, 1), (981, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 15 kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=28d884796f3fdc85dabd62818b37bae77c92c54fb4461319715c930b1023f845
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*255)/math.log(mean)
  img = np.power(img, gamma).clip(0,255).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x, y = pre_process(x, y)

#For conveniency when training
trainx = x.copy()
trainy = y.copy()

x.shape, y.shape
# Out:
# ((981, 48, 48, 1), (981, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x,y)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os
from one_cycle_lr import OneCycleLr


# Training parameters
batch_size = 128
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
# Choose what attention_module to use: cbam_block / se_block / None
model_type = base_model if attention_module==None else base_model+' '+attention_module


# Load dataset.
x = trainx.copy()
y = trainy.copy()

x, x_val, y, y_val = train_test_split(x, y,test_size=0.2, random_state=2021)

# Input image dimensions.
input_shape = x.shape[1:]

# Normalize data.
x = x.astype('float32') / 255
x_val = x_val.astype('float32') / 255

# Convert class vectors to binary class matrices.
y = to_categorical(y, num_classes)
y_val = to_categorical(y_val, num_classes)


# This will preprocessing data augmentation:
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)
datagen.fit(x)

for imgs, labels in datagen.flow(x, y,batch_size = len(x_train), seed=2021):
  x_train = imgs
  y_train = labels
  break

depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(),#SGD(momentum=0.9, clipvalue=0.1), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'model.{epoch:03d}.h5' + model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)
# 1 cycle learning rate
one_c = OneCycleLr(max_lr=0.1, steps_per_epoch=len(x_train), epochs=epochs)

#Early stopping
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=20)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, one_c, early_stop]

history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Score trained model.
#scores = model.evaluate(x_test, y_test, verbose=1,batch_size=batch_size,)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 11s 469ms/step - loss: 2.2871 - accuracy: 0.2500 - val_loss: 2.1906 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/200
# 7/7 [==============================] - 1s 154ms/step - loss: 1.8997 - accuracy: 0.3061 - val_loss: 2.3757 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/200
# 7/7 [==============================] - 1s 152ms/step - loss: 1.8335 - accuracy: 0.3801 - val_loss: 3.9143 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/200
# 7/7 [==============================] - 1s 152ms/step - loss: 1.6891 - accuracy: 0.4082 - val_loss: 17.0087 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/200
# 7/7 [==============================] - 1s 153ms/step - loss: 1.4611 - accuracy: 0.5230 - val_loss: 38.5161 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/200
# 7/7 [==============================] - 1s 156ms/step - loss: 1.2580 - accuracy: 0.6122 - val_loss: 148.1026 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/200
# 7/7 [==============================] - 1s 152ms/step - loss: 1.0354 - accuracy: 0.7041 - val_loss: 87.1474 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.8747 - accuracy: 0.7398 - val_loss: 26.3913 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.7755 - accuracy: 0.7985 - val_loss: 74.5673 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.7472 - accuracy: 0.7844 - val_loss: 8.7582 - val_accuracy: 0.2234
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.6641 - accuracy: 0.8214 - val_loss: 5.1587 - val_accuracy: 0.2234
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.6113 - accuracy: 0.8559 - val_loss: 5.9198 - val_accuracy: 0.2538
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.6346 - accuracy: 0.8355 - val_loss: 27.3322 - val_accuracy: 0.1929
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.5603 - accuracy: 0.8571 - val_loss: 8.9312 - val_accuracy: 0.2183
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.4633 - accuracy: 0.9043 - val_loss: 7.7924 - val_accuracy: 0.1066
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.4374 - accuracy: 0.9133 - val_loss: 16.3539 - val_accuracy: 0.2741
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.4235 - accuracy: 0.9158 - val_loss: 15.2606 - val_accuracy: 0.2234
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.3522 - accuracy: 0.9439 - val_loss: 20.0377 - val_accuracy: 0.1218
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.3413 - accuracy: 0.9503 - val_loss: 16.8837 - val_accuracy: 0.1320
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.3566 - accuracy: 0.9388 - val_loss: 15.5026 - val_accuracy: 0.0914
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.3722 - accuracy: 0.9209 - val_loss: 14.7424 - val_accuracy: 0.0660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.3030 - accuracy: 0.9643 - val_loss: 15.1500 - val_accuracy: 0.0863
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2794 - accuracy: 0.9719 - val_loss: 7.7456 - val_accuracy: 0.2487
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2936 - accuracy: 0.9707 - val_loss: 7.5590 - val_accuracy: 0.2589
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2410 - accuracy: 0.9821 - val_loss: 7.2895 - val_accuracy: 0.2843
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/200
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2409 - accuracy: 0.9860 - val_loss: 6.3170 - val_accuracy: 0.2690
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2181 - accuracy: 0.9923 - val_loss: 4.3069 - val_accuracy: 0.3503
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2231 - accuracy: 0.9885 - val_loss: 3.0896 - val_accuracy: 0.5533
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2294 - accuracy: 0.9783 - val_loss: 2.2247 - val_accuracy: 0.5787
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2975 - accuracy: 0.9554 - val_loss: 2.4770 - val_accuracy: 0.5939
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.3290 - accuracy: 0.9477 - val_loss: 6.3442 - val_accuracy: 0.4061
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2850 - accuracy: 0.9643 - val_loss: 7.8535 - val_accuracy: 0.3655
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.3489 - accuracy: 0.9388 - val_loss: 27.3002 - val_accuracy: 0.1066
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.3196 - accuracy: 0.9477 - val_loss: 8.0697 - val_accuracy: 0.3046
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2642 - accuracy: 0.9758 - val_loss: 5.2362 - val_accuracy: 0.4569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2605 - accuracy: 0.9809 - val_loss: 6.0301 - val_accuracy: 0.4670
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2321 - accuracy: 0.9860 - val_loss: 7.5157 - val_accuracy: 0.3604
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2210 - accuracy: 0.9911 - val_loss: 9.4229 - val_accuracy: 0.3350
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2249 - accuracy: 0.9898 - val_loss: 9.6060 - val_accuracy: 0.3503
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/200
# 7/7 [==============================] - 1s 150ms/step - loss: 0.2699 - accuracy: 0.9796 - val_loss: 9.4670 - val_accuracy: 0.2437
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/200
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2284 - accuracy: 0.9898 - val_loss: 10.9828 - val_accuracy: 0.1421
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2105 - accuracy: 0.9936 - val_loss: 6.7969 - val_accuracy: 0.2589
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2168 - accuracy: 0.9911 - val_loss: 3.6959 - val_accuracy: 0.3909
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/200
# 7/7 [==============================] - 1s 169ms/step - loss: 0.2390 - accuracy: 0.9821 - val_loss: 4.3213 - val_accuracy: 0.4162
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2336 - accuracy: 0.9885 - val_loss: 3.3922 - val_accuracy: 0.5178
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2389 - accuracy: 0.9821 - val_loss: 2.8651 - val_accuracy: 0.5025
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/200
# 7/7 [==============================] - 1s 157ms/step - loss: 0.2592 - accuracy: 0.9758 - val_loss: 4.8930 - val_accuracy: 0.2437
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2592 - accuracy: 0.9758 - val_loss: 2.0101 - val_accuracy: 0.6599
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/200
# 7/7 [==============================] - 1s 159ms/step - loss: 0.2586 - accuracy: 0.9745 - val_loss: 4.1680 - val_accuracy: 0.3756
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2805 - accuracy: 0.9643 - val_loss: 5.0881 - val_accuracy: 0.2995
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2583 - accuracy: 0.9694 - val_loss: 4.6875 - val_accuracy: 0.2944
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2246 - accuracy: 0.9872 - val_loss: 5.9232 - val_accuracy: 0.2335
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2117 - accuracy: 0.9936 - val_loss: 5.3879 - val_accuracy: 0.2183
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2822 - accuracy: 0.9719 - val_loss: 4.8500 - val_accuracy: 0.3249
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/200
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2431 - accuracy: 0.9796 - val_loss: 3.5403 - val_accuracy: 0.4010
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2417 - accuracy: 0.9847 - val_loss: 3.2196 - val_accuracy: 0.4569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2425 - accuracy: 0.9847 - val_loss: 1.7756 - val_accuracy: 0.6244
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2141 - accuracy: 0.9923 - val_loss: 1.2850 - val_accuracy: 0.7817
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2047 - accuracy: 0.9962 - val_loss: 2.1628 - val_accuracy: 0.6244
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2017 - accuracy: 0.9962 - val_loss: 1.1948 - val_accuracy: 0.7513
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/200
# 7/7 [==============================] - 1s 157ms/step - loss: 0.1894 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.8376
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/200
# 7/7 [==============================] - 1s 158ms/step - loss: 0.1865 - accuracy: 1.0000 - val_loss: 0.6864 - val_accuracy: 0.8477
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.1847 - accuracy: 1.0000 - val_loss: 0.7002 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.1821 - accuracy: 1.0000 - val_loss: 0.6754 - val_accuracy: 0.8680
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.1798 - accuracy: 1.0000 - val_loss: 0.6679 - val_accuracy: 0.8782
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.1779 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.8985
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1764 - accuracy: 1.0000 - val_loss: 0.7164 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1792 - accuracy: 0.9974 - val_loss: 0.6460 - val_accuracy: 0.8579
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2393 - accuracy: 0.9847 - val_loss: 2.2955 - val_accuracy: 0.4315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2603 - accuracy: 0.9770 - val_loss: 1.5082 - val_accuracy: 0.6904
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2418 - accuracy: 0.9783 - val_loss: 2.1146 - val_accuracy: 0.5787
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2106 - accuracy: 0.9898 - val_loss: 1.9044 - val_accuracy: 0.5584
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2065 - accuracy: 0.9923 - val_loss: 2.3390 - val_accuracy: 0.5330
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2093 - accuracy: 0.9872 - val_loss: 3.2846 - val_accuracy: 0.4670
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/200
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2375 - accuracy: 0.9707 - val_loss: 2.8384 - val_accuracy: 0.5127
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.3527 - accuracy: 0.9554 - val_loss: 1.6067 - val_accuracy: 0.6345
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/200
# 7/7 [==============================] - 1s 157ms/step - loss: 0.2520 - accuracy: 0.9732 - val_loss: 1.6472 - val_accuracy: 0.7411
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2675 - accuracy: 0.9707 - val_loss: 1.6887 - val_accuracy: 0.7208
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/200
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2387 - accuracy: 0.9809 - val_loss: 1.7666 - val_accuracy: 0.6802
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/200
# 7/7 [==============================] - 1s 157ms/step - loss: 0.2222 - accuracy: 0.9847 - val_loss: 1.8727 - val_accuracy: 0.6802
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/200
# 7/7 [==============================] - 1s 152ms/step - loss: 0.2076 - accuracy: 0.9936 - val_loss: 1.5363 - val_accuracy: 0.7310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 82/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2102 - accuracy: 0.9911 - val_loss: 1.5233 - val_accuracy: 0.7360
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 83/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.1981 - accuracy: 0.9949 - val_loss: 1.4977 - val_accuracy: 0.7462
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 84/200
# 7/7 [==============================] - 1s 155ms/step - loss: 0.1985 - accuracy: 0.9974 - val_loss: 1.3354 - val_accuracy: 0.7462
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 85/200
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2023 - accuracy: 0.9936 - val_loss: 1.1253 - val_accuracy: 0.8020
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 86/200
# 7/7 [==============================] - 1s 160ms/step - loss: 0.1932 - accuracy: 0.9962 - val_loss: 0.9612 - val_accuracy: 0.8122
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00086: early stopping
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

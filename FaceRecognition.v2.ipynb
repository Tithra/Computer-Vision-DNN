# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd


data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SIT723/fer2013.csv')

pixels = data['pixels']
emotions = data['emotion']
usages = data['Usage']

num_of_instances = len(data) #Get the number of data sets
print("The number of data sets is:",num_of_instances)

# %%
#Tidy up the dataset
from tensorflow.keras.utils import to_categorical

#emotions_Str=['anger','disgust','fear','happy','neutral','sad','surprised']
num_classes = 7   #Number of emoticons
x_train,y_train,x_val,y_val,x_test,y_test = [],[],[],[],[],[]
from tqdm import tqdm
for i in tqdm(range(num_of_instances)):
    #one_hot_label = to_categorical(emotions[i],num_classes) #Tags are converted to one-hot encoding to meet the data requirements of keras
    img = list(map(eval,pixels[i].split(' ')))
    np_img = np.asarray(img)
    img = np_img.reshape(48,48)
    if usages[i] == 'Training':
        x_train.append(img)
        y_train.append(emotions[i])
    elif usages[i] == 'PrivateTest':
        x_val.append(img)
        y_val.append(emotions[i])
    else:
        x_test.append(img)
        y_test.append(emotions[i])

# convert data to array format
x_train = np.array(x_train)
y_train = np.array(y_train)
x_train = x_train.reshape(-1,48,48,1)
x_test = np.array(x_test)
y_test = np.array(y_test)
x_test = x_test.reshape(-1,48,48,1)
x_val = np.array(x_val).reshape(-1,48,48,1)
y_val = np.array(y_val)

#Length and shape of data
print('Length of training, testing, validating are:')
len(x_train),len(x_test),len(x_val)

x_val.shape
# Out:
# 100%|██████████| 35887/35887 [04:40<00:00, 128.13it/s]
# Length of training, testing, validating are:
# (3589, 48, 48, 1)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_CKplus() 

x_train = np.array(x_train)
x_train = x_train.reshape(len(x_train),48,48,1)
y_train = np.array(y_train)
x_test = np.array(x_test)
x_test = x_test.reshape(len(x_test),48,48,1)
y_test = np.array(y_test)
x_val = np.array(x_val)
x_val = x_val.reshape(len(x_val),48,48,1)
y_val = np.array(y_val)

# view the shape of dataset
x_train.shape, x_test.shape, x_val.shape
# Out:
# ((687, 48, 48, 1), (147, 48, 48, 1), (147, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 25 kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=7e5d5a755941a58dd1d5d8d69a0d0a5c04958e9fccc3323db49ce32a645fb86e
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
face_cascade = cv2.CascadeClassifier()
if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)
def transform(img):
        img = cv2.resize(img, (48,48))
        #gamma
        mid = 0.5 
        mean = np.mean(img)
        gamma = math.log(mid*255)/math.log(mean)
        img = np.power(img, gamma).clip(0,255).astype(np.uint8)

        img = Image.fromarray(img)
        #filter = ImageEnhance.Contrast(img)# add contrast
        #img = filter.enhance(1.0)
        #filter = ImageEnhance.Sharpness(img)# sharpen
        #img = filter.enhance(3.0)
        img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss

        img = np.array(img)
        img = img.reshape(48,48,1)
        return img

def pre_process(input, target):
  count = 0
  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      img = img[y:y + h, x:x + w]
      #x_temp.append(transform(imp))
      x_temp.append(transform(input[i]))
      y_temp.append(target[i])
      count += 1
    else: 
      if (len(face_detect_2)>0):
        (x, y, w, h) = face_detect_2[0]
        img = img[y:y + h, x:x + w]
        #x_temp.append(transform(img))
        x_temp.append(transform(input[i]))
        y_temp.append(target[i])
        count += 1
    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp
  #pd.DataFrame(x_temp.reshape(len(x_temp),2304)).to_csv('x_train.csv',header=None,index=None)
  #pd.DataFrame(y_temp).to_csv('y_train.csv',header=None,index=None)

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((687, 48, 48, 1), (147, 48, 48, 1), (147, 48, 48, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
#emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
print("Display 25 images from the train set in the form of 5x5 matrix with their respective labels:")
plt.figure(figsize=[8,8])
for i in range(25):
  plt.subplot(5,5,1+i)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_train[i].reshape([48,48]), cmap='gray')
  plt.title(emotion[int(y_train[i])])

plt.show()
# Out:
# Display 25 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import os

# Training parameters
batch_size = 128
epochs = 80
data_augmentation = False
num_classes = 7
subtract_pixel_mean = False  # Subtracting pixel mean improves accuracy
base_model = 'MobileNet'
# Choose what attention_module to use: cbam_block / se_block / None


# Load the CIFAR10 data.
#(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Load the copy of Dataset
x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
#x_val = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= 40:
      lr = 0.0001
    elif epoch >= 20:
      lr=0.001
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)


callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    #history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val), shuffle=True,callbacks=callbacks)
    history = model.fit(x_train, y_train,batch_size=batch_size, epochs=epochs,validation_data=(x_val, y_val),shuffle=True, callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    #history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)


def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 48, 48, 16)   160         input_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 48, 48, 16)   64          conv2d_309[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 48, 48, 16)   0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 48, 48, 16)   2320        activation_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 48, 48, 16)   64          conv2d_310[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 48, 48, 16)   0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 48, 48, 16)   2320        activation_285[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 48, 48, 16)   64          conv2d_311[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_54 (Gl (None, 16)           0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_54 (Global (None, 16)           0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# reshape_108 (Reshape)           (None, 1, 1, 16)     0           global_average_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# reshape_109 (Reshape)           (None, 1, 1, 16)     0           global_max_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# dense_120 (Dense)               (None, 1, 1, 2)      34          reshape_108[0][0]
#                                                                  reshape_109[0][0]
# __________________________________________________________________________________________________
# dense_121 (Dense)               (None, 1, 1, 16)     48          dense_120[0][0]
#                                                                  dense_120[1][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 1, 1, 16)     0           dense_121[0][0]
#                                                                  dense_121[1][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 1, 1, 16)     0           add_162[0][0]
# __________________________________________________________________________________________________
# multiply_108 (Multiply)         (None, 48, 48, 16)   0           batch_normalization_233[0][0]
#                                                                  activation_286[0][0]
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 48, 48, 1)    0           multiply_108[0][0]
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 48, 48, 1)    0           multiply_108[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 48, 48, 2)    0           lambda_108[0][0]
#                                                                  lambda_109[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 48, 48, 1)    98          concatenate_54[0][0]
# __________________________________________________________________________________________________
# multiply_109 (Multiply)         (None, 48, 48, 16)   0           multiply_108[0][0]
#                                                                  conv2d_312[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 48, 48, 16)   0           activation_284[0][0]
#                                                                  multiply_109[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 48, 48, 16)   0           add_163[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 48, 48, 16)   2320        activation_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 48, 48, 16)   64          conv2d_313[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 48, 48, 16)   0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 48, 48, 16)   2320        activation_288[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 48, 48, 16)   64          conv2d_314[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_55 (Gl (None, 16)           0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_55 (Global (None, 16)           0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# reshape_110 (Reshape)           (None, 1, 1, 16)     0           global_average_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# reshape_111 (Reshape)           (None, 1, 1, 16)     0           global_max_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# dense_122 (Dense)               (None, 1, 1, 2)      34          reshape_110[0][0]
#                                                                  reshape_111[0][0]
# __________________________________________________________________________________________________
# dense_123 (Dense)               (None, 1, 1, 16)     48          dense_122[0][0]
#                                                                  dense_122[1][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 1, 1, 16)     0           dense_123[0][0]
#                                                                  dense_123[1][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 1, 1, 16)     0           add_164[0][0]
# __________________________________________________________________________________________________
# multiply_110 (Multiply)         (None, 48, 48, 16)   0           batch_normalization_235[0][0]
#                                                                  activation_289[0][0]
# __________________________________________________________________________________________________
# lambda_110 (Lambda)             (None, 48, 48, 1)    0           multiply_110[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 48, 48, 1)    0           multiply_110[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 48, 48, 2)    0           lambda_110[0][0]
#                                                                  lambda_111[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 48, 48, 1)    98          concatenate_55[0][0]
# __________________________________________________________________________________________________
# multiply_111 (Multiply)         (None, 48, 48, 16)   0           multiply_110[0][0]
#                                                                  conv2d_315[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 48, 48, 16)   0           activation_287[0][0]
#                                                                  multiply_111[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 48, 48, 16)   0           add_165[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, 48, 48, 16)   2320        activation_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 48, 48, 16)   64          conv2d_316[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 48, 48, 16)   0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, 48, 48, 16)   2320        activation_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 48, 48, 16)   64          conv2d_317[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_56 (Gl (None, 16)           0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_56 (Global (None, 16)           0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# reshape_112 (Reshape)           (None, 1, 1, 16)     0           global_average_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# reshape_113 (Reshape)           (None, 1, 1, 16)     0           global_max_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# dense_124 (Dense)               (None, 1, 1, 2)      34          reshape_112[0][0]
#                                                                  reshape_113[0][0]
# __________________________________________________________________________________________________
# dense_125 (Dense)               (None, 1, 1, 16)     48          dense_124[0][0]
#                                                                  dense_124[1][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 1, 1, 16)     0           dense_125[0][0]
#                                                                  dense_125[1][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 1, 1, 16)     0           add_166[0][0]
# __________________________________________________________________________________________________
# multiply_112 (Multiply)         (None, 48, 48, 16)   0           batch_normalization_237[0][0]
#                                                                  activation_292[0][0]
# __________________________________________________________________________________________________
# lambda_112 (Lambda)             (None, 48, 48, 1)    0           multiply_112[0][0]
# __________________________________________________________________________________________________
# lambda_113 (Lambda)             (None, 48, 48, 1)    0           multiply_112[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 48, 48, 2)    0           lambda_112[0][0]
#                                                                  lambda_113[0][0]
# __________________________________________________________________________________________________
# conv2d_318 (Conv2D)             (None, 48, 48, 1)    98          concatenate_56[0][0]
# __________________________________________________________________________________________________
# multiply_113 (Multiply)         (None, 48, 48, 16)   0           multiply_112[0][0]
#                                                                  conv2d_318[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 48, 48, 16)   0           activation_290[0][0]
#                                                                  multiply_113[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 48, 48, 16)   0           add_167[0][0]
# __________________________________________________________________________________________________
# conv2d_319 (Conv2D)             (None, 24, 24, 32)   4640        activation_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 24, 24, 32)   128         conv2d_319[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 24, 24, 32)   0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_320 (Conv2D)             (None, 24, 24, 32)   9248        activation_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 24, 24, 32)   128         conv2d_320[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_57 (Gl (None, 32)           0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_57 (Global (None, 32)           0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# reshape_114 (Reshape)           (None, 1, 1, 32)     0           global_average_pooling2d_57[0][0]
# __________________________________________________________________________________________________
# reshape_115 (Reshape)           (None, 1, 1, 32)     0           global_max_pooling2d_57[0][0]
# __________________________________________________________________________________________________
# dense_126 (Dense)               (None, 1, 1, 4)      132         reshape_114[0][0]
#                                                                  reshape_115[0][0]
# __________________________________________________________________________________________________
# dense_127 (Dense)               (None, 1, 1, 32)     160         dense_126[0][0]
#                                                                  dense_126[1][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 1, 1, 32)     0           dense_127[0][0]
#                                                                  dense_127[1][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 1, 1, 32)     0           add_168[0][0]
# __________________________________________________________________________________________________
# multiply_114 (Multiply)         (None, 24, 24, 32)   0           batch_normalization_239[0][0]
#                                                                  activation_295[0][0]
# __________________________________________________________________________________________________
# lambda_114 (Lambda)             (None, 24, 24, 1)    0           multiply_114[0][0]
# __________________________________________________________________________________________________
# lambda_115 (Lambda)             (None, 24, 24, 1)    0           multiply_114[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 24, 24, 2)    0           lambda_114[0][0]
#                                                                  lambda_115[0][0]
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, 24, 24, 1)    98          concatenate_57[0][0]
# __________________________________________________________________________________________________
# conv2d_321 (Conv2D)             (None, 24, 24, 32)   544         activation_293[0][0]
# __________________________________________________________________________________________________
# multiply_115 (Multiply)         (None, 24, 24, 32)   0           multiply_114[0][0]
#                                                                  conv2d_322[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 24, 24, 32)   0           conv2d_321[0][0]
#                                                                  multiply_115[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 24, 24, 32)   0           add_169[0][0]
# __________________________________________________________________________________________________
# conv2d_323 (Conv2D)             (None, 24, 24, 32)   9248        activation_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 24, 24, 32)   128         conv2d_323[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 24, 24, 32)   0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_324 (Conv2D)             (None, 24, 24, 32)   9248        activation_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 24, 24, 32)   128         conv2d_324[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_58 (Gl (None, 32)           0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_58 (Global (None, 32)           0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# reshape_116 (Reshape)           (None, 1, 1, 32)     0           global_average_pooling2d_58[0][0]
# __________________________________________________________________________________________________
# reshape_117 (Reshape)           (None, 1, 1, 32)     0           global_max_pooling2d_58[0][0]
# __________________________________________________________________________________________________
# dense_128 (Dense)               (None, 1, 1, 4)      132         reshape_116[0][0]
#                                                                  reshape_117[0][0]
# __________________________________________________________________________________________________
# dense_129 (Dense)               (None, 1, 1, 32)     160         dense_128[0][0]
#                                                                  dense_128[1][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 1, 1, 32)     0           dense_129[0][0]
#                                                                  dense_129[1][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 1, 1, 32)     0           add_170[0][0]
# __________________________________________________________________________________________________
# multiply_116 (Multiply)         (None, 24, 24, 32)   0           batch_normalization_241[0][0]
#                                                                  activation_298[0][0]
# __________________________________________________________________________________________________
# lambda_116 (Lambda)             (None, 24, 24, 1)    0           multiply_116[0][0]
# __________________________________________________________________________________________________
# lambda_117 (Lambda)             (None, 24, 24, 1)    0           multiply_116[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 24, 24, 2)    0           lambda_116[0][0]
#                                                                  lambda_117[0][0]
# __________________________________________________________________________________________________
# conv2d_325 (Conv2D)             (None, 24, 24, 1)    98          concatenate_58[0][0]
# __________________________________________________________________________________________________
# multiply_117 (Multiply)         (None, 24, 24, 32)   0           multiply_116[0][0]
#                                                                  conv2d_325[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 24, 24, 32)   0           activation_296[0][0]
#                                                                  multiply_117[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 24, 24, 32)   0           add_171[0][0]
# __________________________________________________________________________________________________
# conv2d_326 (Conv2D)             (None, 24, 24, 32)   9248        activation_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 24, 24, 32)   128         conv2d_326[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 24, 24, 32)   0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_327 (Conv2D)             (None, 24, 24, 32)   9248        activation_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 24, 24, 32)   128         conv2d_327[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_59 (Gl (None, 32)           0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_59 (Global (None, 32)           0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# reshape_118 (Reshape)           (None, 1, 1, 32)     0           global_average_pooling2d_59[0][0]
# __________________________________________________________________________________________________
# reshape_119 (Reshape)           (None, 1, 1, 32)     0           global_max_pooling2d_59[0][0]
# __________________________________________________________________________________________________
# dense_130 (Dense)               (None, 1, 1, 4)      132         reshape_118[0][0]
#                                                                  reshape_119[0][0]
# __________________________________________________________________________________________________
# dense_131 (Dense)               (None, 1, 1, 32)     160         dense_130[0][0]
#                                                                  dense_130[1][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 1, 1, 32)     0           dense_131[0][0]
#                                                                  dense_131[1][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 1, 1, 32)     0           add_172[0][0]
# __________________________________________________________________________________________________
# multiply_118 (Multiply)         (None, 24, 24, 32)   0           batch_normalization_243[0][0]
#                                                                  activation_301[0][0]
# __________________________________________________________________________________________________
# lambda_118 (Lambda)             (None, 24, 24, 1)    0           multiply_118[0][0]
# __________________________________________________________________________________________________
# lambda_119 (Lambda)             (None, 24, 24, 1)    0           multiply_118[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 24, 24, 2)    0           lambda_118[0][0]
#                                                                  lambda_119[0][0]
# __________________________________________________________________________________________________
# conv2d_328 (Conv2D)             (None, 24, 24, 1)    98          concatenate_59[0][0]
# __________________________________________________________________________________________________
# multiply_119 (Multiply)         (None, 24, 24, 32)   0           multiply_118[0][0]
#                                                                  conv2d_328[0][0]
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 24, 24, 32)   0           activation_299[0][0]
#                                                                  multiply_119[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 24, 24, 32)   0           add_173[0][0]
# __________________________________________________________________________________________________
# conv2d_329 (Conv2D)             (None, 12, 12, 64)   18496       activation_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 12, 12, 64)   256         conv2d_329[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 12, 12, 64)   0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_330 (Conv2D)             (None, 12, 12, 64)   36928       activation_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 12, 12, 64)   256         conv2d_330[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_60 (Gl (None, 64)           0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_60 (Global (None, 64)           0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# reshape_120 (Reshape)           (None, 1, 1, 64)     0           global_average_pooling2d_60[0][0]
# __________________________________________________________________________________________________
# reshape_121 (Reshape)           (None, 1, 1, 64)     0           global_max_pooling2d_60[0][0]
# __________________________________________________________________________________________________
# dense_132 (Dense)               (None, 1, 1, 8)      520         reshape_120[0][0]
#                                                                  reshape_121[0][0]
# __________________________________________________________________________________________________
# dense_133 (Dense)               (None, 1, 1, 64)     576         dense_132[0][0]
#                                                                  dense_132[1][0]
# __________________________________________________________________________________________________
# add_174 (Add)                   (None, 1, 1, 64)     0           dense_133[0][0]
#                                                                  dense_133[1][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 1, 1, 64)     0           add_174[0][0]
# __________________________________________________________________________________________________
# multiply_120 (Multiply)         (None, 12, 12, 64)   0           batch_normalization_245[0][0]
#                                                                  activation_304[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 12, 12, 1)    0           multiply_120[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 12, 12, 1)    0           multiply_120[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 12, 12, 2)    0           lambda_120[0][0]
#                                                                  lambda_121[0][0]
# __________________________________________________________________________________________________
# conv2d_332 (Conv2D)             (None, 12, 12, 1)    98          concatenate_60[0][0]
# __________________________________________________________________________________________________
# conv2d_331 (Conv2D)             (None, 12, 12, 64)   2112        activation_302[0][0]
# __________________________________________________________________________________________________
# multiply_121 (Multiply)         (None, 12, 12, 64)   0           multiply_120[0][0]
#                                                                  conv2d_332[0][0]
# __________________________________________________________________________________________________
# add_175 (Add)                   (None, 12, 12, 64)   0           conv2d_331[0][0]
#                                                                  multiply_121[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 12, 12, 64)   0           add_175[0][0]
# __________________________________________________________________________________________________
# conv2d_333 (Conv2D)             (None, 12, 12, 64)   36928       activation_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 12, 12, 64)   256         conv2d_333[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 12, 12, 64)   0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_334 (Conv2D)             (None, 12, 12, 64)   36928       activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 12, 12, 64)   256         conv2d_334[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_61 (Gl (None, 64)           0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_61 (Global (None, 64)           0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# reshape_122 (Reshape)           (None, 1, 1, 64)     0           global_average_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# reshape_123 (Reshape)           (None, 1, 1, 64)     0           global_max_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# dense_134 (Dense)               (None, 1, 1, 8)      520         reshape_122[0][0]
#                                                                  reshape_123[0][0]
# __________________________________________________________________________________________________
# dense_135 (Dense)               (None, 1, 1, 64)     576         dense_134[0][0]
#                                                                  dense_134[1][0]
# __________________________________________________________________________________________________
# add_176 (Add)                   (None, 1, 1, 64)     0           dense_135[0][0]
#                                                                  dense_135[1][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 1, 1, 64)     0           add_176[0][0]
# __________________________________________________________________________________________________
# multiply_122 (Multiply)         (None, 12, 12, 64)   0           batch_normalization_247[0][0]
#                                                                  activation_307[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 12, 12, 1)    0           multiply_122[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 12, 12, 1)    0           multiply_122[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 12, 12, 2)    0           lambda_122[0][0]
#                                                                  lambda_123[0][0]
# __________________________________________________________________________________________________
# conv2d_335 (Conv2D)             (None, 12, 12, 1)    98          concatenate_61[0][0]
# __________________________________________________________________________________________________
# multiply_123 (Multiply)         (None, 12, 12, 64)   0           multiply_122[0][0]
#                                                                  conv2d_335[0][0]
# __________________________________________________________________________________________________
# add_177 (Add)                   (None, 12, 12, 64)   0           activation_305[0][0]
#                                                                  multiply_123[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 12, 12, 64)   0           add_177[0][0]
# __________________________________________________________________________________________________
# conv2d_336 (Conv2D)             (None, 12, 12, 64)   36928       activation_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 12, 12, 64)   256         conv2d_336[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 12, 12, 64)   0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, 12, 12, 64)   36928       activation_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 12, 12, 64)   256         conv2d_337[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_62 (Gl (None, 64)           0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_62 (Global (None, 64)           0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# reshape_124 (Reshape)           (None, 1, 1, 64)     0           global_average_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# reshape_125 (Reshape)           (None, 1, 1, 64)     0           global_max_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# dense_136 (Dense)               (None, 1, 1, 8)      520         reshape_124[0][0]
#                                                                  reshape_125[0][0]
# __________________________________________________________________________________________________
# dense_137 (Dense)               (None, 1, 1, 64)     576         dense_136[0][0]
#                                                                  dense_136[1][0]
# __________________________________________________________________________________________________
# add_178 (Add)                   (None, 1, 1, 64)     0           dense_137[0][0]
#                                                                  dense_137[1][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 1, 1, 64)     0           add_178[0][0]
# __________________________________________________________________________________________________
# multiply_124 (Multiply)         (None, 12, 12, 64)   0           batch_normalization_249[0][0]
#                                                                  activation_310[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 12, 12, 1)    0           multiply_124[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 12, 12, 1)    0           multiply_124[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 12, 12, 2)    0           lambda_124[0][0]
#                                                                  lambda_125[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 12, 12, 1)    98          concatenate_62[0][0]
# __________________________________________________________________________________________________
# multiply_125 (Multiply)         (None, 12, 12, 64)   0           multiply_124[0][0]
#                                                                  conv2d_338[0][0]
# __________________________________________________________________________________________________
# add_179 (Add)                   (None, 12, 12, 64)   0           activation_308[0][0]
#                                                                  multiply_125[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 12, 12, 64)   0           add_179[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 1, 1, 64)     0           activation_311[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 64)           0           average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_138 (Dense)               (None, 7)            455         flatten_12[0][0]
# ==================================================================================================
# Total params: 279,251
# Trainable params: 277,875
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# Not using data augmentation.
# Epoch 1/80
# Learning rate:  0.01
# 6/6 [==============================] - 10s 465ms/step - loss: 2.1634 - accuracy: 0.3100 - val_loss: 6.6062 - val_accuracy: 0.2517
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 119ms/step - loss: 1.5671 - accuracy: 0.4905 - val_loss: 613.2719 - val_accuracy: 0.2449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 112ms/step - loss: 1.1980 - accuracy: 0.6376 - val_loss: 550.1038 - val_accuracy: 0.2449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 114ms/step - loss: 0.8854 - accuracy: 0.7627 - val_loss: 342.4263 - val_accuracy: 0.1973
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 116ms/step - loss: 0.6281 - accuracy: 0.8603 - val_loss: 405.1474 - val_accuracy: 0.1361
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 117ms/step - loss: 0.4583 - accuracy: 0.9301 - val_loss: 286.5453 - val_accuracy: 0.2653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 117ms/step - loss: 0.3954 - accuracy: 0.9491 - val_loss: 219.5748 - val_accuracy: 0.2449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 115ms/step - loss: 0.3254 - accuracy: 0.9796 - val_loss: 250.8927 - val_accuracy: 0.1293
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/80
# Learning rate:  0.01
# ...
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 115ms/step - loss: 0.2181 - accuracy: 0.9985 - val_loss: 22.7210 - val_accuracy: 0.1905
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 120ms/step - loss: 0.2046 - accuracy: 0.9985 - val_loss: 23.9847 - val_accuracy: 0.1973
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1946 - accuracy: 1.0000 - val_loss: 32.5178 - val_accuracy: 0.1905
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1858 - accuracy: 0.9985 - val_loss: 19.2481 - val_accuracy: 0.2041
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/80
# Learning rate:  0.01
# 6/6 [==============================] - 1s 117ms/step - loss: 0.1791 - accuracy: 0.9985 - val_loss: 22.2629 - val_accuracy: 0.1973
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 117ms/step - loss: 0.1860 - accuracy: 0.9942 - val_loss: 16.9515 - val_accuracy: 0.2585
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1705 - accuracy: 1.0000 - val_loss: 12.6968 - val_accuracy: 0.3265
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 118ms/step - loss: 0.1697 - accuracy: 1.0000 - val_loss: 9.5006 - val_accuracy: 0.3810
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 120ms/step - loss: 0.1690 - accuracy: 1.0000 - val_loss: 7.0835 - val_accuracy: 0.4354
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 119ms/step - loss: 0.1677 - accuracy: 1.0000 - val_loss: 5.4879 - val_accuracy: 0.4490
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 120ms/step - loss: 0.1669 - accuracy: 1.0000 - val_loss: 4.4666 - val_accuracy: 0.5034
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 117ms/step - loss: 0.1657 - accuracy: 1.0000 - val_loss: 3.8042 - val_accuracy: 0.5034
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 117ms/step - loss: 0.1649 - accuracy: 1.0000 - val_loss: 3.2944 - val_accuracy: 0.5238
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1639 - accuracy: 1.0000 - val_loss: 2.8966 - val_accuracy: 0.5578
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1630 - accuracy: 1.0000 - val_loss: 2.5650 - val_accuracy: 0.5850
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1622 - accuracy: 1.0000 - val_loss: 2.2822 - val_accuracy: 0.5918
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1612 - accuracy: 1.0000 - val_loss: 2.0439 - val_accuracy: 0.6054
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1603 - accuracy: 1.0000 - val_loss: 1.8408 - val_accuracy: 0.6599
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1593 - accuracy: 1.0000 - val_loss: 1.6616 - val_accuracy: 0.6939
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1584 - accuracy: 1.0000 - val_loss: 1.5025 - val_accuracy: 0.7211
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1576 - accuracy: 1.0000 - val_loss: 1.3571 - val_accuracy: 0.7347
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1565 - accuracy: 1.0000 - val_loss: 1.2304 - val_accuracy: 0.7687
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1555 - accuracy: 1.0000 - val_loss: 1.1204 - val_accuracy: 0.7755
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1546 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.7755
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/80
# Learning rate:  0.001
# 6/6 [==============================] - 1s 117ms/step - loss: 0.1537 - accuracy: 1.0000 - val_loss: 0.9049 - val_accuracy: 0.8095
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1530 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.8163
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1529 - accuracy: 1.0000 - val_loss: 0.7583 - val_accuracy: 0.8299
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1528 - accuracy: 1.0000 - val_loss: 0.6925 - val_accuracy: 0.8435
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1529 - accuracy: 1.0000 - val_loss: 0.6339 - val_accuracy: 0.8435
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1526 - accuracy: 1.0000 - val_loss: 0.5822 - val_accuracy: 0.8571
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1525 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.8707
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1524 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.8776
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1524 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.8844
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1522 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.8980
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1521 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.9048
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1520 - accuracy: 1.0000 - val_loss: 0.3773 - val_accuracy: 0.9116
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1519 - accuracy: 1.0000 - val_loss: 0.3576 - val_accuracy: 0.9184
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1518 - accuracy: 1.0000 - val_loss: 0.3423 - val_accuracy: 0.9320
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1516 - accuracy: 1.0000 - val_loss: 0.3290 - val_accuracy: 0.9456
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1516 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9524
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1514 - accuracy: 1.0000 - val_loss: 0.3090 - val_accuracy: 0.9456
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1513 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9524
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1512 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9524
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1511 - accuracy: 1.0000 - val_loss: 0.2908 - val_accuracy: 0.9524
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1510 - accuracy: 1.0000 - val_loss: 0.2868 - val_accuracy: 0.9592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1508 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1507 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1507 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1506 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1504 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1502 - accuracy: 1.0000 - val_loss: 0.2742 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1502 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1501 - accuracy: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1499 - accuracy: 1.0000 - val_loss: 0.2720 - val_accuracy: 0.9728
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1497 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1497 - accuracy: 1.0000 - val_loss: 0.2709 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1496 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1494 - accuracy: 1.0000 - val_loss: 0.2704 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 118ms/step - loss: 0.1493 - accuracy: 1.0000 - val_loss: 0.2699 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1491 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1490 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1488 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 114ms/step - loss: 0.1487 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1486 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/80
# Learning rate:  0.0001
# 6/6 [==============================] - 1s 113ms/step - loss: 0.1485 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9660
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3050 - accuracy: 0.9524
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, categorical_crossentropy
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt

# Model configuration
batch_size = 128
loss_function = categorical_crossentropy
no_classes = 7
no_epochs = 30
optimizer = RMSprop(lr = 0.01)
verbosity = 1


# Load FER2013 Dataset
x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()


# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
#x_val = x_test.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(512, kernel_size=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(Conv2D(1024, kernel_size=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])

# Fit data to model
history = model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=no_epochs,
            validation_data = (x_val,y_val),
            verbose=verbosity)

# Generate generalization metrics
score = model.evaluate(x_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# Visualize history
# Plot history: Loss
plt.plot(history.history['val_loss'])
plt.title('Validation loss history')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(history.history['val_accuracy'])
plt.title('Validation accuracy history')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

# %%
import glob
emo_folder = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'}
images = []
x = []
y = []
for i, j in emo_folder.items():
  filelist = glob.glob(j + '/*.png')
  for fname in filelist:
    x.append(np.array(Image.open(fname)))
    y.append(i)
x = np.array(x)
y = np.array(y)

pd.DataFrame(x.reshape(len(x),2304)).to_csv('x_train.csv',header=None,index=None)
pd.DataFrame(y).to_csv('y_train.csv',header=None,index=None)

import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
print("Display 25 images from the train set in the form of 5x5 matrix with their respective labels:")
plt.figure(figsize=[8,8])
for i in range(25):
  plt.subplot(5,5,1+i)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x[i].reshape([48,48]), cmap='gray')
  plt.title(emo_folder[int(y[i])])

plt.show()

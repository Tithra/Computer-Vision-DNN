# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Load already prepared CK+
def load_CKplus_full():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)

  x = np.array(x)
  x = x.reshape(len(x),48,48,1)
  y = np.array(y)
  return x, y

def load_CKplus_split():
  x = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/inputs.csv",header=None)
  y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/labels.csv",header=None)
  x, y = shuffle(x, y,random_state = 2021)
  x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=147, random_state=2021)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=147, random_state=2021)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val

#Load already prepared FER2013
def load_FER2013():
  x_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_train.csv",header=None,)
  y_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_train.csv",header=None)
  x_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_test.csv",header=None)
  y_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_test.csv",header=None)
  x_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/x_val.csv",header=None)
  y_val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SIT723/y_val.csv",header=None)

  x_train = np.array(x_train)
  x_train = x_train.reshape(len(x_train),48,48,1)
  y_train = np.array(y_train)
  x_test = np.array(x_test)
  x_test = x_test.reshape(len(x_test),48,48,1)
  y_test = np.array(y_test)
  x_val = np.array(x_val)
  x_val = x_val.reshape(len(x_val),48,48,1)
  y_val = np.array(y_val)
  return x_train, y_train, x_test, y_test, x_val, y_val


x_train, y_train, x_test, y_test, x_val, y_val = load_FER2013()

x_train.shape, x_test.shape, x_val.shape
# Out:
# ((28709, 48, 48, 1), (3589, 48, 48, 1), (3589, 48, 48, 1))

# %%
#face recognition packages
# !pip install opencv-python
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 15 kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=28d884796f3fdc85dabd62818b37bae77c92c54fb4461319715c930b1023f845
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#face detection, crop, sharpen, emboss using both face_recognition and cv2 packages
import face_recognition
from skimage.feature import local_binary_pattern
import cv2
import math
from google.colab.patches import cv2_imshow
from PIL import Image, ImageEnhance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def transform(img):
  if len(img.shape)>2:
    img = img.reshape(48,48)
  #gamma
  mid = 0.5 
  mean = np.mean(img)
  gamma = math.log(mid*255)/math.log(mean)
  img = np.power(img, gamma).clip(0,255).astype(np.uint8)

  #img = Image.fromarray(img)
  #filter = ImageEnhance.Contrast(img)# add contrast
  #img = filter.enhance(2)

  #img = img.filter(ImageEnhance.ImageFilter.SMOOTH)
  #img = img.filter(ImageEnhance.ImageFilter.EMBOSS)#emboss
  #img = img.filter(ImageEnhance.ImageFilter.EDGE_ENHANCE)
  
  #img = local_binary_pattern(img, 30, 1)
  #img = np.array(img)
  return img
def pre_process(input, target, output_height=48, output_width=48):
  face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
  face_cascade = cv2.CascadeClassifier()
  if not face_cascade.load(cv2.samples.findFile(face_cascade_name)):
    print("Error loading xml file")
    exit(0)

  x_temp = []
  y_temp = []
  #plt.figure(figsize=[8,8])
  for i in range(len(input)):
    img = np.array(input[i],'uint8')
    face_detect_1 = face_recognition.face_locations(img) #Using face_recoginition
    face_detect_2 = face_cascade.detectMultiScale(img,1.1, 1) #Using cv2
    if (len(face_detect_1)>0):
      (y, w, h, x) = face_detect_1[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img,(output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    elif (len(face_detect_2)>0):
      (x, y, w, h) = face_detect_2[0]
      #img = img[y:y + h, x:x + w]
      #img = cv2.resize(img, (output_height, output_width))
      
      img = transform(img)
      img = img.reshape(output_height,output_width,1)
      x_temp.append(img)
      y_temp.append(target[i])

    #cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,0), 1)
    #print(i, x, y, w, h)

  x_temp = np.array(x_temp)
  y_temp = np.array(y_temp)
  return x_temp, y_temp

x_train, y_train = pre_process(x_train, y_train)
x_test, y_test = pre_process(x_test, y_test)
x_val, y_val = pre_process(x_val, y_val)

#For conveniency when training
trainx = x_train.copy()
trainy = y_train.copy()
testx = x_test.copy()
testy = y_test.copy()
valx = x_val.copy()
valy = y_val.copy()

x_train.shape, y_train.shape
# Out:
# ((22279, 48, 48, 1), (22279, 1))

# %%
import matplotlib.pyplot as plt
# Displaying 25 images from training dataset in 5x5 matrix
emotion={0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'} #for FER2013
#emotion = {0:'anger',1:'contempt',2:'disgust',3:'fear',4:'happy',5:'sadness',6:'surprise'} #for CK+
def plot_image(input_images,labels):
  print("Display 50 images from the train set in the form of 5x5 matrix with their respective labels:")
  plt.figure(figsize=[16,8])
  for i in range(50):
    plt.subplot(5,10,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(input_images[i].reshape([48,48]), cmap='gray')
    plt.title(emotion[int(labels[i])])
  plt.show()

plot_image(x_train,y_train)
# Out:
# Display 50 images from the train set in the form of 5x5 matrix with their respective labels:

# %%
#CBAM 

from __future__ import print_function
import keras
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import resnet_v1, mobilenets
import numpy as np
import matplotlib.pyplot as plt
import math
import os


# Training parameters
batch_size = 512
epochs = 200
data_augmentation = True
num_classes = 7

attention_module = 'cbam_block'
base_model = 'ResNet18'
# Choose what attention_module to use: cbam_block / se_block / None
model_type = base_model if attention_module==None else base_model+' '+attention_module


# Load dataset.

x_train = trainx.copy()
y_train = trainy.copy()
x_test = testx.copy()
y_test = testy.copy()
x_val = valx.copy()
y_val = valy.copy()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_val = x_val.astype('float32') / 255


# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)

# This will preprocessing data augmentation:
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)
datagen.fit(x_train)

for imgs, labels in datagen.flow(x_train, y_train,batch_size = len(x_train), seed=2021):
  x = imgs
  y = labels
  break

x_train = x.copy()
y_train = y.copy()


depth = 20 # For ResNet, specify the depth (e.g. ResNet50: depth=50, ResNet101: Depth=101)
model = resnet_v1.resnet_v1(input_shape=input_shape, depth=depth,num_classes=7, attention_module='cbam_block')
#model = mobilenets.MobileNet(input_shape=input_shape, classes=num_classes, attention_module='cbam_block')
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',
              optimizer= Adam(),#SGD(momentum=0.9, clipvalue=0.1), #SGD(decay=2e-5, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
#model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'model.{epoch:03d}.h5' + model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)
# 1 cycle learning rate
def lr_schedule(epoch):
    lr = 0.01
    if epoch >= (epochs*0.6):
      lr = 0.0001
    elif epoch >= (epochs*0.2):
      lr=0.001
    print('Learning rate: ', lr)
    return lr
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

def plot_model_history(history):
  # Plot training loss values
  print("Plot loss values (Train vs. Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['loss'],label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

  print("Plot the accuracy (Train and Validation)")
  plt.figure(figsize=(8, 5))
  plt.plot(history.history['accuracy'],label='Training Accuracy')
  plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

plot_model_history(history)
# Score trained model.
#scores = model.evaluate(x_test, y_test, verbose=1,batch_size=batch_size,)
# Out:
# Epoch 1/200
# Learning rate:  0.01
# 44/44 [==============================] - 32s 567ms/step - loss: 1.9790 - accuracy: 0.2662 - val_loss: 1.9518 - val_accuracy: 0.2666
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/200
# Learning rate:  0.01
# 44/44 [==============================] - 23s 529ms/step - loss: 1.8213 - accuracy: 0.3089 - val_loss: 2.0604 - val_accuracy: 0.2226
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/200
# Learning rate:  0.01
# 44/44 [==============================] - 23s 531ms/step - loss: 1.6393 - accuracy: 0.4147 - val_loss: 3.8177 - val_accuracy: 0.1884
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/200
# Learning rate:  0.01
# 44/44 [==============================] - 23s 533ms/step - loss: 1.4913 - accuracy: 0.4779 - val_loss: 2.5510 - val_accuracy: 0.2204
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/200
# Learning rate:  0.01
# 44/44 [==============================] - 23s 534ms/step - loss: 1.3854 - accuracy: 0.5172 - val_loss: 2.3006 - val_accuracy: 0.2117
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/200
# Learning rate:  0.01
# 44/44 [==============================] - 23s 533ms/step - loss: 1.3362 - accuracy: 0.5387 - val_loss: 1.6815 - val_accuracy: 0.3958
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 537ms/step - loss: 1.2883 - accuracy: 0.5627 - val_loss: 1.9732 - val_accuracy: 0.4027
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 537ms/step - loss: 1.2309 - accuracy: 0.5886 - val_loss: 1.5689 - val_accuracy: 0.4802
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 537ms/step - loss: 1.1934 - accuracy: 0.6015 - val_loss: 1.8086 - val_accuracy: 0.3605
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 540ms/step - loss: 1.1798 - accuracy: 0.6132 - val_loss: 1.7608 - val_accuracy: 0.3590
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 539ms/step - loss: 1.1498 - accuracy: 0.6253 - val_loss: 1.4615 - val_accuracy: 0.5085
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 540ms/step - loss: 1.1209 - accuracy: 0.6385 - val_loss: 2.0944 - val_accuracy: 0.3208
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 540ms/step - loss: 1.1049 - accuracy: 0.6513 - val_loss: 1.6777 - val_accuracy: 0.4511
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 541ms/step - loss: 1.0913 - accuracy: 0.6599 - val_loss: 1.8048 - val_accuracy: 0.4551
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 541ms/step - loss: 1.0891 - accuracy: 0.6631 - val_loss: 1.5555 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 543ms/step - loss: 1.0642 - accuracy: 0.6754 - val_loss: 1.4772 - val_accuracy: 0.5286
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 543ms/step - loss: 1.0460 - accuracy: 0.6885 - val_loss: 2.0437 - val_accuracy: 0.3696
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 544ms/step - loss: 1.0460 - accuracy: 0.6904 - val_loss: 1.6807 - val_accuracy: 0.5195
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 544ms/step - loss: 1.0155 - accuracy: 0.7067 - val_loss: 1.6986 - val_accuracy: 0.5104
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 547ms/step - loss: 1.0113 - accuracy: 0.7140 - val_loss: 1.8308 - val_accuracy: 0.4765
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 543ms/step - loss: 0.9911 - accuracy: 0.7263 - val_loss: 2.0464 - val_accuracy: 0.4460
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.9817 - accuracy: 0.7323 - val_loss: 2.0817 - val_accuracy: 0.4864
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.9685 - accuracy: 0.7394 - val_loss: 1.8605 - val_accuracy: 0.5344
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.9467 - accuracy: 0.7548 - val_loss: 2.2737 - val_accuracy: 0.4402
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.9536 - accuracy: 0.7552 - val_loss: 2.0535 - val_accuracy: 0.4711
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.9379 - accuracy: 0.7617 - val_loss: 2.3209 - val_accuracy: 0.4616
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.9189 - accuracy: 0.7778 - val_loss: 2.3941 - val_accuracy: 0.3801
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.9082 - accuracy: 0.7852 - val_loss: 2.1476 - val_accuracy: 0.4853
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 544ms/step - loss: 0.8923 - accuracy: 0.7942 - val_loss: 2.9952 - val_accuracy: 0.3663
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 544ms/step - loss: 0.8670 - accuracy: 0.8053 - val_loss: 2.4932 - val_accuracy: 0.4944
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.8692 - accuracy: 0.8054 - val_loss: 2.8348 - val_accuracy: 0.4565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.8592 - accuracy: 0.8144 - val_loss: 2.6216 - val_accuracy: 0.4867
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 544ms/step - loss: 0.8571 - accuracy: 0.8161 - val_loss: 3.1780 - val_accuracy: 0.3288
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.8646 - accuracy: 0.8160 - val_loss: 2.8389 - val_accuracy: 0.4442
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.8074 - accuracy: 0.8402 - val_loss: 2.5341 - val_accuracy: 0.4405
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.8110 - accuracy: 0.8389 - val_loss: 4.9000 - val_accuracy: 0.3911
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.7985 - accuracy: 0.8431 - val_loss: 3.4117 - val_accuracy: 0.4791
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.8019 - accuracy: 0.8476 - val_loss: 2.6969 - val_accuracy: 0.5195
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 546ms/step - loss: 0.7906 - accuracy: 0.8500 - val_loss: 2.7837 - val_accuracy: 0.5231
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/200
# Learning rate:  0.01
# 44/44 [==============================] - 24s 545ms/step - loss: 0.7793 - accuracy: 0.8595 - val_loss: 2.5380 - val_accuracy: 0.4845
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.6078 - accuracy: 0.9290 - val_loss: 2.3875 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.4924 - accuracy: 0.9773 - val_loss: 2.4237 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 543ms/step - loss: 0.4504 - accuracy: 0.9902 - val_loss: 2.4896 - val_accuracy: 0.5420
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.4253 - accuracy: 0.9955 - val_loss: 2.5185 - val_accuracy: 0.5427
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.4072 - accuracy: 0.9975 - val_loss: 2.5959 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3917 - accuracy: 0.9984 - val_loss: 2.7513 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.3791 - accuracy: 0.9990 - val_loss: 2.9420 - val_accuracy: 0.5398
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3683 - accuracy: 0.9994 - val_loss: 3.1388 - val_accuracy: 0.5344
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.3595 - accuracy: 0.9996 - val_loss: 3.0747 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3511 - accuracy: 0.9996 - val_loss: 3.3415 - val_accuracy: 0.5340
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.3448 - accuracy: 0.9996 - val_loss: 3.1514 - val_accuracy: 0.5315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3373 - accuracy: 0.9998 - val_loss: 3.2377 - val_accuracy: 0.5413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.3298 - accuracy: 0.9998 - val_loss: 3.3398 - val_accuracy: 0.5340
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3249 - accuracy: 0.9997 - val_loss: 3.2682 - val_accuracy: 0.5289
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.3169 - accuracy: 1.0000 - val_loss: 3.3588 - val_accuracy: 0.5351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.3097 - accuracy: 1.0000 - val_loss: 3.2678 - val_accuracy: 0.5238
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.3063 - accuracy: 0.9996 - val_loss: 3.5816 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2993 - accuracy: 1.0000 - val_loss: 3.6334 - val_accuracy: 0.5304
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2923 - accuracy: 1.0000 - val_loss: 3.3683 - val_accuracy: 0.5253
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2872 - accuracy: 0.9999 - val_loss: 3.6965 - val_accuracy: 0.5293
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2810 - accuracy: 1.0000 - val_loss: 3.5291 - val_accuracy: 0.5282
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2753 - accuracy: 1.0000 - val_loss: 3.5573 - val_accuracy: 0.5329
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2690 - accuracy: 1.0000 - val_loss: 3.6342 - val_accuracy: 0.5333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2629 - accuracy: 1.0000 - val_loss: 3.4805 - val_accuracy: 0.5293
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2571 - accuracy: 1.0000 - val_loss: 3.4998 - val_accuracy: 0.5296
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 543ms/step - loss: 0.2530 - accuracy: 0.9996 - val_loss: 3.4909 - val_accuracy: 0.5296
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.2515 - accuracy: 0.9993 - val_loss: 4.2068 - val_accuracy: 0.5322
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2445 - accuracy: 0.9997 - val_loss: 3.9657 - val_accuracy: 0.5264
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2406 - accuracy: 0.9994 - val_loss: 3.9617 - val_accuracy: 0.5326
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2378 - accuracy: 0.9991 - val_loss: 4.3049 - val_accuracy: 0.5231
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2433 - accuracy: 0.9968 - val_loss: 3.8731 - val_accuracy: 0.5264
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2361 - accuracy: 0.9976 - val_loss: 3.7239 - val_accuracy: 0.5053
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2300 - accuracy: 0.9987 - val_loss: 4.0183 - val_accuracy: 0.5315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2233 - accuracy: 0.9990 - val_loss: 4.5036 - val_accuracy: 0.5191
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2190 - accuracy: 0.9991 - val_loss: 4.5618 - val_accuracy: 0.5024
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2242 - accuracy: 0.9961 - val_loss: 4.4812 - val_accuracy: 0.5158
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2289 - accuracy: 0.9937 - val_loss: 5.9508 - val_accuracy: 0.5129
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2340 - accuracy: 0.9917 - val_loss: 4.2459 - val_accuracy: 0.5231
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2259 - accuracy: 0.9947 - val_loss: 4.6473 - val_accuracy: 0.5300
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2212 - accuracy: 0.9948 - val_loss: 4.7501 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2191 - accuracy: 0.9953 - val_loss: 5.0722 - val_accuracy: 0.5282
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 82/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2118 - accuracy: 0.9969 - val_loss: 5.1074 - val_accuracy: 0.5031
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 83/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.2042 - accuracy: 0.9984 - val_loss: 4.8692 - val_accuracy: 0.5267
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 84/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1981 - accuracy: 0.9994 - val_loss: 4.9850 - val_accuracy: 0.5336
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 85/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1940 - accuracy: 0.9996 - val_loss: 4.8169 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 86/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1899 - accuracy: 0.9997 - val_loss: 4.9882 - val_accuracy: 0.5260
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 87/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1869 - accuracy: 0.9998 - val_loss: 4.9722 - val_accuracy: 0.5213
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 88/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1842 - accuracy: 0.9998 - val_loss: 5.0935 - val_accuracy: 0.5296
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 89/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1825 - accuracy: 0.9993 - val_loss: 5.3046 - val_accuracy: 0.5322
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 90/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1860 - accuracy: 0.9975 - val_loss: 4.8603 - val_accuracy: 0.5173
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 91/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2072 - accuracy: 0.9902 - val_loss: 4.1955 - val_accuracy: 0.5176
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 92/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2057 - accuracy: 0.9910 - val_loss: 4.9222 - val_accuracy: 0.5220
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 93/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.2017 - accuracy: 0.9922 - val_loss: 5.8000 - val_accuracy: 0.5238
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 94/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1951 - accuracy: 0.9937 - val_loss: 5.3434 - val_accuracy: 0.4995
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 95/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1881 - accuracy: 0.9958 - val_loss: 5.2581 - val_accuracy: 0.5442
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 96/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1816 - accuracy: 0.9978 - val_loss: 5.5267 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 97/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1759 - accuracy: 0.9987 - val_loss: 5.2888 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 98/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1769 - accuracy: 0.9976 - val_loss: 5.4948 - val_accuracy: 0.5260
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 99/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1762 - accuracy: 0.9977 - val_loss: 4.9484 - val_accuracy: 0.5176
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 100/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1736 - accuracy: 0.9975 - val_loss: 5.4021 - val_accuracy: 0.5322
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 101/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1769 - accuracy: 0.9963 - val_loss: 5.2019 - val_accuracy: 0.5322
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 102/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1758 - accuracy: 0.9962 - val_loss: 5.4906 - val_accuracy: 0.4936
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 103/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1770 - accuracy: 0.9952 - val_loss: 5.4965 - val_accuracy: 0.5471
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 104/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1742 - accuracy: 0.9959 - val_loss: 5.2686 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 105/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1689 - accuracy: 0.9977 - val_loss: 5.4292 - val_accuracy: 0.5351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 106/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1691 - accuracy: 0.9970 - val_loss: 4.9154 - val_accuracy: 0.5246
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 107/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1712 - accuracy: 0.9962 - val_loss: 6.1346 - val_accuracy: 0.4733
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 108/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1744 - accuracy: 0.9943 - val_loss: 5.1872 - val_accuracy: 0.5198
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 109/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1725 - accuracy: 0.9951 - val_loss: 5.1599 - val_accuracy: 0.5267
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 110/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1645 - accuracy: 0.9971 - val_loss: 5.6474 - val_accuracy: 0.5286
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 111/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1601 - accuracy: 0.9985 - val_loss: 5.6330 - val_accuracy: 0.5267
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 112/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1569 - accuracy: 0.9991 - val_loss: 5.2608 - val_accuracy: 0.5326
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 113/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1558 - accuracy: 0.9989 - val_loss: 5.6389 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 114/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1561 - accuracy: 0.9985 - val_loss: 6.0094 - val_accuracy: 0.5333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 115/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1599 - accuracy: 0.9967 - val_loss: 5.3224 - val_accuracy: 0.5304
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 116/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1624 - accuracy: 0.9961 - val_loss: 5.5882 - val_accuracy: 0.5187
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 117/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1608 - accuracy: 0.9957 - val_loss: 5.2486 - val_accuracy: 0.5216
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 118/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1624 - accuracy: 0.9948 - val_loss: 4.7329 - val_accuracy: 0.5307
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 119/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1617 - accuracy: 0.9953 - val_loss: 5.7178 - val_accuracy: 0.5155
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 120/200
# Learning rate:  0.001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1581 - accuracy: 0.9963 - val_loss: 5.5735 - val_accuracy: 0.5162
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 121/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1508 - accuracy: 0.9987 - val_loss: 5.4424 - val_accuracy: 0.5300
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 122/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1468 - accuracy: 1.0000 - val_loss: 5.4445 - val_accuracy: 0.5366
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 123/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1460 - accuracy: 1.0000 - val_loss: 5.4385 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 124/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1457 - accuracy: 1.0000 - val_loss: 5.4348 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 125/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1454 - accuracy: 1.0000 - val_loss: 5.4465 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 126/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1451 - accuracy: 1.0000 - val_loss: 5.4531 - val_accuracy: 0.5355
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 127/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1448 - accuracy: 1.0000 - val_loss: 5.4673 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 128/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1445 - accuracy: 1.0000 - val_loss: 5.4833 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 129/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1443 - accuracy: 1.0000 - val_loss: 5.4960 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 130/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1441 - accuracy: 1.0000 - val_loss: 5.5113 - val_accuracy: 0.5366
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 131/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1438 - accuracy: 1.0000 - val_loss: 5.5262 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 132/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1435 - accuracy: 1.0000 - val_loss: 5.5351 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 133/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1433 - accuracy: 1.0000 - val_loss: 5.5493 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 134/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1430 - accuracy: 1.0000 - val_loss: 5.5571 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 135/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1428 - accuracy: 1.0000 - val_loss: 5.5680 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 136/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1426 - accuracy: 1.0000 - val_loss: 5.5766 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 137/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1423 - accuracy: 1.0000 - val_loss: 5.5849 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 138/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1420 - accuracy: 1.0000 - val_loss: 5.5929 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 139/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1418 - accuracy: 1.0000 - val_loss: 5.5945 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 140/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1415 - accuracy: 1.0000 - val_loss: 5.5995 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 141/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1413 - accuracy: 1.0000 - val_loss: 5.6239 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 142/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1410 - accuracy: 1.0000 - val_loss: 5.6319 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 143/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1407 - accuracy: 1.0000 - val_loss: 5.6291 - val_accuracy: 0.5398
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 144/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1404 - accuracy: 1.0000 - val_loss: 5.6483 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 145/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1402 - accuracy: 1.0000 - val_loss: 5.6518 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 146/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1399 - accuracy: 1.0000 - val_loss: 5.6544 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 147/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1396 - accuracy: 1.0000 - val_loss: 5.6738 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 148/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1393 - accuracy: 1.0000 - val_loss: 5.6870 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 149/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1390 - accuracy: 1.0000 - val_loss: 5.6710 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 150/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1387 - accuracy: 1.0000 - val_loss: 5.6805 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 151/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1384 - accuracy: 1.0000 - val_loss: 5.7113 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 152/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1381 - accuracy: 1.0000 - val_loss: 5.7173 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 153/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1378 - accuracy: 1.0000 - val_loss: 5.7285 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 154/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1375 - accuracy: 1.0000 - val_loss: 5.7389 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 155/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1371 - accuracy: 1.0000 - val_loss: 5.7424 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 156/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1368 - accuracy: 1.0000 - val_loss: 5.7568 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 157/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1365 - accuracy: 1.0000 - val_loss: 5.7478 - val_accuracy: 0.5398
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 158/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1361 - accuracy: 1.0000 - val_loss: 5.7549 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 159/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1358 - accuracy: 1.0000 - val_loss: 5.7750 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 160/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1354 - accuracy: 1.0000 - val_loss: 5.7799 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 161/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1351 - accuracy: 1.0000 - val_loss: 5.8017 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 162/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1347 - accuracy: 1.0000 - val_loss: 5.7822 - val_accuracy: 0.5402
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 163/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1344 - accuracy: 1.0000 - val_loss: 5.8031 - val_accuracy: 0.5387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 164/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1340 - accuracy: 1.0000 - val_loss: 5.8017 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 165/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1336 - accuracy: 1.0000 - val_loss: 5.8030 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 166/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1332 - accuracy: 1.0000 - val_loss: 5.8065 - val_accuracy: 0.5384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 167/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1328 - accuracy: 1.0000 - val_loss: 5.8378 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 168/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1324 - accuracy: 1.0000 - val_loss: 5.8588 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 169/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1320 - accuracy: 1.0000 - val_loss: 5.8416 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 170/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1316 - accuracy: 1.0000 - val_loss: 5.8481 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 171/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1312 - accuracy: 1.0000 - val_loss: 5.8422 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 172/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1308 - accuracy: 1.0000 - val_loss: 5.8469 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 173/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1303 - accuracy: 1.0000 - val_loss: 5.8627 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 174/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1299 - accuracy: 1.0000 - val_loss: 5.8968 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 175/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1295 - accuracy: 1.0000 - val_loss: 5.8705 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 176/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1290 - accuracy: 1.0000 - val_loss: 5.8845 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 177/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1286 - accuracy: 1.0000 - val_loss: 5.9152 - val_accuracy: 0.5366
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 178/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1281 - accuracy: 1.0000 - val_loss: 5.9228 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 179/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1276 - accuracy: 1.0000 - val_loss: 5.9447 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 180/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1271 - accuracy: 1.0000 - val_loss: 5.9355 - val_accuracy: 0.5377
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 181/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 5.9418 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 182/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1261 - accuracy: 1.0000 - val_loss: 5.9534 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 183/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 544ms/step - loss: 0.1256 - accuracy: 1.0000 - val_loss: 5.9460 - val_accuracy: 0.5366
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 184/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1251 - accuracy: 1.0000 - val_loss: 5.9745 - val_accuracy: 0.5380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 185/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1246 - accuracy: 1.0000 - val_loss: 5.9396 - val_accuracy: 0.5351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 186/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1241 - accuracy: 1.0000 - val_loss: 5.9689 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 187/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1236 - accuracy: 1.0000 - val_loss: 5.9771 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 188/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 549ms/step - loss: 0.1230 - accuracy: 1.0000 - val_loss: 5.9672 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 189/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 549ms/step - loss: 0.1225 - accuracy: 1.0000 - val_loss: 5.9763 - val_accuracy: 0.5347
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 190/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1219 - accuracy: 1.0000 - val_loss: 5.9724 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 191/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1213 - accuracy: 1.0000 - val_loss: 5.9855 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 192/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1208 - accuracy: 1.0000 - val_loss: 6.0184 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 193/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 546ms/step - loss: 0.1202 - accuracy: 1.0000 - val_loss: 6.0157 - val_accuracy: 0.5362
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 194/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1196 - accuracy: 1.0000 - val_loss: 6.0122 - val_accuracy: 0.5391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 195/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1190 - accuracy: 1.0000 - val_loss: 5.9923 - val_accuracy: 0.5373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 196/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1184 - accuracy: 1.0000 - val_loss: 5.9701 - val_accuracy: 0.5358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 197/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1178 - accuracy: 1.0000 - val_loss: 6.0475 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 198/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 545ms/step - loss: 0.1172 - accuracy: 1.0000 - val_loss: 5.9945 - val_accuracy: 0.5326
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 199/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 547ms/step - loss: 0.1165 - accuracy: 1.0000 - val_loss: 6.0052 - val_accuracy: 0.5347
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 200/200
# Learning rate:  0.0001
# 44/44 [==============================] - 24s 548ms/step - loss: 0.1159 - accuracy: 1.0000 - val_loss: 6.0103 - val_accuracy: 0.5369
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Plot loss values (Train vs. Validation)
# Plot the accuracy (Train and Validation)
